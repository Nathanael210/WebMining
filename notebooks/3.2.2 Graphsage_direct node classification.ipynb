# %% [markdown]
# # Graphsage direct paper classification

# %%
# install StellarGraph if running on Google Colab
import sys
if 'google.colab' in sys.modules:
    # %pip install -q stellargraph[demos]==1.2.1

# %%
import networkx as nx
import pandas as pd
import numpy as np
import itertools
import os

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.utils import class_weight

import stellargraph as sg
from stellargraph import StellarGraph, StellarDiGraph
from stellargraph import globalvar
from stellargraph import random as sg_random
from stellargraph.mapper import GraphSAGENodeGenerator, DirectedGraphSAGENodeGenerator
from stellargraph.layer import GraphSAGE, MeanAggregator, DirectedGraphSAGE

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from tensorflow import random as tf_random
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential, load_model
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, f1_score, make_scorer
from sklearn.utils.multiclass import unique_labels
from stellargraph import datasets
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from collections import Counter

# from google.colab import drive
# drive.mount('/content/drive')

import torch
torch.cuda.is_available()


sg_random.set_seed(42)
tf_random.set_seed(42)
# %matplotlib inline

# %% [markdown]
# ## Paths

# %%
# Parent paths
# google_path = '/content/drive/My Drive/'
# local_path = '/home/v.zevallosm/'
# parent_path = google_path

#Specific paths
# PATH_DATES = parent_path+'WebMining/data/raw/hep-th-slacdates_unzipped.txt'
# PATH_CITATION = parent_path+'WebMining/data/raw/hep-th-citations_unzipped_filtered.txt'
# PATH_LABEL = parent_path+'WebMining/data/processed/papers_label.csv'
# PATH_ATTRIBUTES = parent_path+'WebMining/data/processed/papers_label.csv'

# PATH_MODEL_GS_D_B = parent_path+'WebMining/models/graphsage_directed_base.hdf5'

PATH_DATES = 'hep-th-slacdates_unzipped.txt'
PATH_CITATION = 'hep-th-citations_unzipped_filtered.txt'
PATH_LABEL = 'papers_label.csv'
PATH_ATTRIBUTES = 'papers_label.csv'

PATH_MODEL_GS_D_B = 'graphsage_directed_base.hdf5'

# %% [markdown]
# ## Loading the dataset

# %%
def read_dates(path):
    df = pd.read_csv(path, sep=' ', header=None, names=['id_paper', 'slac_date'])
    df['slac_date'] = pd.to_datetime(df['slac_date'])
    display(df.head(5))
    return (df)

# %%
def read_citation(path, df):
    df = pd.read_csv(path, sep=' ', header=None, names=['source', 'target'])
    display(df.head(5))
    return(df)

# %%
def get_labels(path, df2, label, date):
    df1 = pd.read_csv(path, index_col=0)
    df1.index.name='id_paper'
    df2 = df2.set_index("id_paper")
    df1 = pd.merge(df1, df2, left_index=True, right_index=True)
    label_full = df1[label]
    label_train = df1[df1.slac_date < date][label]
    label_test = df1[df1.slac_date >= date][label]
    print('Full nodes: %s   Train nodes: %s   Test nodes: %s'%(len(label_full), len(label_train), len(label_test)))
    return (label_full, label_train, label_test)

# %%
def get_features(path, df2, date):
    # Papers ids 
    df1 = pd.read_csv(path, index_col=0)
    df1.index.name='id_paper'

    # Date df
    df2 = df2.set_index("id_paper")

    # Combine datasets
    df1 = pd.merge(df1, df2, left_index=True, right_index=True)

    # Date features
    df1['slac_date'] = pd.to_datetime(df1['slac_date'])
    df1['year']= df1[date].dt.year
    df1['month']= df1[date].dt.month
    df1['week']= df1[date].dt.isocalendar().week

    df1['month_sin'] = np.sin((df1.month-1)*(2.*np.pi/12))
    df1['month_cos'] = np.cos((df1.month-1)*(2.*np.pi/12))

    df1['week_sin'] = np.sin((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))
    df1['week_cos'] = np.cos((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))

    ls = ['year', 'month_sin', 'month_cos', 'week_sin', 'week_cos']
    df_date = df1[ls]
    display(df_date.head(5))
    return(df_date)

# %%
df_dates = read_dates(PATH_DATES)
# Out:
#    id_paper  slac_date
# 0      1001 2000-01-04
# 1      1002 2000-01-04
# 2      1003 2000-01-04
# 3      1004 2000-01-04
# 4      1005 2000-01-04

# %%
df_citation = read_citation(PATH_CITATION, df_dates)
# Out:
#    source   target
# 0    1001  9304045
# 1    1001  9308122
# 2    1001  9309097
# 3    1001  9311042
# 4    1001  9401139

# %%
full_nodes, train_nodes, test_nodes = get_labels(PATH_LABEL, df_dates, 'label', '2002-01-01')
# Out:
# Full nodes: 27750   Train nodes: 23567   Test nodes: 4183

# %%
df_attributes = get_features(PATH_LABEL, df_dates, 'slac_date')
# Out:
#           year  month_sin  month_cos  week_sin  week_cos
# id_paper
# 1001      2000        0.0        1.0       0.0       1.0
# 1002      2000        0.0        1.0       0.0       1.0
# 1003      2000        0.0        1.0       0.0       1.0
# 1004      2000        0.0        1.0       0.0       1.0
# 1005      2000        0.0        1.0       0.0       1.0

# %%
df_attributes.to_csv('dates_sin_cos.csv')

# %% [markdown]
# ## Graph construction

# %%
graph_citation_full = StellarDiGraph({"paper": df_attributes}, {"cites": df_citation})
print(graph_citation_full.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 27750, Edges: 351763
#
#  Node types:
#   paper: [27750]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [351763]
#         Weights: all 1 (default)
#         Features: none

# %%
graph_citation_train = graph_citation_full.subgraph(train_nodes.index)
print(graph_citation_train.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 23567, Edges: 271167
#
#  Node types:
#   paper: [23567]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [271167]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# ### Splitting the data

# %%
train_labels, test_labels = model_selection.train_test_split(
    train_nodes,
    train_size=0.7, #0.05
    test_size=None,
    stratify=train_nodes,
    random_state=42,
)

val_labels, test_labels = model_selection.train_test_split(
    test_labels, 
    train_size=0.67, #0.2
    test_size=None, 
    stratify=test_labels, 
    random_state=42,
)

# %% [markdown]
# Stratified sampling gives the following counts:

# %%
Counter(train_labels)
# Out:
# Counter({0: 5044, 1: 9509, 2: 1103, 3: 840})

# %% [markdown]
# The training set has class imbalance is compensated, with class weights inversely proportional to class support.

# %%
#get class_weights
class_weights = class_weight.compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(train_labels),
                                        y = train_labels                                                    
                                    )
class_weights = dict(zip(np.unique(train_labels), class_weights))
class_weights
# Out:
# {0: 0.8176050753370341,
#  1: 0.43369439478388894,
#  2: 3.7388939256572984,
#  3: 4.90952380952381}

# %% [markdown]
# ### Converting to numeric arrays

# %% [markdown]
# For our categorical target, we will use one-hot vectors that will be fed into a soft-max Keras layer during training.

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(train_labels)
val_targets = target_encoding.transform(val_labels)
test_targets = target_encoding.transform(test_labels)

# %% [markdown]
# ## Creating the DirectedGraphSAGE model in Keras

# %% [markdown]
# To feed data from the graph to the Keras model we need a generator. The generators are specialized to the model and the learning task so we choose the `DirectedGraphSAGENodeGenerator` as we are predicting node attributes with a GraphSAGE model.
#
# We need specify the `batch_size` to use for training and the number of nodes to sample at each level of the model. Here we choose a two-layer model with 10 in-nodes sampled in the first layer, and 4 in-nodes in the second layer.

# %%
batch_size = 50
in_samples = [1, 1]
out_samples = [10, 4]

generator = DirectedGraphSAGENodeGenerator(graph_citation_train, batch_size, in_samples, out_samples)

# %% [markdown]
# Using the `generator.flow()` method, we can create iterators over nodes that should be used to train, validate, or evaluate the model. For training we use only the training nodes returned from our splitter and the target values. The `shuffle=True` argument is given to the `flow` method to improve training.

# %%
train_gen = generator.flow(train_labels.index, train_targets, shuffle=True)
val_gen = generator.flow(val_labels.index, val_targets, shuffle=True)
test_gen = generator.flow(test_labels.index, test_targets)

# %% [markdown]
# Now we can specify our machine learning model, and use 2 layers of 32 neurons each of them. And a dropout of 0.1 to help the model to generalize.

# %%
graphsage_model = DirectedGraphSAGE(
    layer_sizes=[32, 32], generator=generator, bias=True, dropout=0.1 #, activations=["relu"] or  activation=keras.layers.LeakyReLU(alpha=0.01)
)

# %% [markdown]
# Now we create a model to predict the 4 categories using Keras softmax layers.

# %%
x_inp, x_out = graphsage_model.in_out_tensors()
prediction = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)

# %%
prediction.shape
# Out:
# TensorShape([None, 4])

# %% [markdown]
# ### Training the model

# %% [markdown]
# Now let's create the actual Keras model with the graph inputs `x_inp` provided by the `graph_model` and outputs being the predictions from the softmax layer

# %%
model = Model(inputs=x_inp, outputs=prediction)
model.compile(
    optimizer = optimizers.Adam(learning_rate=1e-04),
    loss = losses.categorical_crossentropy, #weighted_categorical_crossentropy(weights)
    metrics = [
        metrics.AUC(),
        metrics.CategoricalAccuracy(),
    ] #= ['accuracy'],
)

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 1, 5)]       0           []
#
#  input_3 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_4 (InputLayer)           [(None, 1, 5)]       0           []
#
#  input_5 (InputLayer)           [(None, 4, 5)]       0           []
#
#  input_6 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_7 (InputLayer)           [(None, 40, 5)]      0           []
#
#  input_1 (InputLayer)           [(None, 1, 5)]       0           []
#
#  reshape (Reshape)              (None, 1, 1, 5)      0           ['input_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 10, 5)     0           ['input_3[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 1, 5)      0           ['input_4[0][0]']
#
#  reshape_3 (Reshape)            (None, 1, 4, 5)      0           ['input_5[0][0]']
#
#  reshape_4 (Reshape)            (None, 10, 1, 5)     0           ['input_6[0][0]']
#
#  reshape_5 (Reshape)            (None, 10, 4, 5)     0           ['input_7[0][0]']
#
#  dropout (Dropout)              (None, 1, 5)         0           ['input_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 1, 5)      0           ['reshape[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 10, 5)     0           ['reshape_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 1, 5)         0           ['input_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 1, 1, 5)      0           ['reshape_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 1, 4, 5)      0           ['reshape_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 10, 5)        0           ['input_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 10, 1, 5)     0           ['reshape_4[0][0]']
#
#  dropout_8 (Dropout)            (None, 10, 4, 5)     0           ['reshape_5[0][0]']
#
#  mean_aggregator (MeanAggregato  multiple            192         ['dropout[0][0]',
#  r)                                                               'dropout_1[0][0]',
#                                                                   'dropout_2[0][0]',
#                                                                   'dropout_3[0][0]',
#                                                                   'dropout_4[0][0]',
#                                                                   'dropout_5[0][0]',
#                                                                   'dropout_6[0][0]',
#                                                                   'dropout_7[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  reshape_6 (Reshape)            (None, 1, 1, 32)     0           ['mean_aggregator[1][0]']
#
#  reshape_7 (Reshape)            (None, 1, 10, 32)    0           ['mean_aggregator[2][0]']
#
#  dropout_9 (Dropout)            (None, 1, 32)        0           ['mean_aggregator[0][0]']
#
#  dropout_10 (Dropout)           (None, 1, 1, 32)     0           ['reshape_6[0][0]']
#
#  dropout_11 (Dropout)           (None, 1, 10, 32)    0           ['reshape_7[0][0]']
#
#  mean_aggregator_1 (MeanAggrega  (None, 1, 32)       1056        ['dropout_9[0][0]',
#  tor)                                                             'dropout_10[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  reshape_8 (Reshape)            (None, 32)           0           ['mean_aggregator_1[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['reshape_8[0][0]']
#
#  dense (Dense)                  (None, 4)            132         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1,380
# Trainable params: 1,380
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Train the model, keeping track of its loss and accuracy on the training set, and its generalisation performance on the validation set.

# %%
# create callback
callback = ModelCheckpoint(
    filepath=PATH_MODEL_GS_D_B,
    monitor='val_categorical_accuracy',
    verbose=1, 
    save_best_only=True,
    mode='max'
)
# callback = EarlyStopping(
#     monitor='val_auc', 
#     mode='max', 
#     verbose=1, 
#     patience=20,
# )

#fit the model
history = model.fit(
    train_gen, 
    epochs=100, 
    validation_data=val_gen, 
    class_weight=class_weights,
    verbose=1, 
    shuffle=True,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3684 - auc: 0.3976 - categorical_accuracy: 0.2151
# Epoch 1: val_categorical_accuracy improved from -inf to 0.20604, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 31s 87ms/step - loss: 1.3685 - auc: 0.3978 - categorical_accuracy: 0.2150 - val_loss: 1.3919 - val_auc: 0.4977 - val_categorical_accuracy: 0.2060
# Epoch 2/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3411 - auc: 0.5504 - categorical_accuracy: 0.2626
# Epoch 2: val_categorical_accuracy improved from 0.20604 to 0.22419, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 17s 50ms/step - loss: 1.3410 - auc: 0.5504 - categorical_accuracy: 0.2626 - val_loss: 1.3534 - val_auc: 0.5439 - val_categorical_accuracy: 0.2242
# Epoch 3/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3158 - auc: 0.5972 - categorical_accuracy: 0.3063
# Epoch 3: val_categorical_accuracy improved from 0.22419 to 0.26536, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 47ms/step - loss: 1.3155 - auc: 0.5972 - categorical_accuracy: 0.3063 - val_loss: 1.3264 - val_auc: 0.5549 - val_categorical_accuracy: 0.2654
# Epoch 4/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2934 - auc: 0.6068 - categorical_accuracy: 0.3225
# Epoch 4: val_categorical_accuracy improved from 0.26536 to 0.35951, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2944 - auc: 0.6069 - categorical_accuracy: 0.3228 - val_loss: 1.2973 - val_auc: 0.5921 - val_categorical_accuracy: 0.3595
# Epoch 5/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2764 - auc: 0.6339 - categorical_accuracy: 0.3597
# Epoch 5: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 41ms/step - loss: 1.2767 - auc: 0.6340 - categorical_accuracy: 0.3596 - val_loss: 1.2851 - val_auc: 0.5842 - val_categorical_accuracy: 0.3420
# Epoch 6/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2653 - auc: 0.6332 - categorical_accuracy: 0.3650
# Epoch 6: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2660 - auc: 0.6329 - categorical_accuracy: 0.3649 - val_loss: 1.2765 - val_auc: 0.5969 - val_categorical_accuracy: 0.3475
# Epoch 7/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2570 - auc: 0.6402 - categorical_accuracy: 0.3701
# Epoch 7: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 41ms/step - loss: 1.2567 - auc: 0.6401 - categorical_accuracy: 0.3698 - val_loss: 1.2680 - val_auc: 0.6181 - val_categorical_accuracy: 0.3561
# Epoch 8/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.2495 - auc: 0.6435 - categorical_accuracy: 0.3752
# Epoch 8: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2499 - auc: 0.6434 - categorical_accuracy: 0.3752 - val_loss: 1.2591 - val_auc: 0.6385 - val_categorical_accuracy: 0.3557
# Epoch 9/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2460 - auc: 0.6489 - categorical_accuracy: 0.3772
# Epoch 9: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2460 - auc: 0.6489 - categorical_accuracy: 0.3772 - val_loss: 1.2589 - val_auc: 0.6344 - val_categorical_accuracy: 0.3403
# Epoch 10/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2414 - auc: 0.6566 - categorical_accuracy: 0.3859
# Epoch 10: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2406 - auc: 0.6561 - categorical_accuracy: 0.3855 - val_loss: 1.2540 - val_auc: 0.6507 - val_categorical_accuracy: 0.3447
# Epoch 11/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2365 - auc: 0.6523 - categorical_accuracy: 0.3771
# Epoch 11: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2365 - auc: 0.6523 - categorical_accuracy: 0.3771 - val_loss: 1.2445 - val_auc: 0.6579 - val_categorical_accuracy: 0.3477
# Epoch 12/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2325 - auc: 0.6544 - categorical_accuracy: 0.3791
# Epoch 12: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2329 - auc: 0.6544 - categorical_accuracy: 0.3791 - val_loss: 1.2450 - val_auc: 0.6521 - val_categorical_accuracy: 0.3361
# Epoch 13/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2274 - auc: 0.6613 - categorical_accuracy: 0.3823
# Epoch 13: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2285 - auc: 0.6612 - categorical_accuracy: 0.3822 - val_loss: 1.2406 - val_auc: 0.6545 - val_categorical_accuracy: 0.3392
# Epoch 14/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2275 - auc: 0.6643 - categorical_accuracy: 0.3830
# Epoch 14: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2267 - auc: 0.6643 - categorical_accuracy: 0.3830 - val_loss: 1.2405 - val_auc: 0.6536 - val_categorical_accuracy: 0.3388
# Epoch 15/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2242 - auc: 0.6622 - categorical_accuracy: 0.3786
# Epoch 15: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2235 - auc: 0.6623 - categorical_accuracy: 0.3787 - val_loss: 1.2349 - val_auc: 0.6555 - val_categorical_accuracy: 0.3392
# Epoch 16/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2224 - auc: 0.6656 - categorical_accuracy: 0.3822
# Epoch 16: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2224 - auc: 0.6656 - categorical_accuracy: 0.3822 - val_loss: 1.2369 - val_auc: 0.6558 - val_categorical_accuracy: 0.3395
# Epoch 17/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2185 - auc: 0.6674 - categorical_accuracy: 0.3823
# Epoch 17: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2185 - auc: 0.6674 - categorical_accuracy: 0.3823 - val_loss: 1.2309 - val_auc: 0.6620 - val_categorical_accuracy: 0.3452
# Epoch 18/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.2165 - auc: 0.6780 - categorical_accuracy: 0.3932
# Epoch 18: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2159 - auc: 0.6775 - categorical_accuracy: 0.3928 - val_loss: 1.2316 - val_auc: 0.6545 - val_categorical_accuracy: 0.3352
# Epoch 19/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2138 - auc: 0.6756 - categorical_accuracy: 0.3844
# Epoch 19: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2138 - auc: 0.6756 - categorical_accuracy: 0.3844 - val_loss: 1.2284 - val_auc: 0.6570 - val_categorical_accuracy: 0.3361
# Epoch 20/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2128 - auc: 0.6680 - categorical_accuracy: 0.3781
# Epoch 20: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2130 - auc: 0.6677 - categorical_accuracy: 0.3776 - val_loss: 1.2194 - val_auc: 0.6622 - val_categorical_accuracy: 0.3433
# Epoch 21/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2098 - auc: 0.6753 - categorical_accuracy: 0.3827
# Epoch 21: val_categorical_accuracy did not improve from 0.35951
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2101 - auc: 0.6754 - categorical_accuracy: 0.3828 - val_loss: 1.2201 - val_auc: 0.6610 - val_categorical_accuracy: 0.3399
# Epoch 22/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2114 - auc: 0.6750 - categorical_accuracy: 0.3840
# Epoch 22: val_categorical_accuracy improved from 0.35951 to 0.37091, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2115 - auc: 0.6750 - categorical_accuracy: 0.3839 - val_loss: 1.2213 - val_auc: 0.6601 - val_categorical_accuracy: 0.3709
# Epoch 23/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2067 - auc: 0.6801 - categorical_accuracy: 0.3880
# Epoch 23: val_categorical_accuracy did not improve from 0.37091
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2067 - auc: 0.6801 - categorical_accuracy: 0.3880 - val_loss: 1.2210 - val_auc: 0.6626 - val_categorical_accuracy: 0.3707
# Epoch 24/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2079 - auc: 0.6787 - categorical_accuracy: 0.3891
# Epoch 24: val_categorical_accuracy improved from 0.37091 to 0.37893, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2079 - auc: 0.6787 - categorical_accuracy: 0.3891 - val_loss: 1.2159 - val_auc: 0.6661 - val_categorical_accuracy: 0.3789
# Epoch 25/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2047 - auc: 0.6824 - categorical_accuracy: 0.3918
# Epoch 25: val_categorical_accuracy improved from 0.37893 to 0.38421, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2042 - auc: 0.6824 - categorical_accuracy: 0.3917 - val_loss: 1.2129 - val_auc: 0.6677 - val_categorical_accuracy: 0.3842
# Epoch 26/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2031 - auc: 0.6838 - categorical_accuracy: 0.3961
# Epoch 26: val_categorical_accuracy did not improve from 0.38421
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2024 - auc: 0.6840 - categorical_accuracy: 0.3962 - val_loss: 1.2185 - val_auc: 0.6629 - val_categorical_accuracy: 0.3798
# Epoch 27/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2023 - auc: 0.6820 - categorical_accuracy: 0.3929
# Epoch 27: val_categorical_accuracy did not improve from 0.38421
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2023 - auc: 0.6820 - categorical_accuracy: 0.3929 - val_loss: 1.2179 - val_auc: 0.6639 - val_categorical_accuracy: 0.3777
# Epoch 28/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1994 - auc: 0.6830 - categorical_accuracy: 0.3995
# Epoch 28: val_categorical_accuracy did not improve from 0.38421
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1989 - auc: 0.6828 - categorical_accuracy: 0.3992 - val_loss: 1.2150 - val_auc: 0.6633 - val_categorical_accuracy: 0.3770
# Epoch 29/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.1959 - auc: 0.6841 - categorical_accuracy: 0.3994
# Epoch 29: val_categorical_accuracy improved from 0.38421 to 0.38590, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1971 - auc: 0.6840 - categorical_accuracy: 0.3994 - val_loss: 1.2073 - val_auc: 0.6752 - val_categorical_accuracy: 0.3859
# Epoch 30/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1970 - auc: 0.6877 - categorical_accuracy: 0.4062
# Epoch 30: val_categorical_accuracy improved from 0.38590 to 0.40110, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1970 - auc: 0.6877 - categorical_accuracy: 0.4062 - val_loss: 1.2104 - val_auc: 0.6768 - val_categorical_accuracy: 0.4011
# Epoch 31/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1962 - auc: 0.6887 - categorical_accuracy: 0.4077
# Epoch 31: val_categorical_accuracy did not improve from 0.40110
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1977 - auc: 0.6885 - categorical_accuracy: 0.4074 - val_loss: 1.2123 - val_auc: 0.6762 - val_categorical_accuracy: 0.3956
# Epoch 32/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1935 - auc: 0.6846 - categorical_accuracy: 0.4045
# Epoch 32: val_categorical_accuracy improved from 0.40110 to 0.40849, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1937 - auc: 0.6847 - categorical_accuracy: 0.4046 - val_loss: 1.2024 - val_auc: 0.6841 - val_categorical_accuracy: 0.4085
# Epoch 33/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1935 - auc: 0.6936 - categorical_accuracy: 0.4175
# Epoch 33: val_categorical_accuracy did not improve from 0.40849
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1945 - auc: 0.6934 - categorical_accuracy: 0.4171 - val_loss: 1.2085 - val_auc: 0.6872 - val_categorical_accuracy: 0.4032
# Epoch 34/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1928 - auc: 0.6857 - categorical_accuracy: 0.4122
# Epoch 34: val_categorical_accuracy did not improve from 0.40849
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1930 - auc: 0.6855 - categorical_accuracy: 0.4120 - val_loss: 1.1990 - val_auc: 0.6928 - val_categorical_accuracy: 0.4085
# Epoch 35/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1910 - auc: 0.6941 - categorical_accuracy: 0.4216
# Epoch 35: val_categorical_accuracy improved from 0.40849 to 0.41018, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1917 - auc: 0.6943 - categorical_accuracy: 0.4217 - val_loss: 1.2067 - val_auc: 0.6914 - val_categorical_accuracy: 0.4102
# Epoch 36/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.1879 - auc: 0.6964 - categorical_accuracy: 0.4250
# Epoch 36: val_categorical_accuracy improved from 0.41018 to 0.41376, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1875 - auc: 0.6962 - categorical_accuracy: 0.4250 - val_loss: 1.1989 - val_auc: 0.6961 - val_categorical_accuracy: 0.4138
# Epoch 37/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1920 - auc: 0.6933 - categorical_accuracy: 0.4211
# Epoch 37: val_categorical_accuracy did not improve from 0.41376
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1916 - auc: 0.6932 - categorical_accuracy: 0.4212 - val_loss: 1.2085 - val_auc: 0.6892 - val_categorical_accuracy: 0.4112
# Epoch 38/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1878 - auc: 0.6885 - categorical_accuracy: 0.4193
# Epoch 38: val_categorical_accuracy improved from 0.41376 to 0.41672, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1879 - auc: 0.6883 - categorical_accuracy: 0.4193 - val_loss: 1.1988 - val_auc: 0.6977 - val_categorical_accuracy: 0.4167
# Epoch 39/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1809 - auc: 0.7006 - categorical_accuracy: 0.4269
# Epoch 39: val_categorical_accuracy improved from 0.41672 to 0.42580, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1809 - auc: 0.7006 - categorical_accuracy: 0.4269 - val_loss: 1.1928 - val_auc: 0.7084 - val_categorical_accuracy: 0.4258
# Epoch 40/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1884 - auc: 0.6937 - categorical_accuracy: 0.4276
# Epoch 40: val_categorical_accuracy did not improve from 0.42580
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1888 - auc: 0.6936 - categorical_accuracy: 0.4276 - val_loss: 1.1980 - val_auc: 0.7058 - val_categorical_accuracy: 0.4216
# Epoch 41/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1817 - auc: 0.6985 - categorical_accuracy: 0.4259
# Epoch 41: val_categorical_accuracy did not improve from 0.42580
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1817 - auc: 0.6985 - categorical_accuracy: 0.4259 - val_loss: 1.1921 - val_auc: 0.7071 - val_categorical_accuracy: 0.4152
# Epoch 42/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.1864 - auc: 0.7033 - categorical_accuracy: 0.4390
# Epoch 42: val_categorical_accuracy did not improve from 0.42580
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1846 - auc: 0.7032 - categorical_accuracy: 0.4390 - val_loss: 1.2006 - val_auc: 0.7007 - val_categorical_accuracy: 0.4163
# Epoch 43/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1819 - auc: 0.7025 - categorical_accuracy: 0.4373
# Epoch 43: val_categorical_accuracy did not improve from 0.42580
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1826 - auc: 0.7024 - categorical_accuracy: 0.4373 - val_loss: 1.1975 - val_auc: 0.7048 - val_categorical_accuracy: 0.4243
# Epoch 44/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1783 - auc: 0.7005 - categorical_accuracy: 0.4311
# Epoch 44: val_categorical_accuracy improved from 0.42580 to 0.44839, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1783 - auc: 0.7005 - categorical_accuracy: 0.4311 - val_loss: 1.1811 - val_auc: 0.7176 - val_categorical_accuracy: 0.4484
# Epoch 45/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1812 - auc: 0.7000 - categorical_accuracy: 0.4361
# Epoch 45: val_categorical_accuracy did not improve from 0.44839
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1815 - auc: 0.7000 - categorical_accuracy: 0.4359 - val_loss: 1.1945 - val_auc: 0.7077 - val_categorical_accuracy: 0.4408
# Epoch 46/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1794 - auc: 0.7051 - categorical_accuracy: 0.4367
# Epoch 46: val_categorical_accuracy did not improve from 0.44839
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1794 - auc: 0.7053 - categorical_accuracy: 0.4370 - val_loss: 1.1916 - val_auc: 0.7132 - val_categorical_accuracy: 0.4452
# Epoch 47/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1730 - auc: 0.7072 - categorical_accuracy: 0.4429
# Epoch 47: val_categorical_accuracy improved from 0.44839 to 0.45007, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1737 - auc: 0.7073 - categorical_accuracy: 0.4428 - val_loss: 1.1936 - val_auc: 0.7060 - val_categorical_accuracy: 0.4501
# Epoch 48/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1761 - auc: 0.7039 - categorical_accuracy: 0.4374
# Epoch 48: val_categorical_accuracy did not improve from 0.45007
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1761 - auc: 0.7040 - categorical_accuracy: 0.4373 - val_loss: 1.1874 - val_auc: 0.7122 - val_categorical_accuracy: 0.4456
# Epoch 49/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1744 - auc: 0.7071 - categorical_accuracy: 0.4412
# Epoch 49: val_categorical_accuracy did not improve from 0.45007
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1744 - auc: 0.7071 - categorical_accuracy: 0.4412 - val_loss: 1.1883 - val_auc: 0.7098 - val_categorical_accuracy: 0.4389
# Epoch 50/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1760 - auc: 0.7067 - categorical_accuracy: 0.4445
# Epoch 50: val_categorical_accuracy did not improve from 0.45007
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1757 - auc: 0.7069 - categorical_accuracy: 0.4447 - val_loss: 1.1915 - val_auc: 0.7043 - val_categorical_accuracy: 0.4431
# Epoch 51/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1737 - auc: 0.7018 - categorical_accuracy: 0.4349
# Epoch 51: val_categorical_accuracy did not improve from 0.45007
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1730 - auc: 0.7017 - categorical_accuracy: 0.4349 - val_loss: 1.1817 - val_auc: 0.7125 - val_categorical_accuracy: 0.4380
# Epoch 52/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1714 - auc: 0.7035 - categorical_accuracy: 0.4379
# Epoch 52: val_categorical_accuracy did not improve from 0.45007
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1710 - auc: 0.7036 - categorical_accuracy: 0.4380 - val_loss: 1.1705 - val_auc: 0.7238 - val_categorical_accuracy: 0.4469
# Epoch 53/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1720 - auc: 0.7098 - categorical_accuracy: 0.4419
# Epoch 53: val_categorical_accuracy did not improve from 0.45007
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1721 - auc: 0.7099 - categorical_accuracy: 0.4420 - val_loss: 1.1870 - val_auc: 0.7036 - val_categorical_accuracy: 0.4368
# Epoch 54/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.1688 - auc: 0.7092 - categorical_accuracy: 0.4410
# Epoch 54: val_categorical_accuracy did not improve from 0.45007
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1682 - auc: 0.7093 - categorical_accuracy: 0.4411 - val_loss: 1.1839 - val_auc: 0.7075 - val_categorical_accuracy: 0.4444
# Epoch 55/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.1669 - auc: 0.7109 - categorical_accuracy: 0.4467
# Epoch 55: val_categorical_accuracy did not improve from 0.45007
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1667 - auc: 0.7113 - categorical_accuracy: 0.4470 - val_loss: 1.1823 - val_auc: 0.7102 - val_categorical_accuracy: 0.4431
# Epoch 56/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1734 - auc: 0.7026 - categorical_accuracy: 0.4360
# Epoch 56: val_categorical_accuracy improved from 0.45007 to 0.46358, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1734 - auc: 0.7026 - categorical_accuracy: 0.4360 - val_loss: 1.1700 - val_auc: 0.7201 - val_categorical_accuracy: 0.4636
# Epoch 57/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1702 - auc: 0.7100 - categorical_accuracy: 0.4447
# Epoch 57: val_categorical_accuracy did not improve from 0.46358
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1695 - auc: 0.7100 - categorical_accuracy: 0.4446 - val_loss: 1.1720 - val_auc: 0.7226 - val_categorical_accuracy: 0.4556
# Epoch 58/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1717 - auc: 0.7071 - categorical_accuracy: 0.4427
# Epoch 58: val_categorical_accuracy improved from 0.46358 to 0.48174, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1705 - auc: 0.7073 - categorical_accuracy: 0.4428 - val_loss: 1.1840 - val_auc: 0.7086 - val_categorical_accuracy: 0.4817
# Epoch 59/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1647 - auc: 0.7070 - categorical_accuracy: 0.4416
# Epoch 59: val_categorical_accuracy improved from 0.48174 to 0.50707, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1647 - auc: 0.7070 - categorical_accuracy: 0.4416 - val_loss: 1.1637 - val_auc: 0.7237 - val_categorical_accuracy: 0.5071
# Epoch 60/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1687 - auc: 0.7095 - categorical_accuracy: 0.4487
# Epoch 60: val_categorical_accuracy improved from 0.50707 to 0.50982, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1691 - auc: 0.7092 - categorical_accuracy: 0.4484 - val_loss: 1.1681 - val_auc: 0.7181 - val_categorical_accuracy: 0.5098
# Epoch 61/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1624 - auc: 0.7138 - categorical_accuracy: 0.4566
# Epoch 61: val_categorical_accuracy did not improve from 0.50982
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1628 - auc: 0.7139 - categorical_accuracy: 0.4565 - val_loss: 1.1697 - val_auc: 0.7164 - val_categorical_accuracy: 0.5094
# Epoch 62/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1651 - auc: 0.7056 - categorical_accuracy: 0.4425
# Epoch 62: val_categorical_accuracy improved from 0.50982 to 0.51108, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1651 - auc: 0.7056 - categorical_accuracy: 0.4425 - val_loss: 1.1735 - val_auc: 0.7158 - val_categorical_accuracy: 0.5111
# Epoch 63/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1711 - auc: 0.7070 - categorical_accuracy: 0.4500
# Epoch 63: val_categorical_accuracy did not improve from 0.51108
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1711 - auc: 0.7070 - categorical_accuracy: 0.4500 - val_loss: 1.1752 - val_auc: 0.7149 - val_categorical_accuracy: 0.5085
# Epoch 64/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1635 - auc: 0.7087 - categorical_accuracy: 0.4494
# Epoch 64: val_categorical_accuracy did not improve from 0.51108
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1635 - auc: 0.7087 - categorical_accuracy: 0.4494 - val_loss: 1.1660 - val_auc: 0.7191 - val_categorical_accuracy: 0.5047
# Epoch 65/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1621 - auc: 0.7119 - categorical_accuracy: 0.4545
# Epoch 65: val_categorical_accuracy did not improve from 0.51108
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1619 - auc: 0.7120 - categorical_accuracy: 0.4545 - val_loss: 1.1698 - val_auc: 0.7160 - val_categorical_accuracy: 0.4991
# Epoch 66/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1652 - auc: 0.7087 - categorical_accuracy: 0.4491
# Epoch 66: val_categorical_accuracy did not improve from 0.51108
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1657 - auc: 0.7086 - categorical_accuracy: 0.4489 - val_loss: 1.1996 - val_auc: 0.6982 - val_categorical_accuracy: 0.4775
# Epoch 67/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1593 - auc: 0.7086 - categorical_accuracy: 0.4513
# Epoch 67: val_categorical_accuracy did not improve from 0.51108
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1593 - auc: 0.7086 - categorical_accuracy: 0.4513 - val_loss: 1.1607 - val_auc: 0.7200 - val_categorical_accuracy: 0.5035
# Epoch 68/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1637 - auc: 0.7089 - categorical_accuracy: 0.4537
# Epoch 68: val_categorical_accuracy improved from 0.51108 to 0.51129, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1633 - auc: 0.7088 - categorical_accuracy: 0.4536 - val_loss: 1.1844 - val_auc: 0.7132 - val_categorical_accuracy: 0.5113
# Epoch 69/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1598 - auc: 0.7118 - categorical_accuracy: 0.4562
# Epoch 69: val_categorical_accuracy did not improve from 0.51129
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1594 - auc: 0.7120 - categorical_accuracy: 0.4564 - val_loss: 1.1730 - val_auc: 0.7163 - val_categorical_accuracy: 0.5069
# Epoch 70/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1572 - auc: 0.7094 - categorical_accuracy: 0.4521
# Epoch 70: val_categorical_accuracy did not improve from 0.51129
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1577 - auc: 0.7095 - categorical_accuracy: 0.4525 - val_loss: 1.1763 - val_auc: 0.7143 - val_categorical_accuracy: 0.5024
# Epoch 71/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1596 - auc: 0.7121 - categorical_accuracy: 0.4560
# Epoch 71: val_categorical_accuracy did not improve from 0.51129
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1596 - auc: 0.7121 - categorical_accuracy: 0.4560 - val_loss: 1.1792 - val_auc: 0.7128 - val_categorical_accuracy: 0.5058
# Epoch 72/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1598 - auc: 0.7138 - categorical_accuracy: 0.4587
# Epoch 72: val_categorical_accuracy did not improve from 0.51129
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1585 - auc: 0.7142 - categorical_accuracy: 0.4590 - val_loss: 1.1654 - val_auc: 0.7191 - val_categorical_accuracy: 0.5092
# Epoch 73/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1568 - auc: 0.7120 - categorical_accuracy: 0.4613
# Epoch 73: val_categorical_accuracy improved from 0.51129 to 0.51256, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1573 - auc: 0.7119 - categorical_accuracy: 0.4612 - val_loss: 1.1706 - val_auc: 0.7172 - val_categorical_accuracy: 0.5126
# Epoch 74/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1560 - auc: 0.7137 - categorical_accuracy: 0.4616
# Epoch 74: val_categorical_accuracy improved from 0.51256 to 0.51509, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1561 - auc: 0.7138 - categorical_accuracy: 0.4614 - val_loss: 1.1645 - val_auc: 0.7204 - val_categorical_accuracy: 0.5151
# Epoch 75/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1556 - auc: 0.7167 - categorical_accuracy: 0.4599
# Epoch 75: val_categorical_accuracy did not improve from 0.51509
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1556 - auc: 0.7167 - categorical_accuracy: 0.4599 - val_loss: 1.1898 - val_auc: 0.7118 - val_categorical_accuracy: 0.4858
# Epoch 76/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1573 - auc: 0.7106 - categorical_accuracy: 0.4574
# Epoch 76: val_categorical_accuracy did not improve from 0.51509
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1573 - auc: 0.7106 - categorical_accuracy: 0.4574 - val_loss: 1.1897 - val_auc: 0.7126 - val_categorical_accuracy: 0.4805
# Epoch 77/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1445 - auc: 0.7171 - categorical_accuracy: 0.4632
# Epoch 77: val_categorical_accuracy improved from 0.51509 to 0.51573, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1446 - auc: 0.7171 - categorical_accuracy: 0.4634 - val_loss: 1.1579 - val_auc: 0.7242 - val_categorical_accuracy: 0.5157
# Epoch 78/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1484 - auc: 0.7145 - categorical_accuracy: 0.4594
# Epoch 78: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1484 - auc: 0.7145 - categorical_accuracy: 0.4594 - val_loss: 1.1582 - val_auc: 0.7243 - val_categorical_accuracy: 0.5096
# Epoch 79/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1565 - auc: 0.7143 - categorical_accuracy: 0.4628
# Epoch 79: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 41ms/step - loss: 1.1565 - auc: 0.7143 - categorical_accuracy: 0.4628 - val_loss: 1.1737 - val_auc: 0.7175 - val_categorical_accuracy: 0.5085
# Epoch 80/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1511 - auc: 0.7147 - categorical_accuracy: 0.4612
# Epoch 80: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1513 - auc: 0.7148 - categorical_accuracy: 0.4613 - val_loss: 1.1653 - val_auc: 0.7190 - val_categorical_accuracy: 0.5014
# Epoch 81/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1510 - auc: 0.7164 - categorical_accuracy: 0.4663
# Epoch 81: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1510 - auc: 0.7164 - categorical_accuracy: 0.4663 - val_loss: 1.1670 - val_auc: 0.7194 - val_categorical_accuracy: 0.5077
# Epoch 82/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1514 - auc: 0.7177 - categorical_accuracy: 0.4662
# Epoch 82: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1514 - auc: 0.7177 - categorical_accuracy: 0.4662 - val_loss: 1.1760 - val_auc: 0.7163 - val_categorical_accuracy: 0.5060
# Epoch 83/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.1506 - auc: 0.7187 - categorical_accuracy: 0.4632
# Epoch 83: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1504 - auc: 0.7185 - categorical_accuracy: 0.4633 - val_loss: 1.1853 - val_auc: 0.7142 - val_categorical_accuracy: 0.5064
# Epoch 84/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1531 - auc: 0.7158 - categorical_accuracy: 0.4640
# Epoch 84: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1531 - auc: 0.7158 - categorical_accuracy: 0.4640 - val_loss: 1.1870 - val_auc: 0.7116 - val_categorical_accuracy: 0.4216
# Epoch 85/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1496 - auc: 0.7181 - categorical_accuracy: 0.4644
# Epoch 85: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1490 - auc: 0.7180 - categorical_accuracy: 0.4644 - val_loss: 1.1707 - val_auc: 0.7186 - val_categorical_accuracy: 0.5132
# Epoch 86/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1492 - auc: 0.7206 - categorical_accuracy: 0.4676
# Epoch 86: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1492 - auc: 0.7206 - categorical_accuracy: 0.4676 - val_loss: 1.1818 - val_auc: 0.7127 - val_categorical_accuracy: 0.4252
# Epoch 87/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1431 - auc: 0.7205 - categorical_accuracy: 0.4694
# Epoch 87: val_categorical_accuracy did not improve from 0.51573
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1431 - auc: 0.7205 - categorical_accuracy: 0.4694 - val_loss: 1.1767 - val_auc: 0.7162 - val_categorical_accuracy: 0.5115
# Epoch 88/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1478 - auc: 0.7169 - categorical_accuracy: 0.4584
# Epoch 88: val_categorical_accuracy improved from 0.51573 to 0.51678, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1480 - auc: 0.7168 - categorical_accuracy: 0.4584 - val_loss: 1.1521 - val_auc: 0.7279 - val_categorical_accuracy: 0.5168
# Epoch 89/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1485 - auc: 0.7206 - categorical_accuracy: 0.4667
# Epoch 89: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1490 - auc: 0.7204 - categorical_accuracy: 0.4664 - val_loss: 1.1705 - val_auc: 0.7198 - val_categorical_accuracy: 0.5060
# Epoch 90/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1457 - auc: 0.7210 - categorical_accuracy: 0.4643
# Epoch 90: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1457 - auc: 0.7210 - categorical_accuracy: 0.4643 - val_loss: 1.1621 - val_auc: 0.7234 - val_categorical_accuracy: 0.5126
# Epoch 91/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1530 - auc: 0.7159 - categorical_accuracy: 0.4585
# Epoch 91: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1530 - auc: 0.7159 - categorical_accuracy: 0.4585 - val_loss: 1.1712 - val_auc: 0.7183 - val_categorical_accuracy: 0.5073
# Epoch 92/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1432 - auc: 0.7182 - categorical_accuracy: 0.4598
# Epoch 92: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1439 - auc: 0.7180 - categorical_accuracy: 0.4596 - val_loss: 1.1603 - val_auc: 0.7240 - val_categorical_accuracy: 0.5102
# Epoch 93/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1371 - auc: 0.7214 - categorical_accuracy: 0.4615
# Epoch 93: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1371 - auc: 0.7214 - categorical_accuracy: 0.4615 - val_loss: 1.1430 - val_auc: 0.7320 - val_categorical_accuracy: 0.5043
# Epoch 94/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1482 - auc: 0.7237 - categorical_accuracy: 0.4669
# Epoch 94: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1480 - auc: 0.7240 - categorical_accuracy: 0.4670 - val_loss: 1.1590 - val_auc: 0.7249 - val_categorical_accuracy: 0.5075
# Epoch 95/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.1393 - auc: 0.7218 - categorical_accuracy: 0.4644
# Epoch 95: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1388 - auc: 0.7220 - categorical_accuracy: 0.4650 - val_loss: 1.1598 - val_auc: 0.7230 - val_categorical_accuracy: 0.5098
# Epoch 96/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1415 - auc: 0.7228 - categorical_accuracy: 0.4605
# Epoch 96: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1415 - auc: 0.7228 - categorical_accuracy: 0.4605 - val_loss: 1.1741 - val_auc: 0.7178 - val_categorical_accuracy: 0.4537
# Epoch 97/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1414 - auc: 0.7239 - categorical_accuracy: 0.4688
# Epoch 97: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1406 - auc: 0.7240 - categorical_accuracy: 0.4688 - val_loss: 1.1694 - val_auc: 0.7187 - val_categorical_accuracy: 0.5066
# Epoch 98/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1390 - auc: 0.7212 - categorical_accuracy: 0.4613
# Epoch 98: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1390 - auc: 0.7212 - categorical_accuracy: 0.4613 - val_loss: 1.1442 - val_auc: 0.7302 - val_categorical_accuracy: 0.5066
# Epoch 99/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1387 - auc: 0.7261 - categorical_accuracy: 0.4667
# Epoch 99: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1387 - auc: 0.7261 - categorical_accuracy: 0.4667 - val_loss: 1.1588 - val_auc: 0.7244 - val_categorical_accuracy: 0.5138
# Epoch 100/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1398 - auc: 0.7218 - categorical_accuracy: 0.4637
# Epoch 100: val_categorical_accuracy did not improve from 0.51678
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1398 - auc: 0.7218 - categorical_accuracy: 0.4637 - val_loss: 1.1544 - val_auc: 0.7269 - val_categorical_accuracy: 0.5147

# %%
sg.utils.plot_history(history)

# %% [markdown]
# ### Evaluate the Model

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# Now we have trained the model we can evaluate on the test set.

# %%
# Make prediction
predictions = model.predict(test_gen)
predictions = target_encoding.inverse_transform(predictions)
results = pd.Series(predictions, index=test_labels.index)

test_gen = generator.flow(test_labels.index, test_targets)

# Evaluation Metrics
cm = confusion_matrix(test_labels, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Directed GraphSAGE on Test Set")
print(classification_report(test_labels, results))

# Performance
test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.54      0.66       714
#            1       0.69      0.51      0.59      1345
#            2       0.13      0.11      0.12       156
#            3       0.11      0.71      0.20       119
#
#     accuracy                           0.50      2334
#    macro avg       0.44      0.47      0.39      2334
# weighted avg       0.67      0.50      0.56      2334
#
# 47/47 [==============================] - 2s 33ms/step - loss: 1.1450 - auc: 0.7286 - categorical_accuracy: 0.5090
#
# Test Set Metrics:
# 	loss: 1.1450
# 	auc: 0.7286
# 	categorical_accuracy: 0.5090

# %% [markdown]
# ## Making predictions with the model in papers pubblished in 2002 and *2003*

# %%
#Load and evaluate the best model version
model = load_model(PATH_MODEL_GS_D_B, custom_objects={'MeanAggregator': MeanAggregator})

# %%
# Introduce prediction nodes
generator = DirectedGraphSAGENodeGenerator(graph_citation_full, batch_size, in_samples, out_samples)
prediction_targets = target_encoding.transform(test_nodes)
prediction_gen = generator.flow(test_nodes.index, prediction_targets)

# Make prediction
predictions = model.predict(prediction_gen)
predictions = target_encoding.inverse_transform(predictions)

# Create prediction dataset
results = pd.Series(predictions, index=test_nodes.index)
df_results = pd.DataFrame({"Predicted": results, "True": test_nodes})

# Evaluation Metrics
cm = confusion_matrix(test_nodes, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Directed GraphSAGE on Prediction Set")
print(classification_report(test_nodes, results))

# Performance
prediction_metrics = model.evaluate(prediction_gen)
print("\nPrediction Set Metrics:")
for name, val in zip(model.metrics_names, prediction_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1537
#            1       0.94      0.50      0.66      2209
#            2       0.13      0.09      0.11       233
#            3       0.13      0.80      0.22       204
#
#     accuracy                           0.67      4183
#    macro avg       0.55      0.60      0.49      4183
# weighted avg       0.88      0.67      0.73      4183
#
# 84/84 [==============================] - 3s 32ms/step - loss: 0.8914 - auc: 0.8422 - categorical_accuracy: 0.6722
#
# Prediction Set Metrics:
# 	loss: 0.8914
# 	auc: 0.8422
# 	categorical_accuracy: 0.6722
