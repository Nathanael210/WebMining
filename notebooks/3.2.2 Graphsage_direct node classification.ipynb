# %% [markdown]
# # Inductive node classification and representation learning using GraphSAGE

# %%
# install StellarGraph if running on Google Colab
import sys
if 'google.colab' in sys.modules:
  # %pip install -q stellargraph[demos]==1.2.1
# Out:
#      |████████████████████████████████| 435 kB 7.8 MB/s
#      |████████████████████████████████| 482 kB 59.2 MB/s
#      |████████████████████████████████| 462 kB 64.1 MB/s
#      |████████████████████████████████| 41 kB 667 kB/s
#   Building wheel for mplleaflet (setup.py) ... done

# %%
import networkx as nx
import pandas as pd
import numpy as np
import itertools
import os

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.utils import class_weight

import stellargraph as sg
from stellargraph import StellarGraph, StellarDiGraph
from stellargraph import globalvar
from stellargraph import random as sg_random
from stellargraph.mapper import GraphSAGENodeGenerator, DirectedGraphSAGENodeGenerator
from stellargraph.layer import GraphSAGE, MeanAggregator, DirectedGraphSAGE

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from tensorflow import random as tf_random
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential, load_model
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, f1_score, make_scorer
from sklearn.utils.multiclass import unique_labels
from stellargraph import datasets
from IPython.display import display, HTML
import matplotlib.pyplot as plt

# from google.colab import drive
# drive.mount('/content/drive')

import torch
torch.cuda.is_available()


sg_random.set_seed(42)
tf_random.set_seed(42)
# %matplotlib inline

# %% [markdown]
# ## Paths

# %%
# Parent paths
# google_path = '/content/drive/My Drive/'
# local_path = '/home/v.zevallosm/'
# parent_path = google_path

#Specific paths
# PATH_DATES = parent_path+'WebMining/data/raw/hep-th-slacdates_unzipped.txt'
# PATH_CITATION = parent_path+'WebMining/data/raw/hep-th-citations_unzipped_filtered.txt'
# PATH_LABEL = parent_path+'WebMining/data/processed/papers_label.csv'
# PATH_ATTRIBUTES = parent_path+'WebMining/data/processed/papers_label.csv'

# PATH_MODEL_GS_D_B = parent_path+'WebMining/models/graphsage_directed_base.hdf5'

PATH_DATES = 'hep-th-slacdates_unzipped.txt'
PATH_CITATION = 'hep-th-citations_unzipped_filtered.txt'
PATH_LABEL = 'papers_label.csv'
PATH_ATTRIBUTES = 'papers_label.csv'

PATH_MODEL_GS_D_B = 'graphsage_directed_base.hdf5'

# %% [markdown]
# ## Loading the dataset
#
# https://stellargraph.readthedocs.io/en/stable/demos/basics/loading-pandas.html

# %%
def read_dates(path):
    df = pd.read_csv(path, sep=' ', header=None, names=['id_paper', 'slac_date'])
    df['slac_date'] = pd.to_datetime(df['slac_date'])
    display(df.head(5))
    return (df)

# %%
def read_citation(path, df):
    df = pd.read_csv(path, sep=' ', header=None, names=['source', 'target'])
    display(df.head(5))
    return(df)

# %%
def get_labels(path, df2, label, date):
  df1 = pd.read_csv(path, index_col=0)
  df1.index.name='id_paper'
  df2 = df2.set_index("id_paper")
  df1 = pd.merge(df1, df2, left_index=True, right_index=True)
  label_full = df1[label]
  label_train = df1[df1.slac_date < date][label]
  label_test = df1[df1.slac_date >= date][label]
  print('Full nodes: %s   Train nodes: %s   Test nodes: %s'%(len(label_full), len(label_train), len(label_test)))
  return (label_full, label_train, label_test)

# %%
def get_features(path, df2, date):
  # Papers ids 
  df1 = pd.read_csv(path, index_col=0)
  df1.index.name='id_paper'
  
  # Date df
  df2 = df2.set_index("id_paper")
  
  # Combine datasets
  df1 = pd.merge(df1, df2, left_index=True, right_index=True)

  # Date features
  df1['slac_date'] = pd.to_datetime(df1['slac_date'])
  df1['year']= df1[date].dt.year
  df1['month']= df1[date].dt.month
  df1['week']= df1[date].dt.isocalendar().week
  
  df1['month_sin'] = np.sin((df1.month-1)*(2.*np.pi/12))
  df1['month_cos'] = np.cos((df1.month-1)*(2.*np.pi/12))
  
  df1['week_sin'] = np.sin((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))
  df1['week_cos'] = np.cos((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))
  
  ls = ['year', 'month_sin', 'month_cos', 'week_sin', 'week_cos']
  df_date = df1[ls]
  display(df_date.head(5))
  return(df_date)

# %%
df_dates = read_dates(PATH_DATES)
# Out:
#    id_paper  slac_date
# 0      1001 2000-01-04
# 1      1002 2000-01-04
# 2      1003 2000-01-04
# 3      1004 2000-01-04
# 4      1005 2000-01-04

# %%
df_citation = read_citation(PATH_CITATION, df_dates)
# Out:
#    source   target
# 0    1001  9304045
# 1    1001  9308122
# 2    1001  9309097
# 3    1001  9311042
# 4    1001  9401139

# %%
full_nodes, train_nodes, test_nodes = get_labels(PATH_LABEL, df_dates, 'label', '2002-01-01')
# Out:
# Full nodes: 27750   Train nodes: 23567   Test nodes: 4183

# %%
df_attributes = get_features(PATH_LABEL, df_dates, 'slac_date')
# Out:
#           year  month_sin  month_cos  week_sin  week_cos
# id_paper
# 1001      2000        0.0        1.0       0.0       1.0
# 1002      2000        0.0        1.0       0.0       1.0
# 1003      2000        0.0        1.0       0.0       1.0
# 1004      2000        0.0        1.0       0.0       1.0
# 1005      2000        0.0        1.0       0.0       1.0

# %%
df_attributes.to_csv('dates_sin_cos.csv')

# %% [markdown]
# ## Graph construction

# %%
graph_citation_full = StellarDiGraph({"paper": df_attributes}, {"cites": df_citation})
print(graph_citation_full.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 27750, Edges: 351763
#
#  Node types:
#   paper: [27750]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [351763]
#         Weights: all 1 (default)
#         Features: none

# %%
graph_citation_train = graph_citation_full.subgraph(train_nodes.index)
print(graph_citation_train.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 23567, Edges: 271167
#
#  Node types:
#   paper: [23567]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [271167]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# ### Splitting the data

# %%
train_labels, test_labels = model_selection.train_test_split(
    train_nodes,
    train_size=0.7, #0.05
    test_size=None,
    stratify=train_nodes,
    random_state=42,
)

val_labels, test_labels = model_selection.train_test_split(
    test_labels, 
    train_size=0.67, #0.2
    test_size=None, 
    stratify=test_labels, 
    random_state=42,
)

# %% [markdown]
# Note using stratified sampling gives the following counts:

# %%
from collections import Counter

Counter(train_labels)
# Out:
# Counter({0: 5044, 1: 9509, 2: 1103, 3: 840})

# %% [markdown]
# The training set has class imbalance that might need to be compensated, e.g., via using a weighted cross-entropy loss in model training, with class weights inversely proportional to class support. However, we will ignore the class imbalance in this example, for simplicity.

# %%
#get class_weights
class_weights = class_weight.compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(train_labels),
                                        y = train_labels                                                    
                                    )
class_weights = dict(zip(np.unique(train_labels), class_weights))
class_weights
# Out:
# {0: 0.8176050753370341,
#  1: 0.43369439478388894,
#  2: 3.7388939256572984,
#  3: 4.90952380952381}

# %% [markdown]
# ### Converting to numeric arrays

# %% [markdown]
# For our categorical target, we will use one-hot vectors that will be fed into a soft-max Keras layer during training.

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(train_labels)
val_targets = target_encoding.transform(val_labels)
test_targets = target_encoding.transform(test_labels)

# %% [markdown]
# ## Creating the GraphSAGE model in Keras

# %% [markdown]
# To feed data from the graph to the Keras model we need a generator. The generators are specialized to the model and the learning task so we choose the `GraphSAGENodeGenerator` as we are predicting node attributes with a GraphSAGE model.
#
# We need two other parameters, the `batch_size` to use for training and the number of nodes to sample at each level of the model. Here we choose a two-layer model with 10 nodes sampled in the first layer, and 10 in the second.

# %%
batch_size = 50
in_samples = [5, 2]
out_samples = [5, 2]

# %% [markdown]
# A `GraphSAGENodeGenerator` object is required to send the node features in sampled subgraphs to Keras

# %%
generator = DirectedGraphSAGENodeGenerator(graph_citation_train, batch_size, in_samples, out_samples)

# %% [markdown]
# Using the `generator.flow()` method, we can create iterators over nodes that should be used to train, validate, or evaluate the model. For training we use only the training nodes returned from our splitter and the target values. The `shuffle=True` argument is given to the `flow` method to improve training.

# %%
train_gen = generator.flow(train_labels.index, train_targets, shuffle=True)
val_gen = generator.flow(val_labels.index, val_targets, shuffle=True)
test_gen = generator.flow(test_labels.index, test_targets)

# %% [markdown]
# Now we can specify our machine learning model, we need a few more parameters for this:
#
#  * the `layer_sizes` is a list of hidden feature sizes of each layer in the model. In this example we use 32-dimensional hidden node features at each layer.
#  * The `bias` and `dropout` are internal parameters of the model.

# %%
graphsage_model = DirectedGraphSAGE(
    layer_sizes=[32, 32], generator=generator, bias=True, dropout=0.1 #, activations=["relu"] or  activation=keras.layers.LeakyReLU(alpha=0.01)
)

# %% [markdown]
# Now we create a model to predict the 3 categories using Keras softmax layers. Note that we need to use the `G.get_target_size` method to find the number of categories in the data.

# %%
x_inp, x_out = graphsage_model.in_out_tensors()
prediction = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)

# %%
prediction.shape
# Out:
# TensorShape([None, 4])

# %% [markdown]
# ### Training the model

# %% [markdown]
# Now let's create the actual Keras model with the graph inputs `x_inp` provided by the `graph_model` and outputs being the predictions from the softmax layer

# %%
model = Model(inputs=x_inp, outputs=prediction)
model.compile(
    optimizer = optimizers.Adam(learning_rate=1e-04),
    loss = losses.categorical_crossentropy, #weighted_categorical_crossentropy(weights)
    metrics = [
        metrics.AUC(),
        metrics.CategoricalAccuracy(),
    ] #= ['accuracy'],
)

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5, 5)]       0           []
#
#  input_3 (InputLayer)           [(None, 5, 5)]       0           []
#
#  input_4 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_5 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_6 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_7 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_1 (InputLayer)           [(None, 1, 5)]       0           []
#
#  reshape (Reshape)              (None, 1, 5, 5)      0           ['input_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 5, 5)      0           ['input_3[0][0]']
#
#  reshape_2 (Reshape)            (None, 5, 2, 5)      0           ['input_4[0][0]']
#
#  reshape_3 (Reshape)            (None, 5, 2, 5)      0           ['input_5[0][0]']
#
#  reshape_4 (Reshape)            (None, 5, 2, 5)      0           ['input_6[0][0]']
#
#  reshape_5 (Reshape)            (None, 5, 2, 5)      0           ['input_7[0][0]']
#
#  dropout (Dropout)              (None, 1, 5)         0           ['input_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 5, 5)      0           ['reshape[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 5, 5)      0           ['reshape_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 5, 5)         0           ['input_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 5, 2, 5)      0           ['reshape_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 5, 2, 5)      0           ['reshape_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 5, 5)         0           ['input_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 5, 2, 5)      0           ['reshape_4[0][0]']
#
#  dropout_8 (Dropout)            (None, 5, 2, 5)      0           ['reshape_5[0][0]']
#
#  mean_aggregator (MeanAggregato  multiple            192         ['dropout[0][0]',
#  r)                                                               'dropout_1[0][0]',
#                                                                   'dropout_2[0][0]',
#                                                                   'dropout_3[0][0]',
#                                                                   'dropout_4[0][0]',
#                                                                   'dropout_5[0][0]',
#                                                                   'dropout_6[0][0]',
#                                                                   'dropout_7[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  reshape_6 (Reshape)            (None, 1, 5, 32)     0           ['mean_aggregator[1][0]']
#
#  reshape_7 (Reshape)            (None, 1, 5, 32)     0           ['mean_aggregator[2][0]']
#
#  dropout_9 (Dropout)            (None, 1, 32)        0           ['mean_aggregator[0][0]']
#
#  dropout_10 (Dropout)           (None, 1, 5, 32)     0           ['reshape_6[0][0]']
#
#  dropout_11 (Dropout)           (None, 1, 5, 32)     0           ['reshape_7[0][0]']
#
#  mean_aggregator_1 (MeanAggrega  (None, 1, 32)       1056        ['dropout_9[0][0]',
#  tor)                                                             'dropout_10[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  reshape_8 (Reshape)            (None, 32)           0           ['mean_aggregator_1[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['reshape_8[0][0]']
#
#  dense (Dense)                  (None, 4)            132         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1,380
# Trainable params: 1,380
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Train the model, keeping track of its loss and accuracy on the training set, and its generalisation performance on the validation set (we need to create another generator over the validation data for this)

# %%
# create callback
callback = ModelCheckpoint(
    filepath=PATH_MODEL_GS_D_B,
    monitor='val_categorical_accuracy',
    verbose=1, 
    save_best_only=True,
    mode='max'
)
# callback = EarlyStopping(
#     monitor='val_auc', 
#     mode='max', 
#     verbose=1, 
#     patience=20,
# )

#fit the model
history = model.fit(
    train_gen, 
    epochs=100, 
    validation_data=val_gen, 
    class_weight=class_weights,
    verbose=1, 
    shuffle=True,
    callbacks=[callback]
)
# Out:
# Epoch 1/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3424 - auc: 0.5399 - categorical_accuracy: 0.2424
# Epoch 1: val_categorical_accuracy improved from -inf to 0.21216, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 31s 95ms/step - loss: 1.3424 - auc: 0.5399 - categorical_accuracy: 0.2424 - val_loss: 1.3592 - val_auc: 0.5327 - val_categorical_accuracy: 0.2122
# Epoch 2/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3136 - auc: 0.5805 - categorical_accuracy: 0.2766
# Epoch 2: val_categorical_accuracy improved from 0.21216 to 0.30336, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.3148 - auc: 0.5805 - categorical_accuracy: 0.2769 - val_loss: 1.3177 - val_auc: 0.5792 - val_categorical_accuracy: 0.3034
# Epoch 3/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2933 - auc: 0.6123 - categorical_accuracy: 0.3279
# Epoch 3: val_categorical_accuracy improved from 0.30336 to 0.32362, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 49ms/step - loss: 1.2933 - auc: 0.6123 - categorical_accuracy: 0.3279 - val_loss: 1.2943 - val_auc: 0.5915 - val_categorical_accuracy: 0.3236
# Epoch 4/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2740 - auc: 0.6320 - categorical_accuracy: 0.3517
# Epoch 4: val_categorical_accuracy improved from 0.32362 to 0.35297, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 50ms/step - loss: 1.2740 - auc: 0.6320 - categorical_accuracy: 0.3517 - val_loss: 1.2732 - val_auc: 0.6263 - val_categorical_accuracy: 0.3530
# Epoch 5/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2606 - auc: 0.6398 - categorical_accuracy: 0.3638
# Epoch 5: val_categorical_accuracy improved from 0.35297 to 0.41123, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 18s 53ms/step - loss: 1.2606 - auc: 0.6398 - categorical_accuracy: 0.3638 - val_loss: 1.2548 - val_auc: 0.6783 - val_categorical_accuracy: 0.4112
# Epoch 6/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2509 - auc: 0.6598 - categorical_accuracy: 0.3906
# Epoch 6: val_categorical_accuracy did not improve from 0.41123
# 330/330 [==============================] - 18s 54ms/step - loss: 1.2509 - auc: 0.6598 - categorical_accuracy: 0.3906 - val_loss: 1.2533 - val_auc: 0.6450 - val_categorical_accuracy: 0.3984
# Epoch 7/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2425 - auc: 0.6749 - categorical_accuracy: 0.4136
# Epoch 7: val_categorical_accuracy did not improve from 0.41123
# 330/330 [==============================] - 16s 50ms/step - loss: 1.2433 - auc: 0.6747 - categorical_accuracy: 0.4134 - val_loss: 1.2528 - val_auc: 0.6312 - val_categorical_accuracy: 0.3612
# Epoch 8/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2372 - auc: 0.6627 - categorical_accuracy: 0.3948
# Epoch 8: val_categorical_accuracy did not improve from 0.41123
# 330/330 [==============================] - 16s 49ms/step - loss: 1.2372 - auc: 0.6627 - categorical_accuracy: 0.3948 - val_loss: 1.2415 - val_auc: 0.6528 - val_categorical_accuracy: 0.4081
# Epoch 9/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2328 - auc: 0.6607 - categorical_accuracy: 0.3845
# Epoch 9: val_categorical_accuracy did not improve from 0.41123
# 330/330 [==============================] - 16s 49ms/step - loss: 1.2328 - auc: 0.6603 - categorical_accuracy: 0.3843 - val_loss: 1.2338 - val_auc: 0.6638 - val_categorical_accuracy: 0.4066
# Epoch 10/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2256 - auc: 0.6657 - categorical_accuracy: 0.3909
# Epoch 10: val_categorical_accuracy improved from 0.41123 to 0.42115, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2262 - auc: 0.6657 - categorical_accuracy: 0.3909 - val_loss: 1.2253 - val_auc: 0.6758 - val_categorical_accuracy: 0.4212
# Epoch 11/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2232 - auc: 0.6781 - categorical_accuracy: 0.4099
# Epoch 11: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2232 - auc: 0.6781 - categorical_accuracy: 0.4099 - val_loss: 1.2285 - val_auc: 0.6570 - val_categorical_accuracy: 0.4053
# Epoch 12/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2174 - auc: 0.6745 - categorical_accuracy: 0.4038
# Epoch 12: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2174 - auc: 0.6745 - categorical_accuracy: 0.4038 - val_loss: 1.2260 - val_auc: 0.6601 - val_categorical_accuracy: 0.3946
# Epoch 13/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2133 - auc: 0.6661 - categorical_accuracy: 0.3912
# Epoch 13: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 49ms/step - loss: 1.2133 - auc: 0.6661 - categorical_accuracy: 0.3912 - val_loss: 1.2139 - val_auc: 0.6817 - val_categorical_accuracy: 0.4167
# Epoch 14/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2112 - auc: 0.6872 - categorical_accuracy: 0.4186
# Epoch 14: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 50ms/step - loss: 1.2107 - auc: 0.6872 - categorical_accuracy: 0.4186 - val_loss: 1.2160 - val_auc: 0.6673 - val_categorical_accuracy: 0.3948
# Epoch 15/100
# 330/330 [==============================] - ETA: 0s - loss: 1.2056 - auc: 0.6748 - categorical_accuracy: 0.3983
# Epoch 15: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 49ms/step - loss: 1.2056 - auc: 0.6748 - categorical_accuracy: 0.3983 - val_loss: 1.2088 - val_auc: 0.6749 - val_categorical_accuracy: 0.4019
# Epoch 16/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.2013 - auc: 0.6844 - categorical_accuracy: 0.4139
# Epoch 16: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 49ms/step - loss: 1.2012 - auc: 0.6843 - categorical_accuracy: 0.4140 - val_loss: 1.2057 - val_auc: 0.6733 - val_categorical_accuracy: 0.3984
# Epoch 17/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1996 - auc: 0.6840 - categorical_accuracy: 0.4096
# Epoch 17: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1996 - auc: 0.6840 - categorical_accuracy: 0.4096 - val_loss: 1.2033 - val_auc: 0.6760 - val_categorical_accuracy: 0.4064
# Epoch 18/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1941 - auc: 0.6786 - categorical_accuracy: 0.3999
# Epoch 18: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1938 - auc: 0.6786 - categorical_accuracy: 0.4000 - val_loss: 1.1974 - val_auc: 0.6811 - val_categorical_accuracy: 0.4089
# Epoch 19/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1919 - auc: 0.6874 - categorical_accuracy: 0.4123
# Epoch 19: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1919 - auc: 0.6874 - categorical_accuracy: 0.4123 - val_loss: 1.1988 - val_auc: 0.6779 - val_categorical_accuracy: 0.4064
# Epoch 20/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1921 - auc: 0.6836 - categorical_accuracy: 0.4088
# Epoch 20: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1909 - auc: 0.6835 - categorical_accuracy: 0.4087 - val_loss: 1.2050 - val_auc: 0.6654 - val_categorical_accuracy: 0.3954
# Epoch 21/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1872 - auc: 0.6745 - categorical_accuracy: 0.3952
# Epoch 21: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1872 - auc: 0.6745 - categorical_accuracy: 0.3952 - val_loss: 1.1914 - val_auc: 0.6789 - val_categorical_accuracy: 0.4005
# Epoch 22/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1850 - auc: 0.6805 - categorical_accuracy: 0.3978
# Epoch 22: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1857 - auc: 0.6804 - categorical_accuracy: 0.3981 - val_loss: 1.1889 - val_auc: 0.6846 - val_categorical_accuracy: 0.4028
# Epoch 23/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1806 - auc: 0.6888 - categorical_accuracy: 0.4110
# Epoch 23: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1806 - auc: 0.6888 - categorical_accuracy: 0.4110 - val_loss: 1.1977 - val_auc: 0.6750 - val_categorical_accuracy: 0.3994
# Epoch 24/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1783 - auc: 0.6840 - categorical_accuracy: 0.4047
# Epoch 24: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1780 - auc: 0.6843 - categorical_accuracy: 0.4047 - val_loss: 1.1888 - val_auc: 0.6841 - val_categorical_accuracy: 0.4024
# Epoch 25/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1747 - auc: 0.6871 - categorical_accuracy: 0.4027
# Epoch 25: val_categorical_accuracy did not improve from 0.42115
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1749 - auc: 0.6871 - categorical_accuracy: 0.4028 - val_loss: 1.1879 - val_auc: 0.6830 - val_categorical_accuracy: 0.4072
# Epoch 26/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1722 - auc: 0.6912 - categorical_accuracy: 0.4098
# Epoch 26: val_categorical_accuracy improved from 0.42115 to 0.43234, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1728 - auc: 0.6912 - categorical_accuracy: 0.4101 - val_loss: 1.1807 - val_auc: 0.6898 - val_categorical_accuracy: 0.4323
# Epoch 27/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1720 - auc: 0.6875 - categorical_accuracy: 0.4017
# Epoch 27: val_categorical_accuracy did not improve from 0.43234
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1717 - auc: 0.6877 - categorical_accuracy: 0.4019 - val_loss: 1.1888 - val_auc: 0.6829 - val_categorical_accuracy: 0.4313
# Epoch 28/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1687 - auc: 0.6906 - categorical_accuracy: 0.4084
# Epoch 28: val_categorical_accuracy improved from 0.43234 to 0.43530, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1703 - auc: 0.6907 - categorical_accuracy: 0.4082 - val_loss: 1.1801 - val_auc: 0.6920 - val_categorical_accuracy: 0.4353
# Epoch 29/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1701 - auc: 0.6917 - categorical_accuracy: 0.4129
# Epoch 29: val_categorical_accuracy improved from 0.43530 to 0.43867, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1703 - auc: 0.6916 - categorical_accuracy: 0.4127 - val_loss: 1.1820 - val_auc: 0.6927 - val_categorical_accuracy: 0.4387
# Epoch 30/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1652 - auc: 0.6908 - categorical_accuracy: 0.4050
# Epoch 30: val_categorical_accuracy improved from 0.43867 to 0.43931, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1652 - auc: 0.6908 - categorical_accuracy: 0.4050 - val_loss: 1.1698 - val_auc: 0.7038 - val_categorical_accuracy: 0.4393
# Epoch 31/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1643 - auc: 0.6982 - categorical_accuracy: 0.4225
# Epoch 31: val_categorical_accuracy did not improve from 0.43931
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1643 - auc: 0.6982 - categorical_accuracy: 0.4222 - val_loss: 1.1775 - val_auc: 0.6972 - val_categorical_accuracy: 0.4311
# Epoch 32/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1623 - auc: 0.7005 - categorical_accuracy: 0.4221
# Epoch 32: val_categorical_accuracy did not improve from 0.43931
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1623 - auc: 0.7005 - categorical_accuracy: 0.4221 - val_loss: 1.1777 - val_auc: 0.6976 - val_categorical_accuracy: 0.4385
# Epoch 33/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1589 - auc: 0.6961 - categorical_accuracy: 0.4162
# Epoch 33: val_categorical_accuracy did not improve from 0.43931
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1582 - auc: 0.6964 - categorical_accuracy: 0.4165 - val_loss: 1.1714 - val_auc: 0.7023 - val_categorical_accuracy: 0.4361
# Epoch 34/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1627 - auc: 0.6985 - categorical_accuracy: 0.4171
# Epoch 34: val_categorical_accuracy improved from 0.43931 to 0.43952, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1628 - auc: 0.6984 - categorical_accuracy: 0.4171 - val_loss: 1.1770 - val_auc: 0.7012 - val_categorical_accuracy: 0.4395
# Epoch 35/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1624 - auc: 0.7003 - categorical_accuracy: 0.4212
# Epoch 35: val_categorical_accuracy did not improve from 0.43952
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1624 - auc: 0.7003 - categorical_accuracy: 0.4212 - val_loss: 1.1733 - val_auc: 0.7040 - val_categorical_accuracy: 0.4340
# Epoch 36/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1586 - auc: 0.7003 - categorical_accuracy: 0.4237
# Epoch 36: val_categorical_accuracy improved from 0.43952 to 0.44353, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1592 - auc: 0.7004 - categorical_accuracy: 0.4236 - val_loss: 1.1739 - val_auc: 0.7033 - val_categorical_accuracy: 0.4435
# Epoch 37/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1570 - auc: 0.6961 - categorical_accuracy: 0.4183
# Epoch 37: val_categorical_accuracy improved from 0.44353 to 0.45113, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1570 - auc: 0.6961 - categorical_accuracy: 0.4183 - val_loss: 1.1633 - val_auc: 0.7132 - val_categorical_accuracy: 0.4511
# Epoch 38/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1563 - auc: 0.7049 - categorical_accuracy: 0.4279
# Epoch 38: val_categorical_accuracy did not improve from 0.45113
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1561 - auc: 0.7050 - categorical_accuracy: 0.4277 - val_loss: 1.1718 - val_auc: 0.7059 - val_categorical_accuracy: 0.4416
# Epoch 39/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1540 - auc: 0.7037 - categorical_accuracy: 0.4285
# Epoch 39: val_categorical_accuracy did not improve from 0.45113
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1540 - auc: 0.7037 - categorical_accuracy: 0.4286 - val_loss: 1.1678 - val_auc: 0.7114 - val_categorical_accuracy: 0.4448
# Epoch 40/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1538 - auc: 0.7032 - categorical_accuracy: 0.4285
# Epoch 40: val_categorical_accuracy improved from 0.45113 to 0.45915, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1538 - auc: 0.7032 - categorical_accuracy: 0.4286 - val_loss: 1.1670 - val_auc: 0.7137 - val_categorical_accuracy: 0.4592
# Epoch 41/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1506 - auc: 0.7065 - categorical_accuracy: 0.4311
# Epoch 41: val_categorical_accuracy did not improve from 0.45915
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1506 - auc: 0.7065 - categorical_accuracy: 0.4311 - val_loss: 1.1617 - val_auc: 0.7152 - val_categorical_accuracy: 0.4589
# Epoch 42/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1495 - auc: 0.7115 - categorical_accuracy: 0.4369
# Epoch 42: val_categorical_accuracy improved from 0.45915 to 0.46717, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1495 - auc: 0.7115 - categorical_accuracy: 0.4369 - val_loss: 1.1518 - val_auc: 0.7264 - val_categorical_accuracy: 0.4672
# Epoch 43/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1498 - auc: 0.7093 - categorical_accuracy: 0.4322
# Epoch 43: val_categorical_accuracy improved from 0.46717 to 0.46865, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1498 - auc: 0.7093 - categorical_accuracy: 0.4322 - val_loss: 1.1542 - val_auc: 0.7279 - val_categorical_accuracy: 0.4687
# Epoch 44/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1498 - auc: 0.7095 - categorical_accuracy: 0.4323
# Epoch 44: val_categorical_accuracy did not improve from 0.46865
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1498 - auc: 0.7095 - categorical_accuracy: 0.4323 - val_loss: 1.1670 - val_auc: 0.7156 - val_categorical_accuracy: 0.4530
# Epoch 45/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1490 - auc: 0.7089 - categorical_accuracy: 0.4319
# Epoch 45: val_categorical_accuracy did not improve from 0.46865
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1490 - auc: 0.7089 - categorical_accuracy: 0.4319 - val_loss: 1.1678 - val_auc: 0.7162 - val_categorical_accuracy: 0.4492
# Epoch 46/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1467 - auc: 0.7121 - categorical_accuracy: 0.4371
# Epoch 46: val_categorical_accuracy did not improve from 0.46865
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1462 - auc: 0.7123 - categorical_accuracy: 0.4375 - val_loss: 1.1596 - val_auc: 0.7247 - val_categorical_accuracy: 0.4583
# Epoch 47/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1453 - auc: 0.7131 - categorical_accuracy: 0.4354
# Epoch 47: val_categorical_accuracy did not improve from 0.46865
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1447 - auc: 0.7132 - categorical_accuracy: 0.4357 - val_loss: 1.1683 - val_auc: 0.7206 - val_categorical_accuracy: 0.4640
# Epoch 48/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1445 - auc: 0.7085 - categorical_accuracy: 0.4315
# Epoch 48: val_categorical_accuracy improved from 0.46865 to 0.46992, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1454 - auc: 0.7084 - categorical_accuracy: 0.4316 - val_loss: 1.1444 - val_auc: 0.7349 - val_categorical_accuracy: 0.4699
# Epoch 49/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1451 - auc: 0.7174 - categorical_accuracy: 0.4423
# Epoch 49: val_categorical_accuracy did not improve from 0.46992
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1458 - auc: 0.7173 - categorical_accuracy: 0.4422 - val_loss: 1.1644 - val_auc: 0.7208 - val_categorical_accuracy: 0.4617
# Epoch 50/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1456 - auc: 0.7134 - categorical_accuracy: 0.4355
# Epoch 50: val_categorical_accuracy did not improve from 0.46992
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1456 - auc: 0.7134 - categorical_accuracy: 0.4355 - val_loss: 1.1734 - val_auc: 0.7196 - val_categorical_accuracy: 0.4334
# Epoch 51/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1455 - auc: 0.7141 - categorical_accuracy: 0.4462
# Epoch 51: val_categorical_accuracy did not improve from 0.46992
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1444 - auc: 0.7142 - categorical_accuracy: 0.4466 - val_loss: 1.1733 - val_auc: 0.7186 - val_categorical_accuracy: 0.4304
# Epoch 52/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1423 - auc: 0.7131 - categorical_accuracy: 0.4394
# Epoch 52: val_categorical_accuracy did not improve from 0.46992
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1425 - auc: 0.7132 - categorical_accuracy: 0.4396 - val_loss: 1.1522 - val_auc: 0.7314 - val_categorical_accuracy: 0.4651
# Epoch 53/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1472 - auc: 0.7153 - categorical_accuracy: 0.4387
# Epoch 53: val_categorical_accuracy did not improve from 0.46992
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1472 - auc: 0.7153 - categorical_accuracy: 0.4387 - val_loss: 1.1698 - val_auc: 0.7198 - val_categorical_accuracy: 0.4239
# Epoch 54/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1453 - auc: 0.7128 - categorical_accuracy: 0.4352
# Epoch 54: val_categorical_accuracy improved from 0.46992 to 0.47752, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1453 - auc: 0.7128 - categorical_accuracy: 0.4352 - val_loss: 1.1498 - val_auc: 0.7301 - val_categorical_accuracy: 0.4775
# Epoch 55/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1404 - auc: 0.7201 - categorical_accuracy: 0.4472
# Epoch 55: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1415 - auc: 0.7200 - categorical_accuracy: 0.4469 - val_loss: 1.1773 - val_auc: 0.7174 - val_categorical_accuracy: 0.4247
# Epoch 56/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1421 - auc: 0.7140 - categorical_accuracy: 0.4401
# Epoch 56: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1421 - auc: 0.7140 - categorical_accuracy: 0.4401 - val_loss: 1.1628 - val_auc: 0.7247 - val_categorical_accuracy: 0.4283
# Epoch 57/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1415 - auc: 0.7149 - categorical_accuracy: 0.4404
# Epoch 57: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1414 - auc: 0.7147 - categorical_accuracy: 0.4403 - val_loss: 1.1738 - val_auc: 0.7166 - val_categorical_accuracy: 0.4193
# Epoch 58/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1389 - auc: 0.7199 - categorical_accuracy: 0.4491
# Epoch 58: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1389 - auc: 0.7199 - categorical_accuracy: 0.4491 - val_loss: 1.1680 - val_auc: 0.7226 - val_categorical_accuracy: 0.4222
# Epoch 59/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1362 - auc: 0.7211 - categorical_accuracy: 0.4539
# Epoch 59: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1362 - auc: 0.7211 - categorical_accuracy: 0.4539 - val_loss: 1.1716 - val_auc: 0.7223 - val_categorical_accuracy: 0.4266
# Epoch 60/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1384 - auc: 0.7158 - categorical_accuracy: 0.4419
# Epoch 60: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1384 - auc: 0.7158 - categorical_accuracy: 0.4419 - val_loss: 1.1562 - val_auc: 0.7294 - val_categorical_accuracy: 0.4433
# Epoch 61/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1378 - auc: 0.7164 - categorical_accuracy: 0.4396
# Epoch 61: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1373 - auc: 0.7164 - categorical_accuracy: 0.4396 - val_loss: 1.1568 - val_auc: 0.7320 - val_categorical_accuracy: 0.4501
# Epoch 62/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1403 - auc: 0.7180 - categorical_accuracy: 0.4460
# Epoch 62: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1403 - auc: 0.7180 - categorical_accuracy: 0.4460 - val_loss: 1.1545 - val_auc: 0.7298 - val_categorical_accuracy: 0.4558
# Epoch 63/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1348 - auc: 0.7196 - categorical_accuracy: 0.4480
# Epoch 63: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1348 - auc: 0.7196 - categorical_accuracy: 0.4480 - val_loss: 1.1497 - val_auc: 0.7338 - val_categorical_accuracy: 0.4579
# Epoch 64/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1364 - auc: 0.7223 - categorical_accuracy: 0.4541
# Epoch 64: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1364 - auc: 0.7223 - categorical_accuracy: 0.4541 - val_loss: 1.1650 - val_auc: 0.7275 - val_categorical_accuracy: 0.4452
# Epoch 65/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1300 - auc: 0.7210 - categorical_accuracy: 0.4478
# Epoch 65: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1300 - auc: 0.7210 - categorical_accuracy: 0.4478 - val_loss: 1.1564 - val_auc: 0.7324 - val_categorical_accuracy: 0.4509
# Epoch 66/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1321 - auc: 0.7204 - categorical_accuracy: 0.4512
# Epoch 66: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1321 - auc: 0.7204 - categorical_accuracy: 0.4512 - val_loss: 1.1541 - val_auc: 0.7362 - val_categorical_accuracy: 0.4735
# Epoch 67/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1319 - auc: 0.7219 - categorical_accuracy: 0.4502
# Epoch 67: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1319 - auc: 0.7219 - categorical_accuracy: 0.4502 - val_loss: 1.1568 - val_auc: 0.7362 - val_categorical_accuracy: 0.4758
# Epoch 68/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1364 - auc: 0.7239 - categorical_accuracy: 0.4553
# Epoch 68: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1364 - auc: 0.7239 - categorical_accuracy: 0.4553 - val_loss: 1.1673 - val_auc: 0.7292 - val_categorical_accuracy: 0.4678
# Epoch 69/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1324 - auc: 0.7184 - categorical_accuracy: 0.4464
# Epoch 69: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1324 - auc: 0.7184 - categorical_accuracy: 0.4464 - val_loss: 1.1438 - val_auc: 0.7400 - val_categorical_accuracy: 0.4775
# Epoch 70/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1305 - auc: 0.7245 - categorical_accuracy: 0.4564
# Epoch 70: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1318 - auc: 0.7245 - categorical_accuracy: 0.4563 - val_loss: 1.1755 - val_auc: 0.7262 - val_categorical_accuracy: 0.4545
# Epoch 71/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1309 - auc: 0.7208 - categorical_accuracy: 0.4526
# Epoch 71: val_categorical_accuracy improved from 0.47752 to 0.48280, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1298 - auc: 0.7208 - categorical_accuracy: 0.4526 - val_loss: 1.1468 - val_auc: 0.7409 - val_categorical_accuracy: 0.4828
# Epoch 72/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1308 - auc: 0.7249 - categorical_accuracy: 0.4597
# Epoch 72: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1306 - auc: 0.7247 - categorical_accuracy: 0.4597 - val_loss: 1.1937 - val_auc: 0.7156 - val_categorical_accuracy: 0.4463
# Epoch 73/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1275 - auc: 0.7225 - categorical_accuracy: 0.4548
# Epoch 73: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1275 - auc: 0.7225 - categorical_accuracy: 0.4548 - val_loss: 1.1556 - val_auc: 0.7343 - val_categorical_accuracy: 0.4630
# Epoch 74/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1318 - auc: 0.7212 - categorical_accuracy: 0.4537
# Epoch 74: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1324 - auc: 0.7214 - categorical_accuracy: 0.4539 - val_loss: 1.1482 - val_auc: 0.7378 - val_categorical_accuracy: 0.4735
# Epoch 75/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1276 - auc: 0.7300 - categorical_accuracy: 0.4681
# Epoch 75: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1272 - auc: 0.7300 - categorical_accuracy: 0.4681 - val_loss: 1.1617 - val_auc: 0.7335 - val_categorical_accuracy: 0.4733
# Epoch 76/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1294 - auc: 0.7226 - categorical_accuracy: 0.4560
# Epoch 76: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1294 - auc: 0.7226 - categorical_accuracy: 0.4560 - val_loss: 1.1450 - val_auc: 0.7396 - val_categorical_accuracy: 0.4763
# Epoch 77/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1292 - auc: 0.7249 - categorical_accuracy: 0.4546
# Epoch 77: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1282 - auc: 0.7248 - categorical_accuracy: 0.4546 - val_loss: 1.1598 - val_auc: 0.7307 - val_categorical_accuracy: 0.4670
# Epoch 78/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1239 - auc: 0.7259 - categorical_accuracy: 0.4571
# Epoch 78: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1239 - auc: 0.7259 - categorical_accuracy: 0.4571 - val_loss: 1.1493 - val_auc: 0.7370 - val_categorical_accuracy: 0.4803
# Epoch 79/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1227 - auc: 0.7272 - categorical_accuracy: 0.4633
# Epoch 79: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1229 - auc: 0.7271 - categorical_accuracy: 0.4631 - val_loss: 1.1725 - val_auc: 0.7283 - val_categorical_accuracy: 0.4630
# Epoch 80/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1188 - auc: 0.7273 - categorical_accuracy: 0.4576
# Epoch 80: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1188 - auc: 0.7273 - categorical_accuracy: 0.4576 - val_loss: 1.1698 - val_auc: 0.7296 - val_categorical_accuracy: 0.4687
# Epoch 81/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1257 - auc: 0.7248 - categorical_accuracy: 0.4553
# Epoch 81: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1257 - auc: 0.7248 - categorical_accuracy: 0.4553 - val_loss: 1.1699 - val_auc: 0.7307 - val_categorical_accuracy: 0.4693
# Epoch 82/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1223 - auc: 0.7270 - categorical_accuracy: 0.4607
# Epoch 82: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1223 - auc: 0.7270 - categorical_accuracy: 0.4607 - val_loss: 1.1784 - val_auc: 0.7281 - val_categorical_accuracy: 0.4703
# Epoch 83/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1202 - auc: 0.7265 - categorical_accuracy: 0.4585
# Epoch 83: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1202 - auc: 0.7265 - categorical_accuracy: 0.4585 - val_loss: 1.1557 - val_auc: 0.7365 - val_categorical_accuracy: 0.4676
# Epoch 84/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1172 - auc: 0.7288 - categorical_accuracy: 0.4593
# Epoch 84: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1172 - auc: 0.7288 - categorical_accuracy: 0.4593 - val_loss: 1.1633 - val_auc: 0.7335 - val_categorical_accuracy: 0.4720
# Epoch 85/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1223 - auc: 0.7280 - categorical_accuracy: 0.4599
# Epoch 85: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 16s 50ms/step - loss: 1.1219 - auc: 0.7281 - categorical_accuracy: 0.4603 - val_loss: 1.1786 - val_auc: 0.7235 - val_categorical_accuracy: 0.4655
# Epoch 86/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1148 - auc: 0.7299 - categorical_accuracy: 0.4627
# Epoch 86: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1148 - auc: 0.7299 - categorical_accuracy: 0.4627 - val_loss: 1.1528 - val_auc: 0.7375 - val_categorical_accuracy: 0.4727
# Epoch 87/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1203 - auc: 0.7305 - categorical_accuracy: 0.4616
# Epoch 87: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1203 - auc: 0.7305 - categorical_accuracy: 0.4616 - val_loss: 1.1661 - val_auc: 0.7363 - val_categorical_accuracy: 0.4784
# Epoch 88/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1147 - auc: 0.7283 - categorical_accuracy: 0.4577
# Epoch 88: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1147 - auc: 0.7283 - categorical_accuracy: 0.4577 - val_loss: 1.1510 - val_auc: 0.7396 - val_categorical_accuracy: 0.4680
# Epoch 89/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1193 - auc: 0.7325 - categorical_accuracy: 0.4664
# Epoch 89: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1193 - auc: 0.7325 - categorical_accuracy: 0.4664 - val_loss: 1.1737 - val_auc: 0.7310 - val_categorical_accuracy: 0.4689
# Epoch 90/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1168 - auc: 0.7287 - categorical_accuracy: 0.4622
# Epoch 90: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 16s 49ms/step - loss: 1.1160 - auc: 0.7286 - categorical_accuracy: 0.4620 - val_loss: 1.1827 - val_auc: 0.7278 - val_categorical_accuracy: 0.4737
# Epoch 91/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1081 - auc: 0.7327 - categorical_accuracy: 0.4658
# Epoch 91: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1093 - auc: 0.7325 - categorical_accuracy: 0.4656 - val_loss: 1.1596 - val_auc: 0.7378 - val_categorical_accuracy: 0.4754
# Epoch 92/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1149 - auc: 0.7334 - categorical_accuracy: 0.4658
# Epoch 92: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 44ms/step - loss: 1.1140 - auc: 0.7334 - categorical_accuracy: 0.4657 - val_loss: 1.1497 - val_auc: 0.7396 - val_categorical_accuracy: 0.4701
# Epoch 93/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1151 - auc: 0.7340 - categorical_accuracy: 0.4659
# Epoch 93: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1151 - auc: 0.7340 - categorical_accuracy: 0.4659 - val_loss: 1.1669 - val_auc: 0.7346 - val_categorical_accuracy: 0.4744
# Epoch 94/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1106 - auc: 0.7327 - categorical_accuracy: 0.4620
# Epoch 94: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1105 - auc: 0.7328 - categorical_accuracy: 0.4621 - val_loss: 1.1859 - val_auc: 0.7240 - val_categorical_accuracy: 0.4663
# Epoch 95/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1068 - auc: 0.7324 - categorical_accuracy: 0.4672
# Epoch 95: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1075 - auc: 0.7325 - categorical_accuracy: 0.4672 - val_loss: 1.1456 - val_auc: 0.7388 - val_categorical_accuracy: 0.4784
# Epoch 96/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1039 - auc: 0.7358 - categorical_accuracy: 0.4717
# Epoch 96: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 50ms/step - loss: 1.1039 - auc: 0.7358 - categorical_accuracy: 0.4717 - val_loss: 1.1590 - val_auc: 0.7389 - val_categorical_accuracy: 0.4739
# Epoch 97/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1108 - auc: 0.7336 - categorical_accuracy: 0.4656
# Epoch 97: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1108 - auc: 0.7336 - categorical_accuracy: 0.4656 - val_loss: 1.1863 - val_auc: 0.7259 - val_categorical_accuracy: 0.4680
# Epoch 98/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1079 - auc: 0.7349 - categorical_accuracy: 0.4667
# Epoch 98: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1078 - auc: 0.7348 - categorical_accuracy: 0.4666 - val_loss: 1.1770 - val_auc: 0.7279 - val_categorical_accuracy: 0.4763
# Epoch 99/100
# 330/330 [==============================] - ETA: 0s - loss: 1.1128 - auc: 0.7290 - categorical_accuracy: 0.4657
# Epoch 99: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 17s 51ms/step - loss: 1.1128 - auc: 0.7290 - categorical_accuracy: 0.4657 - val_loss: 1.1753 - val_auc: 0.7270 - val_categorical_accuracy: 0.4659
# Epoch 100/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.1094 - auc: 0.7319 - categorical_accuracy: 0.4596
# Epoch 100: val_categorical_accuracy did not improve from 0.48280
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1092 - auc: 0.7320 - categorical_accuracy: 0.4596 - val_loss: 1.1518 - val_auc: 0.7393 - val_categorical_accuracy: 0.4720

# %%
sg.utils.plot_history(history)

# %% [markdown]
# ### Evaluate the Model

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# Now we have trained the model we can evaluate on the test set.

# %%
# Make prediction
predictions = model.predict(test_gen)
predictions = target_encoding.inverse_transform(predictions)
results = pd.Series(predictions, index=test_labels.index)

test_gen = generator.flow(test_labels.index, test_targets)

# Evaluation Metrics
cm = confusion_matrix(test_labels, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Directed GraphSAGE on Test Set")
print(classification_report(test_labels, results))

# Performance
test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.66       714
#            1       0.70      0.42      0.52      1345
#            2       0.09      0.09      0.09       156
#            3       0.12      0.86      0.21       119
#
#     accuracy                           0.46      2334
#    macro avg       0.43      0.48      0.37      2334
# weighted avg       0.66      0.46      0.52      2334
#
# 47/47 [==============================] - 2s 35ms/step - loss: 1.1442 - auc: 0.7400 - categorical_accuracy: 0.4653
#
# Test Set Metrics:
# 	loss: 1.1442
# 	auc: 0.7400
# 	categorical_accuracy: 0.4653

# %% [markdown]
# ### Making predictions with the model in papers pubblished in 2002 and *2003*

# %%
#Load and evaluate the best model version
model = load_model(PATH_MODEL_GS_D_B, custom_objects={'MeanAggregator': MeanAggregator})

# %%
# Introduce prediction nodes
generator = DirectedGraphSAGENodeGenerator(graph_citation_full, batch_size, in_samples, out_samples)
prediction_targets = target_encoding.transform(test_nodes)
prediction_gen = generator.flow(test_nodes.index, prediction_targets)

# Make prediction
predictions = model.predict(prediction_gen)
predictions = target_encoding.inverse_transform(predictions)

# Create prediction dataset
results = pd.Series(predictions, index=test_nodes.index)
df_results = pd.DataFrame({"Predicted": results, "True": test_nodes})

# Evaluation Metrics
cm = confusion_matrix(test_nodes, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Directed GraphSAGE on Prediction Set")
print(classification_report(test_nodes, results))

# Performance
prediction_metrics = model.evaluate(prediction_gen)
print("\nPrediction Set Metrics:")
for name, val in zip(model.metrics_names, prediction_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      1537
#            1       0.97      0.45      0.61      2209
#            2       0.18      0.47      0.26       233
#            3       0.16      0.75      0.26       204
#
#     accuracy                           0.66      4183
#    macro avg       0.57      0.66      0.53      4183
# weighted avg       0.88      0.66      0.71      4183
#
# 84/84 [==============================] - 3s 31ms/step - loss: 0.8022 - auc: 0.8952 - categorical_accuracy: 0.6500
#
# Prediction Set Metrics:
# 	loss: 0.8022
# 	auc: 0.8952
# 	categorical_accuracy: 0.6500
