# %% [markdown]
# # Inductive node classification and representation learning using GraphSAGE

# %%
# install StellarGraph if running on Google Colab
import sys
if 'google.colab' in sys.modules:
  # %pip install -q stellargraph[demos]==1.2.1

# %%
import networkx as nx
import pandas as pd
import numpy as np
import itertools
import os

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.utils import class_weight

import stellargraph as sg
from stellargraph import StellarGraph, StellarDiGraph
from stellargraph import globalvar
from stellargraph.mapper import GraphSAGENodeGenerator, DirectedGraphSAGENodeGenerator
from stellargraph.layer import GraphSAGE, MeanAggregator, DirectedGraphSAGE

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential, load_model
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, f1_score, make_scorer
from sklearn.utils.multiclass import unique_labels
from stellargraph import datasets
from IPython.display import display, HTML
import matplotlib.pyplot as plt

# from google.colab import drive
# drive.mount('/content/drive')

import torch
torch.cuda.is_available()

# %matplotlib inline

# %% [markdown]
# ## Paths

# %%
# Parent paths
# google_path = '/content/drive/My Drive/'
# local_path = '/home/v.zevallosm/'
# parent_path = google_path

#Specific paths
# PATH_DATES = parent_path+'WebMining/data/raw/hep-th-slacdates_unzipped.txt'
# PATH_CITATION = parent_path+'WebMining/data/raw/hep-th-citations_unzipped_filtered.txt'
# PATH_LABEL = parent_path+'WebMining/data/processed/papers_label.csv'
# PATH_ATTRIBUTES = parent_path+'WebMining/data/processed/papers_label.csv'

# PATH_MODEL_GS_D_B = parent_path+'WebMining/models/graphsage_directed_base.hdf5'

PATH_DATES = 'hep-th-slacdates_unzipped.txt'
PATH_CITATION = 'hep-th-citations_unzipped_filtered.txt'
PATH_LABEL = 'papers_label.csv'
PATH_ATTRIBUTES = 'papers_label.csv'

PATH_MODEL_GS_D_B = 'graphsage_directed_base.hdf5'

# %% [markdown]
# ## Loading the dataset
#
# https://stellargraph.readthedocs.io/en/stable/demos/basics/loading-pandas.html

# %%
def read_dates(path):
    df = pd.read_csv(path, sep=' ', header=None, names=['id_paper', 'slac_date'])
    df['slac_date'] = pd.to_datetime(df['slac_date'])
    display(df.head(5))
    return (df)

# %%
def read_citation(path, df):
    df = pd.read_csv(path, sep=' ', header=None, names=['source', 'target'])
    display(df.head(5))
    return(df)

# %%
def get_labels(path, df2, label, date):
  df1 = pd.read_csv(path, index_col=0)
  df1.index.name='id_paper'
  df2 = df2.set_index("id_paper")
  df1 = pd.merge(df1, df2, left_index=True, right_index=True)
  label_full = df1[label]
  label_train = df1[df1.slac_date < date][label]
  label_test = df1[df1.slac_date >= date][label]
  print('Full nodes: %s   Train nodes: %s   Test nodes: %s'%(len(label_full), len(label_train), len(label_test)))
  return (label_full, label_train, label_test)

# %%
def get_features(path, df2, date):
  # Papers ids 
  df1 = pd.read_csv(path, index_col=0)
  df1.index.name='id_paper'
  
  # Date df
  df2 = df2.set_index("id_paper")
  
  # Combine datasets
  df1 = pd.merge(df1, df2, left_index=True, right_index=True)

  # Date features
  df1['slac_date'] = pd.to_datetime(df1['slac_date'])
  df1['year']= df1[date].dt.year
  df1['month']= df1[date].dt.month
  df1['week']= df1[date].dt.isocalendar().week
  
  df1['month_sin'] = np.sin((df1.month-1)*(2.*np.pi/12))
  df1['month_cos'] = np.cos((df1.month-1)*(2.*np.pi/12))
  
  df1['week_sin'] = np.sin((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))
  df1['week_cos'] = np.cos((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))
  
  ls = ['year', 'month_sin', 'month_cos', 'week_sin', 'week_cos']
  df_date = df1[ls]
  display(df_date.head(5))
  return(df_date)

# %%
df_dates = read_dates(PATH_DATES)
# Out:
#    id_paper  slac_date
# 0      1001 2000-01-04
# 1      1002 2000-01-04
# 2      1003 2000-01-04
# 3      1004 2000-01-04
# 4      1005 2000-01-04

# %%
df_citation = read_citation(PATH_CITATION, df_dates)
# Out:
#    source   target
# 0    1001  9304045
# 1    1001  9308122
# 2    1001  9309097
# 3    1001  9311042
# 4    1001  9401139

# %%
full_nodes, train_nodes, test_nodes = get_labels(PATH_LABEL, df_dates, 'label', '2002-01-01')
# Out:
# Full nodes: 27750   Train nodes: 23567   Test nodes: 4183

# %%
df_attributes = get_features(PATH_LABEL, df_dates, 'slac_date')
# Out:
#           year  month_sin  month_cos  week_sin  week_cos
# id_paper
# 1001      2000        0.0        1.0       0.0       1.0
# 1002      2000        0.0        1.0       0.0       1.0
# 1003      2000        0.0        1.0       0.0       1.0
# 1004      2000        0.0        1.0       0.0       1.0
# 1005      2000        0.0        1.0       0.0       1.0

# %%
df_attributes.to_csv('dates_sin_cos.csv')

# %% [markdown]
# ## Graph construction

# %%
graph_citation_full = StellarDiGraph({"paper": df_attributes}, {"cites": df_citation})
print(graph_citation_full.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 27750, Edges: 351763
#
#  Node types:
#   paper: [27750]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [351763]
#         Weights: all 1 (default)
#         Features: none

# %%
graph_citation_train = graph_citation_full.subgraph(train_nodes.index)
print(graph_citation_train.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 23567, Edges: 271167
#
#  Node types:
#   paper: [23567]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [271167]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# ### Splitting the data

# %%
train_labels, test_labels = model_selection.train_test_split(
    train_nodes,
    train_size=0.7, #0.05
    test_size=None,
    stratify=train_nodes,
    random_state=42,
)

val_labels, test_labels = model_selection.train_test_split(
    test_labels, 
    train_size=0.67, #0.2
    test_size=None, 
    stratify=test_labels, 
    random_state=42,
)

# %% [markdown]
# Note using stratified sampling gives the following counts:

# %%
from collections import Counter

Counter(train_labels)
# Out:
# Counter({0: 5044, 1: 9509, 2: 1103, 3: 840})

# %% [markdown]
# The training set has class imbalance that might need to be compensated, e.g., via using a weighted cross-entropy loss in model training, with class weights inversely proportional to class support. However, we will ignore the class imbalance in this example, for simplicity.

# %%
#get class_weights
class_weights = class_weight.compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(train_labels),
                                        y = train_labels                                                    
                                    )
class_weights = dict(zip(np.unique(train_labels), class_weights))
class_weights
# Out:
# {0: 0.8176050753370341,
#  1: 0.43369439478388894,
#  2: 3.7388939256572984,
#  3: 4.90952380952381}

# %% [markdown]
# ### Converting to numeric arrays

# %% [markdown]
# For our categorical target, we will use one-hot vectors that will be fed into a soft-max Keras layer during training.

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(train_labels)
val_targets = target_encoding.transform(val_labels)
test_targets = target_encoding.transform(test_labels)

# %% [markdown]
# ## Creating the GraphSAGE model in Keras

# %% [markdown]
# To feed data from the graph to the Keras model we need a generator. The generators are specialized to the model and the learning task so we choose the `GraphSAGENodeGenerator` as we are predicting node attributes with a GraphSAGE model.
#
# We need two other parameters, the `batch_size` to use for training and the number of nodes to sample at each level of the model. Here we choose a two-layer model with 10 nodes sampled in the first layer, and 10 in the second.

# %%
batch_size = 50
in_samples = [5, 2]
out_samples = [5, 2]

# %% [markdown]
# A `GraphSAGENodeGenerator` object is required to send the node features in sampled subgraphs to Keras

# %%
generator = DirectedGraphSAGENodeGenerator(graph_citation_train, batch_size, in_samples, out_samples)

# %% [markdown]
# Using the `generator.flow()` method, we can create iterators over nodes that should be used to train, validate, or evaluate the model. For training we use only the training nodes returned from our splitter and the target values. The `shuffle=True` argument is given to the `flow` method to improve training.

# %%
train_gen = generator.flow(train_labels.index, train_targets, shuffle=True)
val_gen = generator.flow(val_labels.index, val_targets, shuffle=True)
test_gen = generator.flow(test_labels.index, test_targets)

# %% [markdown]
# Now we can specify our machine learning model, we need a few more parameters for this:
#
#  * the `layer_sizes` is a list of hidden feature sizes of each layer in the model. In this example we use 32-dimensional hidden node features at each layer.
#  * The `bias` and `dropout` are internal parameters of the model.

# %%
graphsage_model = DirectedGraphSAGE(
    layer_sizes=[32, 32], generator=generator, bias=True, dropout=0.1 #, activations=["relu"] or  activation=keras.layers.LeakyReLU(alpha=0.01)
)

# %% [markdown]
# Now we create a model to predict the 3 categories using Keras softmax layers. Note that we need to use the `G.get_target_size` method to find the number of categories in the data.

# %%
x_inp, x_out = graphsage_model.in_out_tensors()
prediction = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)

# %%
prediction.shape
# Out:
# TensorShape([None, 4])

# %% [markdown]
# ### Training the model

# %% [markdown]
# Now let's create the actual Keras model with the graph inputs `x_inp` provided by the `graph_model` and outputs being the predictions from the softmax layer

# %%
model = Model(inputs=x_inp, outputs=prediction)
model.compile(
    optimizer = optimizers.Adam(learning_rate=1e-04),
    loss = losses.categorical_crossentropy, #weighted_categorical_crossentropy(weights)
    metrics = [
        metrics.AUC(),
        metrics.CategoricalAccuracy(),
    ] #= ['accuracy'],
)

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5, 5)]       0           []
#
#  input_3 (InputLayer)           [(None, 5, 5)]       0           []
#
#  input_4 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_5 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_6 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_7 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_1 (InputLayer)           [(None, 1, 5)]       0           []
#
#  reshape (Reshape)              (None, 1, 5, 5)      0           ['input_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 5, 5)      0           ['input_3[0][0]']
#
#  reshape_2 (Reshape)            (None, 5, 2, 5)      0           ['input_4[0][0]']
#
#  reshape_3 (Reshape)            (None, 5, 2, 5)      0           ['input_5[0][0]']
#
#  reshape_4 (Reshape)            (None, 5, 2, 5)      0           ['input_6[0][0]']
#
#  reshape_5 (Reshape)            (None, 5, 2, 5)      0           ['input_7[0][0]']
#
#  dropout (Dropout)              (None, 1, 5)         0           ['input_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 5, 5)      0           ['reshape[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 5, 5)      0           ['reshape_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 5, 5)         0           ['input_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 5, 2, 5)      0           ['reshape_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 5, 2, 5)      0           ['reshape_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 5, 5)         0           ['input_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 5, 2, 5)      0           ['reshape_4[0][0]']
#
#  dropout_8 (Dropout)            (None, 5, 2, 5)      0           ['reshape_5[0][0]']
#
#  mean_aggregator (MeanAggregato  multiple            192         ['dropout[0][0]',
#  r)                                                               'dropout_1[0][0]',
#                                                                   'dropout_2[0][0]',
#                                                                   'dropout_3[0][0]',
#                                                                   'dropout_4[0][0]',
#                                                                   'dropout_5[0][0]',
#                                                                   'dropout_6[0][0]',
#                                                                   'dropout_7[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  reshape_6 (Reshape)            (None, 1, 5, 32)     0           ['mean_aggregator[1][0]']
#
#  reshape_7 (Reshape)            (None, 1, 5, 32)     0           ['mean_aggregator[2][0]']
#
#  dropout_9 (Dropout)            (None, 1, 32)        0           ['mean_aggregator[0][0]']
#
#  dropout_10 (Dropout)           (None, 1, 5, 32)     0           ['reshape_6[0][0]']
#
#  dropout_11 (Dropout)           (None, 1, 5, 32)     0           ['reshape_7[0][0]']
#
#  mean_aggregator_1 (MeanAggrega  (None, 1, 32)       1056        ['dropout_9[0][0]',
#  tor)                                                             'dropout_10[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  reshape_8 (Reshape)            (None, 32)           0           ['mean_aggregator_1[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['reshape_8[0][0]']
#
#  dense (Dense)                  (None, 4)            132         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1,380
# Trainable params: 1,380
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Train the model, keeping track of its loss and accuracy on the training set, and its generalisation performance on the validation set (we need to create another generator over the validation data for this)

# %%
# create callback
callback = ModelCheckpoint(
    filepath=PATH_MODEL_GS_D_B,
    monitor='val_categorical_accuracy',
    verbose=1, 
    save_best_only=True,
    mode='max'
)
# callback = EarlyStopping(
#     monitor='val_auc', 
#     mode='max', 
#     verbose=1, 
#     patience=20,
# )

#fit the model
history = model.fit(
    train_gen, 
    epochs=120, 
    validation_data=val_gen, 
    class_weight=class_weights,
    verbose=1, 
    shuffle=True,
    callbacks=[callback]
)
# Out:
# Epoch 1/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.3699 - auc: 0.5085 - categorical_accuracy: 0.1946
# Epoch 1: val_categorical_accuracy improved from -inf to 0.20519, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 28s 75ms/step - loss: 1.3685 - auc: 0.5089 - categorical_accuracy: 0.1947 - val_loss: 1.3403 - val_auc: 0.6128 - val_categorical_accuracy: 0.2052
# Epoch 2/120
# 330/330 [==============================] - ETA: 0s - loss: 1.3284 - auc: 0.6367 - categorical_accuracy: 0.3069
# Epoch 2: val_categorical_accuracy improved from 0.20519 to 0.26240, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 15s 45ms/step - loss: 1.3284 - auc: 0.6367 - categorical_accuracy: 0.3069 - val_loss: 1.2894 - val_auc: 0.6647 - val_categorical_accuracy: 0.2624
# Epoch 3/120
# 330/330 [==============================] - ETA: 0s - loss: 1.2940 - auc: 0.6949 - categorical_accuracy: 0.4073
# Epoch 3: val_categorical_accuracy improved from 0.26240 to 0.33988, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2940 - auc: 0.6949 - categorical_accuracy: 0.4073 - val_loss: 1.2587 - val_auc: 0.6834 - val_categorical_accuracy: 0.3399
# Epoch 4/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.2713 - auc: 0.6885 - categorical_accuracy: 0.3800
# Epoch 4: val_categorical_accuracy did not improve from 0.33988
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2720 - auc: 0.6885 - categorical_accuracy: 0.3800 - val_loss: 1.2494 - val_auc: 0.6857 - val_categorical_accuracy: 0.3154
# Epoch 5/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.2601 - auc: 0.6877 - categorical_accuracy: 0.3954
# Epoch 5: val_categorical_accuracy improved from 0.33988 to 0.37830, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2596 - auc: 0.6877 - categorical_accuracy: 0.3955 - val_loss: 1.2426 - val_auc: 0.7092 - val_categorical_accuracy: 0.3783
# Epoch 6/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.2461 - auc: 0.6896 - categorical_accuracy: 0.4208
# Epoch 6: val_categorical_accuracy did not improve from 0.37830
# 330/330 [==============================] - 15s 44ms/step - loss: 1.2474 - auc: 0.6893 - categorical_accuracy: 0.4203 - val_loss: 1.2500 - val_auc: 0.6474 - val_categorical_accuracy: 0.3177
# Epoch 7/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.2405 - auc: 0.6641 - categorical_accuracy: 0.3840
# Epoch 7: val_categorical_accuracy improved from 0.37830 to 0.39793, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2401 - auc: 0.6644 - categorical_accuracy: 0.3843 - val_loss: 1.2369 - val_auc: 0.6706 - val_categorical_accuracy: 0.3979
# Epoch 8/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.2322 - auc: 0.6590 - categorical_accuracy: 0.3850
# Epoch 8: val_categorical_accuracy did not improve from 0.39793
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2318 - auc: 0.6593 - categorical_accuracy: 0.3855 - val_loss: 1.2298 - val_auc: 0.6773 - val_categorical_accuracy: 0.3922
# Epoch 9/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.2297 - auc: 0.6785 - categorical_accuracy: 0.4111
# Epoch 9: val_categorical_accuracy did not improve from 0.39793
# 330/330 [==============================] - 14s 41ms/step - loss: 1.2280 - auc: 0.6787 - categorical_accuracy: 0.4115 - val_loss: 1.2326 - val_auc: 0.6583 - val_categorical_accuracy: 0.3846
# Epoch 10/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.2223 - auc: 0.6706 - categorical_accuracy: 0.3980
# Epoch 10: val_categorical_accuracy did not improve from 0.39793
# 330/330 [==============================] - 14s 43ms/step - loss: 1.2231 - auc: 0.6706 - categorical_accuracy: 0.3983 - val_loss: 1.2297 - val_auc: 0.6548 - val_categorical_accuracy: 0.3838
# Epoch 11/120
# 330/330 [==============================] - ETA: 0s - loss: 1.2183 - auc: 0.6744 - categorical_accuracy: 0.4089
# Epoch 11: val_categorical_accuracy did not improve from 0.39793
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2183 - auc: 0.6744 - categorical_accuracy: 0.4089 - val_loss: 1.2331 - val_auc: 0.6460 - val_categorical_accuracy: 0.3861
# Epoch 12/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.2115 - auc: 0.6723 - categorical_accuracy: 0.4027
# Epoch 12: val_categorical_accuracy did not improve from 0.39793
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2114 - auc: 0.6724 - categorical_accuracy: 0.4029 - val_loss: 1.2261 - val_auc: 0.6558 - val_categorical_accuracy: 0.3973
# Epoch 13/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.2066 - auc: 0.6692 - categorical_accuracy: 0.3964
# Epoch 13: val_categorical_accuracy improved from 0.39793 to 0.40279, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2085 - auc: 0.6691 - categorical_accuracy: 0.3963 - val_loss: 1.2153 - val_auc: 0.6662 - val_categorical_accuracy: 0.4028
# Epoch 14/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.2041 - auc: 0.6726 - categorical_accuracy: 0.4020
# Epoch 14: val_categorical_accuracy improved from 0.40279 to 0.40722, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.2036 - auc: 0.6726 - categorical_accuracy: 0.4020 - val_loss: 1.2129 - val_auc: 0.6685 - val_categorical_accuracy: 0.4072
# Epoch 15/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1997 - auc: 0.6771 - categorical_accuracy: 0.4078
# Epoch 15: val_categorical_accuracy did not improve from 0.40722
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1996 - auc: 0.6773 - categorical_accuracy: 0.4081 - val_loss: 1.2098 - val_auc: 0.6729 - val_categorical_accuracy: 0.3992
# Epoch 16/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1954 - auc: 0.6820 - categorical_accuracy: 0.4110
# Epoch 16: val_categorical_accuracy did not improve from 0.40722
# 330/330 [==============================] - 14s 41ms/step - loss: 1.1958 - auc: 0.6816 - categorical_accuracy: 0.4106 - val_loss: 1.2180 - val_auc: 0.6623 - val_categorical_accuracy: 0.4026
# Epoch 17/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1940 - auc: 0.6683 - categorical_accuracy: 0.3943
# Epoch 17: val_categorical_accuracy improved from 0.40722 to 0.40743, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1940 - auc: 0.6683 - categorical_accuracy: 0.3943 - val_loss: 1.1993 - val_auc: 0.6824 - val_categorical_accuracy: 0.4074
# Epoch 18/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1881 - auc: 0.6801 - categorical_accuracy: 0.4063
# Epoch 18: val_categorical_accuracy did not improve from 0.40743
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1881 - auc: 0.6801 - categorical_accuracy: 0.4063 - val_loss: 1.2054 - val_auc: 0.6752 - val_categorical_accuracy: 0.3988
# Epoch 19/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1844 - auc: 0.6793 - categorical_accuracy: 0.4008
# Epoch 19: val_categorical_accuracy improved from 0.40743 to 0.43171, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1844 - auc: 0.6793 - categorical_accuracy: 0.4008 - val_loss: 1.1937 - val_auc: 0.6882 - val_categorical_accuracy: 0.4317
# Epoch 20/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1842 - auc: 0.6809 - categorical_accuracy: 0.4075
# Epoch 20: val_categorical_accuracy improved from 0.43171 to 0.43361, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1842 - auc: 0.6809 - categorical_accuracy: 0.4075 - val_loss: 1.1899 - val_auc: 0.6927 - val_categorical_accuracy: 0.4336
# Epoch 21/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1791 - auc: 0.6849 - categorical_accuracy: 0.4113
# Epoch 21: val_categorical_accuracy did not improve from 0.43361
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1791 - auc: 0.6849 - categorical_accuracy: 0.4113 - val_loss: 1.1887 - val_auc: 0.6931 - val_categorical_accuracy: 0.4277
# Epoch 22/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1768 - auc: 0.6905 - categorical_accuracy: 0.4162
# Epoch 22: val_categorical_accuracy improved from 0.43361 to 0.43593, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1763 - auc: 0.6904 - categorical_accuracy: 0.4160 - val_loss: 1.2014 - val_auc: 0.6821 - val_categorical_accuracy: 0.4359
# Epoch 23/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1713 - auc: 0.6856 - categorical_accuracy: 0.4094
# Epoch 23: val_categorical_accuracy did not improve from 0.43593
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1713 - auc: 0.6856 - categorical_accuracy: 0.4094 - val_loss: 1.1868 - val_auc: 0.6965 - val_categorical_accuracy: 0.4342
# Epoch 24/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1706 - auc: 0.6928 - categorical_accuracy: 0.4225
# Epoch 24: val_categorical_accuracy did not improve from 0.43593
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1706 - auc: 0.6928 - categorical_accuracy: 0.4225 - val_loss: 1.1957 - val_auc: 0.6860 - val_categorical_accuracy: 0.4260
# Epoch 25/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1653 - auc: 0.6905 - categorical_accuracy: 0.4118
# Epoch 25: val_categorical_accuracy improved from 0.43593 to 0.43910, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1653 - auc: 0.6905 - categorical_accuracy: 0.4118 - val_loss: 1.1957 - val_auc: 0.6884 - val_categorical_accuracy: 0.4391
# Epoch 26/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1664 - auc: 0.6931 - categorical_accuracy: 0.4227
# Epoch 26: val_categorical_accuracy improved from 0.43910 to 0.44269, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1658 - auc: 0.6934 - categorical_accuracy: 0.4230 - val_loss: 1.1874 - val_auc: 0.6961 - val_categorical_accuracy: 0.4427
# Epoch 27/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1598 - auc: 0.7008 - categorical_accuracy: 0.4263
# Epoch 27: val_categorical_accuracy improved from 0.44269 to 0.45282, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1598 - auc: 0.7008 - categorical_accuracy: 0.4263 - val_loss: 1.1841 - val_auc: 0.7012 - val_categorical_accuracy: 0.4528
# Epoch 28/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1599 - auc: 0.6971 - categorical_accuracy: 0.4219
# Epoch 28: val_categorical_accuracy did not improve from 0.45282
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1597 - auc: 0.6972 - categorical_accuracy: 0.4222 - val_loss: 1.1762 - val_auc: 0.7075 - val_categorical_accuracy: 0.4518
# Epoch 29/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1550 - auc: 0.6976 - categorical_accuracy: 0.4225
# Epoch 29: val_categorical_accuracy improved from 0.45282 to 0.47055, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1550 - auc: 0.6976 - categorical_accuracy: 0.4225 - val_loss: 1.1616 - val_auc: 0.7244 - val_categorical_accuracy: 0.4706
# Epoch 30/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1575 - auc: 0.7033 - categorical_accuracy: 0.4304
# Epoch 30: val_categorical_accuracy did not improve from 0.47055
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1575 - auc: 0.7033 - categorical_accuracy: 0.4304 - val_loss: 1.1867 - val_auc: 0.7052 - val_categorical_accuracy: 0.4575
# Epoch 31/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1608 - auc: 0.6984 - categorical_accuracy: 0.4264
# Epoch 31: val_categorical_accuracy did not improve from 0.47055
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1608 - auc: 0.6984 - categorical_accuracy: 0.4264 - val_loss: 1.1722 - val_auc: 0.7136 - val_categorical_accuracy: 0.4543
# Epoch 32/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1540 - auc: 0.7060 - categorical_accuracy: 0.4357
# Epoch 32: val_categorical_accuracy did not improve from 0.47055
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1540 - auc: 0.7060 - categorical_accuracy: 0.4357 - val_loss: 1.1689 - val_auc: 0.7159 - val_categorical_accuracy: 0.4581
# Epoch 33/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1527 - auc: 0.7064 - categorical_accuracy: 0.4363
# Epoch 33: val_categorical_accuracy did not improve from 0.47055
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1527 - auc: 0.7064 - categorical_accuracy: 0.4363 - val_loss: 1.1882 - val_auc: 0.7043 - val_categorical_accuracy: 0.4148
# Epoch 34/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1570 - auc: 0.7009 - categorical_accuracy: 0.4320
# Epoch 34: val_categorical_accuracy did not improve from 0.47055
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1565 - auc: 0.7014 - categorical_accuracy: 0.4325 - val_loss: 1.1794 - val_auc: 0.7101 - val_categorical_accuracy: 0.4520
# Epoch 35/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1484 - auc: 0.7036 - categorical_accuracy: 0.4300
# Epoch 35: val_categorical_accuracy did not improve from 0.47055
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1486 - auc: 0.7037 - categorical_accuracy: 0.4300 - val_loss: 1.1614 - val_auc: 0.7223 - val_categorical_accuracy: 0.4693
# Epoch 36/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1519 - auc: 0.7056 - categorical_accuracy: 0.4293
# Epoch 36: val_categorical_accuracy did not improve from 0.47055
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1519 - auc: 0.7056 - categorical_accuracy: 0.4293 - val_loss: 1.1798 - val_auc: 0.7101 - val_categorical_accuracy: 0.4184
# Epoch 37/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1475 - auc: 0.7073 - categorical_accuracy: 0.4338
# Epoch 37: val_categorical_accuracy did not improve from 0.47055
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1475 - auc: 0.7073 - categorical_accuracy: 0.4338 - val_loss: 1.1645 - val_auc: 0.7224 - val_categorical_accuracy: 0.4676
# Epoch 38/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.1475 - auc: 0.7130 - categorical_accuracy: 0.4454
# Epoch 38: val_categorical_accuracy improved from 0.47055 to 0.47351, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1473 - auc: 0.7133 - categorical_accuracy: 0.4456 - val_loss: 1.1530 - val_auc: 0.7297 - val_categorical_accuracy: 0.4735
# Epoch 39/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1412 - auc: 0.7113 - categorical_accuracy: 0.4368
# Epoch 39: val_categorical_accuracy did not improve from 0.47351
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1412 - auc: 0.7113 - categorical_accuracy: 0.4368 - val_loss: 1.1588 - val_auc: 0.7274 - val_categorical_accuracy: 0.4674
# Epoch 40/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1440 - auc: 0.7112 - categorical_accuracy: 0.4457
# Epoch 40: val_categorical_accuracy improved from 0.47351 to 0.50644, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1440 - auc: 0.7112 - categorical_accuracy: 0.4457 - val_loss: 1.1482 - val_auc: 0.7356 - val_categorical_accuracy: 0.5064
# Epoch 41/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.1475 - auc: 0.7170 - categorical_accuracy: 0.4528
# Epoch 41: val_categorical_accuracy did not improve from 0.50644
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1468 - auc: 0.7170 - categorical_accuracy: 0.4525 - val_loss: 1.1659 - val_auc: 0.7241 - val_categorical_accuracy: 0.4596
# Epoch 42/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1452 - auc: 0.7110 - categorical_accuracy: 0.4410
# Epoch 42: val_categorical_accuracy did not improve from 0.50644
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1453 - auc: 0.7110 - categorical_accuracy: 0.4411 - val_loss: 1.1620 - val_auc: 0.7302 - val_categorical_accuracy: 0.4767
# Epoch 43/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1392 - auc: 0.7118 - categorical_accuracy: 0.4470
# Epoch 43: val_categorical_accuracy did not improve from 0.50644
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1392 - auc: 0.7118 - categorical_accuracy: 0.4470 - val_loss: 1.1449 - val_auc: 0.7350 - val_categorical_accuracy: 0.5054
# Epoch 44/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1401 - auc: 0.7145 - categorical_accuracy: 0.4423
# Epoch 44: val_categorical_accuracy did not improve from 0.50644
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1401 - auc: 0.7145 - categorical_accuracy: 0.4423 - val_loss: 1.1729 - val_auc: 0.7246 - val_categorical_accuracy: 0.4516
# Epoch 45/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1411 - auc: 0.7121 - categorical_accuracy: 0.4442
# Epoch 45: val_categorical_accuracy improved from 0.50644 to 0.51045, saving model to graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1411 - auc: 0.7121 - categorical_accuracy: 0.4442 - val_loss: 1.1532 - val_auc: 0.7354 - val_categorical_accuracy: 0.5104
# Epoch 46/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.1393 - auc: 0.7159 - categorical_accuracy: 0.4522
# Epoch 46: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1392 - auc: 0.7159 - categorical_accuracy: 0.4523 - val_loss: 1.1655 - val_auc: 0.7313 - val_categorical_accuracy: 0.4687
# Epoch 47/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.1420 - auc: 0.7145 - categorical_accuracy: 0.4468
# Epoch 47: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1408 - auc: 0.7141 - categorical_accuracy: 0.4465 - val_loss: 1.1668 - val_auc: 0.7279 - val_categorical_accuracy: 0.4699
# Epoch 48/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1406 - auc: 0.7136 - categorical_accuracy: 0.4435
# Epoch 48: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1413 - auc: 0.7136 - categorical_accuracy: 0.4437 - val_loss: 1.1824 - val_auc: 0.7203 - val_categorical_accuracy: 0.4488
# Epoch 49/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1361 - auc: 0.7110 - categorical_accuracy: 0.4402
# Epoch 49: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1361 - auc: 0.7110 - categorical_accuracy: 0.4402 - val_loss: 1.1432 - val_auc: 0.7401 - val_categorical_accuracy: 0.4868
# Epoch 50/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1417 - auc: 0.7145 - categorical_accuracy: 0.4468
# Epoch 50: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1416 - auc: 0.7144 - categorical_accuracy: 0.4467 - val_loss: 1.1954 - val_auc: 0.7158 - val_categorical_accuracy: 0.4516
# Epoch 51/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1341 - auc: 0.7189 - categorical_accuracy: 0.4510
# Epoch 51: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1336 - auc: 0.7192 - categorical_accuracy: 0.4513 - val_loss: 1.1893 - val_auc: 0.7191 - val_categorical_accuracy: 0.4511
# Epoch 52/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1331 - auc: 0.7137 - categorical_accuracy: 0.4433
# Epoch 52: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1331 - auc: 0.7137 - categorical_accuracy: 0.4433 - val_loss: 1.1579 - val_auc: 0.7326 - val_categorical_accuracy: 0.4699
# Epoch 53/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1296 - auc: 0.7217 - categorical_accuracy: 0.4593
# Epoch 53: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1296 - auc: 0.7217 - categorical_accuracy: 0.4593 - val_loss: 1.1511 - val_auc: 0.7356 - val_categorical_accuracy: 0.4756
# Epoch 54/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1354 - auc: 0.7213 - categorical_accuracy: 0.4604
# Epoch 54: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1355 - auc: 0.7213 - categorical_accuracy: 0.4605 - val_loss: 1.1800 - val_auc: 0.7244 - val_categorical_accuracy: 0.4651
# Epoch 55/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1355 - auc: 0.7154 - categorical_accuracy: 0.4495
# Epoch 55: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1355 - auc: 0.7154 - categorical_accuracy: 0.4495 - val_loss: 1.1831 - val_auc: 0.7246 - val_categorical_accuracy: 0.4699
# Epoch 56/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.1315 - auc: 0.7189 - categorical_accuracy: 0.4542
# Epoch 56: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1310 - auc: 0.7187 - categorical_accuracy: 0.4537 - val_loss: 1.1491 - val_auc: 0.7396 - val_categorical_accuracy: 0.4830
# Epoch 57/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1360 - auc: 0.7194 - categorical_accuracy: 0.4568
# Epoch 57: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1362 - auc: 0.7195 - categorical_accuracy: 0.4570 - val_loss: 1.1651 - val_auc: 0.7309 - val_categorical_accuracy: 0.4684
# Epoch 58/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1306 - auc: 0.7202 - categorical_accuracy: 0.4570
# Epoch 58: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1306 - auc: 0.7202 - categorical_accuracy: 0.4570 - val_loss: 1.1747 - val_auc: 0.7268 - val_categorical_accuracy: 0.4731
# Epoch 59/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1275 - auc: 0.7197 - categorical_accuracy: 0.4559
# Epoch 59: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1275 - auc: 0.7197 - categorical_accuracy: 0.4559 - val_loss: 1.1580 - val_auc: 0.7342 - val_categorical_accuracy: 0.4741
# Epoch 60/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1304 - auc: 0.7220 - categorical_accuracy: 0.4548
# Epoch 60: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1298 - auc: 0.7221 - categorical_accuracy: 0.4548 - val_loss: 1.1858 - val_auc: 0.7226 - val_categorical_accuracy: 0.4760
# Epoch 61/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1259 - auc: 0.7170 - categorical_accuracy: 0.4491
# Epoch 61: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1259 - auc: 0.7170 - categorical_accuracy: 0.4491 - val_loss: 1.1605 - val_auc: 0.7341 - val_categorical_accuracy: 0.4714
# Epoch 62/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1265 - auc: 0.7247 - categorical_accuracy: 0.4606
# Epoch 62: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 41ms/step - loss: 1.1265 - auc: 0.7247 - categorical_accuracy: 0.4606 - val_loss: 1.1598 - val_auc: 0.7335 - val_categorical_accuracy: 0.4672
# Epoch 63/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1283 - auc: 0.7230 - categorical_accuracy: 0.4548
# Epoch 63: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1278 - auc: 0.7230 - categorical_accuracy: 0.4548 - val_loss: 1.1616 - val_auc: 0.7329 - val_categorical_accuracy: 0.4741
# Epoch 64/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1276 - auc: 0.7234 - categorical_accuracy: 0.4556
# Epoch 64: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1277 - auc: 0.7234 - categorical_accuracy: 0.4554 - val_loss: 1.1969 - val_auc: 0.7167 - val_categorical_accuracy: 0.4606
# Epoch 65/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1251 - auc: 0.7218 - categorical_accuracy: 0.4540
# Epoch 65: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1251 - auc: 0.7218 - categorical_accuracy: 0.4540 - val_loss: 1.1704 - val_auc: 0.7310 - val_categorical_accuracy: 0.4822
# Epoch 66/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1237 - auc: 0.7206 - categorical_accuracy: 0.4523
# Epoch 66: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1237 - auc: 0.7206 - categorical_accuracy: 0.4523 - val_loss: 1.1797 - val_auc: 0.7254 - val_categorical_accuracy: 0.4691
# Epoch 67/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1226 - auc: 0.7245 - categorical_accuracy: 0.4605
# Epoch 67: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1222 - auc: 0.7246 - categorical_accuracy: 0.4607 - val_loss: 1.1780 - val_auc: 0.7253 - val_categorical_accuracy: 0.4678
# Epoch 68/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1157 - auc: 0.7237 - categorical_accuracy: 0.4525
# Epoch 68: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1157 - auc: 0.7237 - categorical_accuracy: 0.4525 - val_loss: 1.1398 - val_auc: 0.7441 - val_categorical_accuracy: 0.4872
# Epoch 69/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1190 - auc: 0.7272 - categorical_accuracy: 0.4588
# Epoch 69: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1197 - auc: 0.7272 - categorical_accuracy: 0.4586 - val_loss: 1.1636 - val_auc: 0.7368 - val_categorical_accuracy: 0.4708
# Epoch 70/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1166 - auc: 0.7306 - categorical_accuracy: 0.4637
# Epoch 70: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1165 - auc: 0.7305 - categorical_accuracy: 0.4636 - val_loss: 1.1868 - val_auc: 0.7208 - val_categorical_accuracy: 0.4634
# Epoch 71/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1189 - auc: 0.7250 - categorical_accuracy: 0.4547
# Epoch 71: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1192 - auc: 0.7250 - categorical_accuracy: 0.4548 - val_loss: 1.1946 - val_auc: 0.7203 - val_categorical_accuracy: 0.4680
# Epoch 72/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1205 - auc: 0.7227 - categorical_accuracy: 0.4528
# Epoch 72: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1202 - auc: 0.7226 - categorical_accuracy: 0.4524 - val_loss: 1.1687 - val_auc: 0.7307 - val_categorical_accuracy: 0.4689
# Epoch 73/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1174 - auc: 0.7316 - categorical_accuracy: 0.4642
# Epoch 73: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1173 - auc: 0.7313 - categorical_accuracy: 0.4637 - val_loss: 1.1987 - val_auc: 0.7179 - val_categorical_accuracy: 0.4511
# Epoch 74/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1183 - auc: 0.7255 - categorical_accuracy: 0.4602
# Epoch 74: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1182 - auc: 0.7257 - categorical_accuracy: 0.4604 - val_loss: 1.1764 - val_auc: 0.7277 - val_categorical_accuracy: 0.4720
# Epoch 75/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1149 - auc: 0.7278 - categorical_accuracy: 0.4616
# Epoch 75: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1149 - auc: 0.7278 - categorical_accuracy: 0.4616 - val_loss: 1.1888 - val_auc: 0.7230 - val_categorical_accuracy: 0.4720
# Epoch 76/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1165 - auc: 0.7276 - categorical_accuracy: 0.4618
# Epoch 76: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1165 - auc: 0.7276 - categorical_accuracy: 0.4618 - val_loss: 1.1728 - val_auc: 0.7295 - val_categorical_accuracy: 0.4748
# Epoch 77/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1090 - auc: 0.7330 - categorical_accuracy: 0.4662
# Epoch 77: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1090 - auc: 0.7330 - categorical_accuracy: 0.4662 - val_loss: 1.1932 - val_auc: 0.7212 - val_categorical_accuracy: 0.4756
# Epoch 78/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1133 - auc: 0.7289 - categorical_accuracy: 0.4572
# Epoch 78: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1140 - auc: 0.7291 - categorical_accuracy: 0.4577 - val_loss: 1.1795 - val_auc: 0.7261 - val_categorical_accuracy: 0.4725
# Epoch 79/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1083 - auc: 0.7293 - categorical_accuracy: 0.4583
# Epoch 79: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1072 - auc: 0.7294 - categorical_accuracy: 0.4584 - val_loss: 1.1703 - val_auc: 0.7299 - val_categorical_accuracy: 0.4712
# Epoch 80/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1098 - auc: 0.7332 - categorical_accuracy: 0.4573
# Epoch 80: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1103 - auc: 0.7332 - categorical_accuracy: 0.4573 - val_loss: 1.1837 - val_auc: 0.7242 - val_categorical_accuracy: 0.4693
# Epoch 81/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.1132 - auc: 0.7280 - categorical_accuracy: 0.4588
# Epoch 81: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1124 - auc: 0.7282 - categorical_accuracy: 0.4590 - val_loss: 1.1723 - val_auc: 0.7318 - val_categorical_accuracy: 0.4693
# Epoch 82/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1079 - auc: 0.7315 - categorical_accuracy: 0.4628
# Epoch 82: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1079 - auc: 0.7315 - categorical_accuracy: 0.4628 - val_loss: 1.1616 - val_auc: 0.7362 - val_categorical_accuracy: 0.4670
# Epoch 83/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1110 - auc: 0.7342 - categorical_accuracy: 0.4629
# Epoch 83: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1110 - auc: 0.7342 - categorical_accuracy: 0.4629 - val_loss: 1.2045 - val_auc: 0.7151 - val_categorical_accuracy: 0.4513
# Epoch 84/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1087 - auc: 0.7318 - categorical_accuracy: 0.4624
# Epoch 84: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1095 - auc: 0.7318 - categorical_accuracy: 0.4624 - val_loss: 1.2013 - val_auc: 0.7176 - val_categorical_accuracy: 0.4682
# Epoch 85/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1118 - auc: 0.7303 - categorical_accuracy: 0.4633
# Epoch 85: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1105 - auc: 0.7306 - categorical_accuracy: 0.4636 - val_loss: 1.1819 - val_auc: 0.7260 - val_categorical_accuracy: 0.4640
# Epoch 86/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1134 - auc: 0.7319 - categorical_accuracy: 0.4591
# Epoch 86: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1132 - auc: 0.7319 - categorical_accuracy: 0.4594 - val_loss: 1.2039 - val_auc: 0.7157 - val_categorical_accuracy: 0.4516
# Epoch 87/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1115 - auc: 0.7279 - categorical_accuracy: 0.4565
# Epoch 87: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1104 - auc: 0.7278 - categorical_accuracy: 0.4566 - val_loss: 1.1667 - val_auc: 0.7340 - val_categorical_accuracy: 0.4767
# Epoch 88/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1098 - auc: 0.7303 - categorical_accuracy: 0.4594
# Epoch 88: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1098 - auc: 0.7305 - categorical_accuracy: 0.4594 - val_loss: 1.1801 - val_auc: 0.7278 - val_categorical_accuracy: 0.4750
# Epoch 89/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1040 - auc: 0.7369 - categorical_accuracy: 0.4690
# Epoch 89: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1040 - auc: 0.7369 - categorical_accuracy: 0.4690 - val_loss: 1.1896 - val_auc: 0.7204 - val_categorical_accuracy: 0.4697
# Epoch 90/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1055 - auc: 0.7326 - categorical_accuracy: 0.4580
# Epoch 90: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1055 - auc: 0.7326 - categorical_accuracy: 0.4580 - val_loss: 1.1796 - val_auc: 0.7285 - val_categorical_accuracy: 0.4695
# Epoch 91/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1075 - auc: 0.7352 - categorical_accuracy: 0.4671
# Epoch 91: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1082 - auc: 0.7350 - categorical_accuracy: 0.4669 - val_loss: 1.1675 - val_auc: 0.7325 - val_categorical_accuracy: 0.4676
# Epoch 92/120
# 330/330 [==============================] - ETA: 0s - loss: 1.1098 - auc: 0.7344 - categorical_accuracy: 0.4608
# Epoch 92: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1098 - auc: 0.7344 - categorical_accuracy: 0.4608 - val_loss: 1.1929 - val_auc: 0.7193 - val_categorical_accuracy: 0.4486
# Epoch 93/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1027 - auc: 0.7313 - categorical_accuracy: 0.4582
# Epoch 93: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1030 - auc: 0.7314 - categorical_accuracy: 0.4584 - val_loss: 1.1772 - val_auc: 0.7291 - val_categorical_accuracy: 0.4727
# Epoch 94/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1005 - auc: 0.7362 - categorical_accuracy: 0.4652
# Epoch 94: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1004 - auc: 0.7361 - categorical_accuracy: 0.4649 - val_loss: 1.1957 - val_auc: 0.7181 - val_categorical_accuracy: 0.4699
# Epoch 95/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1041 - auc: 0.7352 - categorical_accuracy: 0.4618
# Epoch 95: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1032 - auc: 0.7354 - categorical_accuracy: 0.4621 - val_loss: 1.1860 - val_auc: 0.7252 - val_categorical_accuracy: 0.4663
# Epoch 96/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1015 - auc: 0.7360 - categorical_accuracy: 0.4569
# Epoch 96: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1015 - auc: 0.7362 - categorical_accuracy: 0.4570 - val_loss: 1.1859 - val_auc: 0.7230 - val_categorical_accuracy: 0.4750
# Epoch 97/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1018 - auc: 0.7361 - categorical_accuracy: 0.4697
# Epoch 97: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.1009 - auc: 0.7364 - categorical_accuracy: 0.4699 - val_loss: 1.1779 - val_auc: 0.7278 - val_categorical_accuracy: 0.4693
# Epoch 98/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.1009 - auc: 0.7373 - categorical_accuracy: 0.4616
# Epoch 98: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1004 - auc: 0.7372 - categorical_accuracy: 0.4616 - val_loss: 1.1899 - val_auc: 0.7226 - val_categorical_accuracy: 0.4744
# Epoch 99/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0985 - auc: 0.7362 - categorical_accuracy: 0.4583
# Epoch 99: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0987 - auc: 0.7365 - categorical_accuracy: 0.4585 - val_loss: 1.1903 - val_auc: 0.7204 - val_categorical_accuracy: 0.4665
# Epoch 100/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0966 - auc: 0.7377 - categorical_accuracy: 0.4607
# Epoch 100: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0974 - auc: 0.7377 - categorical_accuracy: 0.4607 - val_loss: 1.1882 - val_auc: 0.7235 - val_categorical_accuracy: 0.4585
# Epoch 101/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.1028 - auc: 0.7299 - categorical_accuracy: 0.4528
# Epoch 101: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.1030 - auc: 0.7299 - categorical_accuracy: 0.4527 - val_loss: 1.1793 - val_auc: 0.7274 - val_categorical_accuracy: 0.4710
# Epoch 102/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.0942 - auc: 0.7397 - categorical_accuracy: 0.4622
# Epoch 102: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0945 - auc: 0.7400 - categorical_accuracy: 0.4627 - val_loss: 1.1668 - val_auc: 0.7333 - val_categorical_accuracy: 0.4701
# Epoch 103/120
# 330/330 [==============================] - ETA: 0s - loss: 1.0951 - auc: 0.7404 - categorical_accuracy: 0.4673
# Epoch 103: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0951 - auc: 0.7404 - categorical_accuracy: 0.4673 - val_loss: 1.1857 - val_auc: 0.7241 - val_categorical_accuracy: 0.4680
# Epoch 104/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0986 - auc: 0.7381 - categorical_accuracy: 0.4646
# Epoch 104: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0977 - auc: 0.7382 - categorical_accuracy: 0.4645 - val_loss: 1.1763 - val_auc: 0.7304 - val_categorical_accuracy: 0.4663
# Epoch 105/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0911 - auc: 0.7406 - categorical_accuracy: 0.4604
# Epoch 105: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0910 - auc: 0.7407 - categorical_accuracy: 0.4605 - val_loss: 1.1786 - val_auc: 0.7274 - val_categorical_accuracy: 0.4744
# Epoch 106/120
# 330/330 [==============================] - ETA: 0s - loss: 1.0963 - auc: 0.7385 - categorical_accuracy: 0.4601
# Epoch 106: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0963 - auc: 0.7385 - categorical_accuracy: 0.4601 - val_loss: 1.1821 - val_auc: 0.7283 - val_categorical_accuracy: 0.4708
# Epoch 107/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0917 - auc: 0.7427 - categorical_accuracy: 0.4649
# Epoch 107: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0936 - auc: 0.7427 - categorical_accuracy: 0.4648 - val_loss: 1.1909 - val_auc: 0.7231 - val_categorical_accuracy: 0.4642
# Epoch 108/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0981 - auc: 0.7362 - categorical_accuracy: 0.4537
# Epoch 108: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0984 - auc: 0.7362 - categorical_accuracy: 0.4535 - val_loss: 1.1654 - val_auc: 0.7355 - val_categorical_accuracy: 0.4712
# Epoch 109/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.0942 - auc: 0.7420 - categorical_accuracy: 0.4638
# Epoch 109: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0940 - auc: 0.7420 - categorical_accuracy: 0.4639 - val_loss: 1.1647 - val_auc: 0.7356 - val_categorical_accuracy: 0.4748
# Epoch 110/120
# 330/330 [==============================] - ETA: 0s - loss: 1.0934 - auc: 0.7417 - categorical_accuracy: 0.4631
# Epoch 110: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0934 - auc: 0.7417 - categorical_accuracy: 0.4631 - val_loss: 1.1832 - val_auc: 0.7282 - val_categorical_accuracy: 0.4583
# Epoch 111/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0935 - auc: 0.7436 - categorical_accuracy: 0.4657
# Epoch 111: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 42ms/step - loss: 1.0932 - auc: 0.7438 - categorical_accuracy: 0.4659 - val_loss: 1.2033 - val_auc: 0.7154 - val_categorical_accuracy: 0.4509
# Epoch 112/120
# 330/330 [==============================] - ETA: 0s - loss: 1.0997 - auc: 0.7369 - categorical_accuracy: 0.4593
# Epoch 112: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0997 - auc: 0.7369 - categorical_accuracy: 0.4593 - val_loss: 1.1813 - val_auc: 0.7261 - val_categorical_accuracy: 0.4649
# Epoch 113/120
# 328/330 [============================>.] - ETA: 0s - loss: 1.0933 - auc: 0.7396 - categorical_accuracy: 0.4608
# Epoch 113: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0924 - auc: 0.7395 - categorical_accuracy: 0.4604 - val_loss: 1.1771 - val_auc: 0.7300 - val_categorical_accuracy: 0.4672
# Epoch 114/120
# 330/330 [==============================] - ETA: 0s - loss: 1.0883 - auc: 0.7469 - categorical_accuracy: 0.4694
# Epoch 114: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0883 - auc: 0.7469 - categorical_accuracy: 0.4694 - val_loss: 1.2087 - val_auc: 0.7142 - val_categorical_accuracy: 0.4456
# Epoch 115/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0865 - auc: 0.7442 - categorical_accuracy: 0.4671
# Epoch 115: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0877 - auc: 0.7438 - categorical_accuracy: 0.4667 - val_loss: 1.1832 - val_auc: 0.7268 - val_categorical_accuracy: 0.4646
# Epoch 116/120
# 330/330 [==============================] - ETA: 0s - loss: 1.0923 - auc: 0.7410 - categorical_accuracy: 0.4565
# Epoch 116: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0923 - auc: 0.7410 - categorical_accuracy: 0.4565 - val_loss: 1.1802 - val_auc: 0.7277 - val_categorical_accuracy: 0.4716
# Epoch 117/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0869 - auc: 0.7473 - categorical_accuracy: 0.4670
# Epoch 117: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0872 - auc: 0.7472 - categorical_accuracy: 0.4667 - val_loss: 1.1999 - val_auc: 0.7157 - val_categorical_accuracy: 0.4446
# Epoch 118/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0880 - auc: 0.7405 - categorical_accuracy: 0.4594
# Epoch 118: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0881 - auc: 0.7406 - categorical_accuracy: 0.4599 - val_loss: 1.1992 - val_auc: 0.7184 - val_categorical_accuracy: 0.4471
# Epoch 119/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0866 - auc: 0.7483 - categorical_accuracy: 0.4646
# Epoch 119: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0864 - auc: 0.7483 - categorical_accuracy: 0.4648 - val_loss: 1.2000 - val_auc: 0.7186 - val_categorical_accuracy: 0.4530
# Epoch 120/120
# 329/330 [============================>.] - ETA: 0s - loss: 1.0869 - auc: 0.7457 - categorical_accuracy: 0.4655
# Epoch 120: val_categorical_accuracy did not improve from 0.51045
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0868 - auc: 0.7456 - categorical_accuracy: 0.4654 - val_loss: 1.1823 - val_auc: 0.7271 - val_categorical_accuracy: 0.4695

# %%
sg.utils.plot_history(history)

# %% [markdown]
# ### Evaluate the Model

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# Now we have trained the model we can evaluate on the test set.

# %%
# Make prediction
predictions = model.predict(test_gen)
predictions = target_encoding.inverse_transform(predictions)
results = pd.Series(predictions, index=test_labels.index)

test_gen = generator.flow(test_labels.index, test_targets)

# Evaluation Metrics
cm = confusion_matrix(test_labels, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Directed GraphSAGE on Test Set")
print(classification_report(test_labels, results))

# Performance
test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.58      0.67       714
#            1       0.71      0.42      0.53      1345
#            2       0.09      0.08      0.09       156
#            3       0.13      0.92      0.22       119
#
#     accuracy                           0.47      2334
#    macro avg       0.43      0.50      0.38      2334
# weighted avg       0.66      0.47      0.52      2334
#
# 47/47 [==============================] - 2s 31ms/step - loss: 1.1650 - auc: 0.7319 - categorical_accuracy: 0.4687
#
# Test Set Metrics:
# 	loss: 1.1650
# 	auc: 0.7319
# 	categorical_accuracy: 0.4687

# %% [markdown]
# ### Making predictions with the model in papers pubblished in 2002 and *2003*

# %%
#Load and evaluate the best model version
model = load_model(PATH_MODEL_GS_D_B, custom_objects={'MeanAggregator': MeanAggregator})

# %%
# Introduce prediction nodes
generator = DirectedGraphSAGENodeGenerator(graph_citation_full, batch_size, in_samples, out_samples)
prediction_targets = target_encoding.transform(test_nodes)
prediction_gen = generator.flow(test_nodes.index, prediction_targets)

# Make prediction
predictions = model.predict(prediction_gen)
predictions = target_encoding.inverse_transform(predictions)

# Create prediction dataset
results = pd.Series(predictions, index=test_nodes.index)
df_results = pd.DataFrame({"Predicted": results, "True": test_nodes})

# Evaluation Metrics
cm = confusion_matrix(test_nodes, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Directed GraphSAGE on Prediction Set")
print(classification_report(test_nodes, results))

# Performance
prediction_metrics = model.evaluate(prediction_gen)
print("\nPrediction Set Metrics:")
for name, val in zip(model.metrics_names, prediction_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      1537
#            1       0.93      0.54      0.68      2209
#            2       0.00      0.00      0.00       233
#            3       0.13      0.86      0.23       204
#
#     accuracy                           0.69      4183
#    macro avg       0.51      0.60      0.47      4183
# weighted avg       0.85      0.69      0.73      4183
#
# 84/84 [==============================] - 3s 32ms/step - loss: 0.7883 - auc: 0.8990 - categorical_accuracy: 0.7064
#
# Prediction Set Metrics:
# 	loss: 0.7883
# 	auc: 0.8990
# 	categorical_accuracy: 0.7064
