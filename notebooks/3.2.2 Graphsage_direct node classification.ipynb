# %% [markdown]
# # Inductive node classification and representation learning using GraphSAGE

# %%
# install StellarGraph if running on Google Colab
import sys
if 'google.colab' in sys.modules:
  # %pip install -q stellargraph[demos]==1.2.1

# %%
import networkx as nx
import pandas as pd
import numpy as np
import itertools
import os

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.utils import class_weight

import stellargraph as sg
from stellargraph import StellarGraph, StellarDiGraph
from stellargraph import globalvar
from stellargraph.mapper import GraphSAGENodeGenerator, DirectedGraphSAGENodeGenerator
from stellargraph.layer import GraphSAGE, MeanAggregator, DirectedGraphSAGE

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential, load_model
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, f1_score, make_scorer
from sklearn.utils.multiclass import unique_labels
from stellargraph import datasets
from IPython.display import display, HTML
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

import torch
torch.cuda.is_available()

# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Paths

# %%
# Parent paths
google_path = '/content/drive/My Drive/'
local_path = '/home/v.zevallosm/'
parent_path = google_path

#Specific paths
PATH_DATES = parent_path+'WebMining/data/raw/hep-th-slacdates_unzipped.txt'
PATH_CITATION = parent_path+'WebMining/data/raw/hep-th-citations_unzipped_filtered.txt'
PATH_LABEL = parent_path+'WebMining/data/processed/papers_label.csv'
PATH_ATTRIBUTES = parent_path+'WebMining/data/processed/papers_label.csv'

PATH_MODEL_GS_D_B = parent_path+'WebMining/models/graphsage_directed_base.hdf5'

# %% [markdown]
# ## Loading the dataset
#
# https://stellargraph.readthedocs.io/en/stable/demos/basics/loading-pandas.html

# %%
def read_dates(path):
    df = pd.read_csv(path, sep=' ', header=None, names=['id_paper', 'slac_date'])
    df['slac_date'] = pd.to_datetime(df['slac_date'])
    display(df.head(5))
    return (df)

# %%
def read_citation(path, df):
    df = pd.read_csv(path, sep=' ', header=None, names=['source', 'target'])
    display(df.head(5))
    return(df)

# %%
def get_labels(path, df2, label, date):
  df1 = pd.read_csv(path, index_col=0)
  df1.index.name='id_paper'
  df2 = df2.set_index("id_paper")
  df1 = pd.merge(df1, df2, left_index=True, right_index=True)
  label_full = df1[label]
  label_train = df1[df1.slac_date < date][label]
  label_test = df1[df1.slac_date >= date][label]
  print('Full nodes: %s   Train nodes: %s   Test nodes: %s'%(len(label_full), len(label_train), len(label_test)))
  return (label_full, label_train, label_test)

# %%
def get_features(path, df2, date):
  # Papers ids 
  df1 = pd.read_csv(path, index_col=0)
  df1.index.name='id_paper'
  
  # Date df
  df2 = df2.set_index("id_paper")
  
  # Combine datasets
  df1 = pd.merge(df1, df2, left_index=True, right_index=True)

  # Date features
  df1['slac_date'] = pd.to_datetime(df1['slac_date'])
  df1['year']= df1[date].dt.year
  df1['month']= df1[date].dt.month
  df1['week']= df1[date].dt.isocalendar().week
  
  df1['month_sin'] = np.sin((df1.month-1)*(2.*np.pi/12))
  df1['month_cos'] = np.cos((df1.month-1)*(2.*np.pi/12))
  
  df1['week_sin'] = np.sin((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))
  df1['week_cos'] = np.cos((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))
  
  ls = ['year', 'month_sin', 'month_cos', 'week_sin', 'week_cos']
  df_date = df1[ls]
  display(df_date.head(5))
  return(df_date)

# %%
df_dates = read_dates(PATH_DATES)
# Out:
#    id_paper  slac_date
# 0      1001 2000-01-04
# 1      1002 2000-01-04
# 2      1003 2000-01-04
# 3      1004 2000-01-04
# 4      1005 2000-01-04

# %%
df_citation = read_citation(PATH_CITATION, df_dates)
# Out:
#    source   target
# 0    1001  9304045
# 1    1001  9308122
# 2    1001  9309097
# 3    1001  9311042
# 4    1001  9401139

# %%
full_nodes, train_nodes, test_nodes = get_labels(PATH_LABEL, df_dates, 'label', '2002-01-01')
# Out:
# Full nodes: 27750   Train nodes: 23567   Test nodes: 4183

# %%
df_attributes = get_features(PATH_LABEL, df_dates, 'slac_date')
# Out:
#           year  month_sin  month_cos  week_sin  week_cos
# id_paper
# 1001      2000        0.0        1.0       0.0       1.0
# 1002      2000        0.0        1.0       0.0       1.0
# 1003      2000        0.0        1.0       0.0       1.0
# 1004      2000        0.0        1.0       0.0       1.0
# 1005      2000        0.0        1.0       0.0       1.0

# %% [markdown]
# ## Graph construction

# %%
graph_citation_full = StellarDiGraph({"paper": df_attributes}, {"cites": df_citation})
print(graph_citation_full.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 27750, Edges: 351763
#
#  Node types:
#   paper: [27750]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [351763]
#         Weights: all 1 (default)
#         Features: none

# %%
graph_citation_train = graph_citation_full.subgraph(train_nodes.index)
print(graph_citation_train.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 23567, Edges: 271167
#
#  Node types:
#   paper: [23567]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [271167]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# ### Splitting the data

# %%
train_labels, test_labels = model_selection.train_test_split(
    train_nodes,
    train_size=0.7, #0.05
    test_size=None,
    stratify=train_nodes,
    random_state=42,
)

val_labels, test_labels = model_selection.train_test_split(
    test_labels, 
    train_size=0.67, #0.2
    test_size=None, 
    stratify=test_labels, 
    random_state=42,
)

# %% [markdown]
# Note using stratified sampling gives the following counts:

# %%
from collections import Counter

Counter(train_labels)
# Out:
# Counter({0: 5044, 1: 9509, 2: 1103, 3: 840})

# %% [markdown]
# The training set has class imbalance that might need to be compensated, e.g., via using a weighted cross-entropy loss in model training, with class weights inversely proportional to class support. However, we will ignore the class imbalance in this example, for simplicity.

# %%
#get class_weights
class_weights = class_weight.compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(train_labels),
                                        y = train_labels                                                    
                                    )
class_weights = dict(zip(np.unique(train_labels), class_weights))
class_weights
# Out:
# {0: 0.8176050753370341,
#  1: 0.43369439478388894,
#  2: 3.7388939256572984,
#  3: 4.90952380952381}

# %% [markdown]
# ### Converting to numeric arrays

# %% [markdown]
# For our categorical target, we will use one-hot vectors that will be fed into a soft-max Keras layer during training.

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(train_labels)
val_targets = target_encoding.transform(val_labels)
test_targets = target_encoding.transform(test_labels)

# %% [markdown]
# ## Creating the GraphSAGE model in Keras

# %% [markdown]
# To feed data from the graph to the Keras model we need a generator. The generators are specialized to the model and the learning task so we choose the `GraphSAGENodeGenerator` as we are predicting node attributes with a GraphSAGE model.
#
# We need two other parameters, the `batch_size` to use for training and the number of nodes to sample at each level of the model. Here we choose a two-layer model with 10 nodes sampled in the first layer, and 10 in the second.

# %%
batch_size = 50
in_samples = [5, 2]
out_samples = [5, 2]

# %% [markdown]
# A `GraphSAGENodeGenerator` object is required to send the node features in sampled subgraphs to Keras

# %%
generator = DirectedGraphSAGENodeGenerator(graph_citation_train, batch_size, in_samples, out_samples)

# %% [markdown]
# Using the `generator.flow()` method, we can create iterators over nodes that should be used to train, validate, or evaluate the model. For training we use only the training nodes returned from our splitter and the target values. The `shuffle=True` argument is given to the `flow` method to improve training.

# %%
train_gen = generator.flow(train_labels.index, train_targets, shuffle=True)
val_gen = generator.flow(val_labels.index, val_targets, shuffle=True)
test_gen = generator.flow(test_labels.index, test_targets)

# %% [markdown]
# Now we can specify our machine learning model, we need a few more parameters for this:
#
#  * the `layer_sizes` is a list of hidden feature sizes of each layer in the model. In this example we use 32-dimensional hidden node features at each layer.
#  * The `bias` and `dropout` are internal parameters of the model.

# %%
graphsage_model = DirectedGraphSAGE(
    layer_sizes=[32, 32], generator=generator, bias=True, dropout=0.1 #, activations=["relu"] or  activation=keras.layers.LeakyReLU(alpha=0.01)
)

# %% [markdown]
# Now we create a model to predict the 3 categories using Keras softmax layers. Note that we need to use the `G.get_target_size` method to find the number of categories in the data.

# %%
x_inp, x_out = graphsage_model.in_out_tensors()
prediction = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)

# %%
prediction.shape
# Out:
# TensorShape([None, 4])

# %% [markdown]
# ### Training the model

# %% [markdown]
# Now let's create the actual Keras model with the graph inputs `x_inp` provided by the `graph_model` and outputs being the predictions from the softmax layer

# %%
model = Model(inputs=x_inp, outputs=prediction)
model.compile(
    optimizer = optimizers.Adam(learning_rate=0.001),
    loss = losses.categorical_crossentropy, #weighted_categorical_crossentropy(weights)
    metrics = [metrics.CategoricalAccuracy()] #= ['accuracy'],
)

print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 5, 5)]       0           []
#
#  input_3 (InputLayer)           [(None, 5, 5)]       0           []
#
#  input_4 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_5 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_6 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_7 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_1 (InputLayer)           [(None, 1, 5)]       0           []
#
#  reshape (Reshape)              (None, 1, 5, 5)      0           ['input_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 5, 5)      0           ['input_3[0][0]']
#
#  reshape_2 (Reshape)            (None, 5, 2, 5)      0           ['input_4[0][0]']
#
#  reshape_3 (Reshape)            (None, 5, 2, 5)      0           ['input_5[0][0]']
#
#  reshape_4 (Reshape)            (None, 5, 2, 5)      0           ['input_6[0][0]']
#
#  reshape_5 (Reshape)            (None, 5, 2, 5)      0           ['input_7[0][0]']
#
#  dropout (Dropout)              (None, 1, 5)         0           ['input_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 5, 5)      0           ['reshape[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 5, 5)      0           ['reshape_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 5, 5)         0           ['input_2[0][0]']
#
#  dropout_4 (Dropout)            (None, 5, 2, 5)      0           ['reshape_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 5, 2, 5)      0           ['reshape_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 5, 5)         0           ['input_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 5, 2, 5)      0           ['reshape_4[0][0]']
#
#  dropout_8 (Dropout)            (None, 5, 2, 5)      0           ['reshape_5[0][0]']
#
#  mean_aggregator (MeanAggregato  multiple            192         ['dropout[0][0]',
#  r)                                                               'dropout_1[0][0]',
#                                                                   'dropout_2[0][0]',
#                                                                   'dropout_3[0][0]',
#                                                                   'dropout_4[0][0]',
#                                                                   'dropout_5[0][0]',
#                                                                   'dropout_6[0][0]',
#                                                                   'dropout_7[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  reshape_6 (Reshape)            (None, 1, 5, 32)     0           ['mean_aggregator[1][0]']
#
#  reshape_7 (Reshape)            (None, 1, 5, 32)     0           ['mean_aggregator[2][0]']
#
#  dropout_9 (Dropout)            (None, 1, 32)        0           ['mean_aggregator[0][0]']
#
#  dropout_10 (Dropout)           (None, 1, 5, 32)     0           ['reshape_6[0][0]']
#
#  dropout_11 (Dropout)           (None, 1, 5, 32)     0           ['reshape_7[0][0]']
#
#  mean_aggregator_1 (MeanAggrega  (None, 1, 32)       1056        ['dropout_9[0][0]',
#  tor)                                                             'dropout_10[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  reshape_8 (Reshape)            (None, 32)           0           ['mean_aggregator_1[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['reshape_8[0][0]']
#
#  dense (Dense)                  (None, 4)            132         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1,380
# Trainable params: 1,380
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Train the model, keeping track of its loss and accuracy on the training set, and its generalisation performance on the validation set (we need to create another generator over the validation data for this)

# %%
#create callback
checkpoint = ModelCheckpoint(filepath=PATH_MODEL_GS_D_B, 
                             monitor='val_categorical_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')

#fit the model
history = model.fit(train_gen, 
                    epochs=100, 
                    validation_data=val_gen, 
                    class_weight=class_weights,
                    verbose=1, 
                    shuffle=True,
                    callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0273 - categorical_accuracy: 0.4647
# Epoch 1: val_categorical_accuracy improved from -inf to 0.46527, saving model to /content/drive/My Drive/WebMining/models/graphsage_directed_base.hdf5
# 330/330 [==============================] - 18s 54ms/step - loss: 1.0268 - categorical_accuracy: 0.4648 - val_loss: 1.0935 - val_categorical_accuracy: 0.4653
# Epoch 2/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0306 - categorical_accuracy: 0.4697
# Epoch 2: val_categorical_accuracy did not improve from 0.46527
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0294 - categorical_accuracy: 0.4699 - val_loss: 1.1179 - val_categorical_accuracy: 0.4503
# Epoch 3/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0319 - categorical_accuracy: 0.4704
# Epoch 3: val_categorical_accuracy did not improve from 0.46527
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0322 - categorical_accuracy: 0.4705 - val_loss: 1.0855 - val_categorical_accuracy: 0.4461
# Epoch 4/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0305 - categorical_accuracy: 0.4659
# Epoch 4: val_categorical_accuracy improved from 0.46527 to 0.47752, saving model to /content/drive/My Drive/WebMining/models/graphsage_directed_base.hdf5
# 330/330 [==============================] - 16s 50ms/step - loss: 1.0305 - categorical_accuracy: 0.4661 - val_loss: 1.0552 - val_categorical_accuracy: 0.4775
# Epoch 5/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0278 - categorical_accuracy: 0.4690
# Epoch 5: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 18s 54ms/step - loss: 1.0278 - categorical_accuracy: 0.4690 - val_loss: 1.0775 - val_categorical_accuracy: 0.4560
# Epoch 6/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0378 - categorical_accuracy: 0.4585
# Epoch 6: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 19s 57ms/step - loss: 1.0378 - categorical_accuracy: 0.4585 - val_loss: 1.0748 - val_categorical_accuracy: 0.4463
# Epoch 7/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0294 - categorical_accuracy: 0.4629
# Epoch 7: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 14s 42ms/step - loss: 1.0294 - categorical_accuracy: 0.4629 - val_loss: 1.0876 - val_categorical_accuracy: 0.4587
# Epoch 8/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0286 - categorical_accuracy: 0.4657
# Epoch 8: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 15s 46ms/step - loss: 1.0286 - categorical_accuracy: 0.4657 - val_loss: 1.0903 - val_categorical_accuracy: 0.4581
# Epoch 9/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0311 - categorical_accuracy: 0.4621
# Epoch 9: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 49ms/step - loss: 1.0311 - categorical_accuracy: 0.4621 - val_loss: 1.0746 - val_categorical_accuracy: 0.4592
# Epoch 10/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0272 - categorical_accuracy: 0.4650
# Epoch 10: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0280 - categorical_accuracy: 0.4649 - val_loss: 1.0900 - val_categorical_accuracy: 0.4503
# Epoch 11/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0353 - categorical_accuracy: 0.4631
# Epoch 11: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0353 - categorical_accuracy: 0.4631 - val_loss: 1.1041 - val_categorical_accuracy: 0.4518
# Epoch 12/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0382 - categorical_accuracy: 0.4646
# Epoch 12: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0381 - categorical_accuracy: 0.4647 - val_loss: 1.0894 - val_categorical_accuracy: 0.4545
# Epoch 13/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0330 - categorical_accuracy: 0.4616
# Epoch 13: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0330 - categorical_accuracy: 0.4616 - val_loss: 1.0551 - val_categorical_accuracy: 0.4754
# Epoch 14/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0373 - categorical_accuracy: 0.4588
# Epoch 14: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0373 - categorical_accuracy: 0.4588 - val_loss: 1.1204 - val_categorical_accuracy: 0.4568
# Epoch 15/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0317 - categorical_accuracy: 0.4647
# Epoch 15: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 50ms/step - loss: 1.0313 - categorical_accuracy: 0.4648 - val_loss: 1.1174 - val_categorical_accuracy: 0.4448
# Epoch 16/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0310 - categorical_accuracy: 0.4618
# Epoch 16: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 53ms/step - loss: 1.0310 - categorical_accuracy: 0.4618 - val_loss: 1.0749 - val_categorical_accuracy: 0.4615
# Epoch 17/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0321 - categorical_accuracy: 0.4597
# Epoch 17: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 50ms/step - loss: 1.0320 - categorical_accuracy: 0.4598 - val_loss: 1.0717 - val_categorical_accuracy: 0.4649
# Epoch 18/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0283 - categorical_accuracy: 0.4718
# Epoch 18: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0279 - categorical_accuracy: 0.4722 - val_loss: 1.0643 - val_categorical_accuracy: 0.4615
# Epoch 19/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0280 - categorical_accuracy: 0.4634
# Epoch 19: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 16s 49ms/step - loss: 1.0280 - categorical_accuracy: 0.4634 - val_loss: 1.0974 - val_categorical_accuracy: 0.4526
# Epoch 20/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0320 - categorical_accuracy: 0.4670
# Epoch 20: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0324 - categorical_accuracy: 0.4671 - val_loss: 1.0974 - val_categorical_accuracy: 0.4577
# Epoch 21/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0267 - categorical_accuracy: 0.4634
# Epoch 21: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 14s 42ms/step - loss: 1.0267 - categorical_accuracy: 0.4634 - val_loss: 1.0604 - val_categorical_accuracy: 0.4570
# Epoch 22/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0255 - categorical_accuracy: 0.4736
# Epoch 22: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0254 - categorical_accuracy: 0.4740 - val_loss: 1.1541 - val_categorical_accuracy: 0.4374
# Epoch 23/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0233 - categorical_accuracy: 0.4630
# Epoch 23: val_categorical_accuracy did not improve from 0.47752
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0233 - categorical_accuracy: 0.4630 - val_loss: 1.1156 - val_categorical_accuracy: 0.4452
# Epoch 24/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0264 - categorical_accuracy: 0.4628
# Epoch 24: val_categorical_accuracy improved from 0.47752 to 0.49145, saving model to /content/drive/My Drive/WebMining/models/graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0274 - categorical_accuracy: 0.4627 - val_loss: 1.0295 - val_categorical_accuracy: 0.4915
# Epoch 25/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0256 - categorical_accuracy: 0.4730
# Epoch 25: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 16s 50ms/step - loss: 1.0256 - categorical_accuracy: 0.4730 - val_loss: 1.0950 - val_categorical_accuracy: 0.4541
# Epoch 26/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0296 - categorical_accuracy: 0.4662
# Epoch 26: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0296 - categorical_accuracy: 0.4662 - val_loss: 1.1222 - val_categorical_accuracy: 0.4456
# Epoch 27/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0269 - categorical_accuracy: 0.4673
# Epoch 27: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 14s 42ms/step - loss: 1.0269 - categorical_accuracy: 0.4673 - val_loss: 1.0552 - val_categorical_accuracy: 0.4720
# Epoch 28/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0275 - categorical_accuracy: 0.4688
# Epoch 28: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0275 - categorical_accuracy: 0.4688 - val_loss: 1.1311 - val_categorical_accuracy: 0.4520
# Epoch 29/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0288 - categorical_accuracy: 0.4678
# Epoch 29: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0289 - categorical_accuracy: 0.4681 - val_loss: 1.1150 - val_categorical_accuracy: 0.4490
# Epoch 30/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0282 - categorical_accuracy: 0.4620
# Epoch 30: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 16s 50ms/step - loss: 1.0282 - categorical_accuracy: 0.4620 - val_loss: 1.1161 - val_categorical_accuracy: 0.4478
# Epoch 31/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0308 - categorical_accuracy: 0.4627
# Epoch 31: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 14s 42ms/step - loss: 1.0316 - categorical_accuracy: 0.4629 - val_loss: 1.1229 - val_categorical_accuracy: 0.4448
# Epoch 32/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0319 - categorical_accuracy: 0.4655
# Epoch 32: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0318 - categorical_accuracy: 0.4655 - val_loss: 1.0964 - val_categorical_accuracy: 0.4636
# Epoch 33/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0220 - categorical_accuracy: 0.4755
# Epoch 33: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0220 - categorical_accuracy: 0.4755 - val_loss: 1.0970 - val_categorical_accuracy: 0.4549
# Epoch 34/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0299 - categorical_accuracy: 0.4616
# Epoch 34: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0311 - categorical_accuracy: 0.4617 - val_loss: 1.0973 - val_categorical_accuracy: 0.4530
# Epoch 35/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.0216 - categorical_accuracy: 0.4675
# Epoch 35: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0220 - categorical_accuracy: 0.4674 - val_loss: 1.0468 - val_categorical_accuracy: 0.4725
# Epoch 36/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0238 - categorical_accuracy: 0.4661
# Epoch 36: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0238 - categorical_accuracy: 0.4661 - val_loss: 1.1011 - val_categorical_accuracy: 0.4484
# Epoch 37/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0271 - categorical_accuracy: 0.4659
# Epoch 37: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0263 - categorical_accuracy: 0.4659 - val_loss: 1.0532 - val_categorical_accuracy: 0.4625
# Epoch 38/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0232 - categorical_accuracy: 0.4738
# Epoch 38: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 53ms/step - loss: 1.0225 - categorical_accuracy: 0.4739 - val_loss: 1.1122 - val_categorical_accuracy: 0.4321
# Epoch 39/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0269 - categorical_accuracy: 0.4732
# Epoch 39: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 15s 45ms/step - loss: 1.0269 - categorical_accuracy: 0.4732 - val_loss: 1.0682 - val_categorical_accuracy: 0.4541
# Epoch 40/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0199 - categorical_accuracy: 0.4706
# Epoch 40: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0208 - categorical_accuracy: 0.4708 - val_loss: 1.0981 - val_categorical_accuracy: 0.4471
# Epoch 41/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0276 - categorical_accuracy: 0.4715
# Epoch 41: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0278 - categorical_accuracy: 0.4717 - val_loss: 1.1356 - val_categorical_accuracy: 0.4376
# Epoch 42/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0262 - categorical_accuracy: 0.4680
# Epoch 42: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 16s 49ms/step - loss: 1.0262 - categorical_accuracy: 0.4680 - val_loss: 1.0848 - val_categorical_accuracy: 0.4566
# Epoch 43/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0224 - categorical_accuracy: 0.4690
# Epoch 43: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0224 - categorical_accuracy: 0.4690 - val_loss: 1.0701 - val_categorical_accuracy: 0.4615
# Epoch 44/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0225 - categorical_accuracy: 0.4723
# Epoch 44: val_categorical_accuracy did not improve from 0.49145
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0228 - categorical_accuracy: 0.4722 - val_loss: 1.0678 - val_categorical_accuracy: 0.4782
# Epoch 45/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0276 - categorical_accuracy: 0.4698
# Epoch 45: val_categorical_accuracy improved from 0.49145 to 0.49335, saving model to /content/drive/My Drive/WebMining/models/graphsage_directed_base.hdf5
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0276 - categorical_accuracy: 0.4698 - val_loss: 1.0518 - val_categorical_accuracy: 0.4934
# Epoch 46/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0178 - categorical_accuracy: 0.4778
# Epoch 46: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0187 - categorical_accuracy: 0.4778 - val_loss: 1.1039 - val_categorical_accuracy: 0.4541
# Epoch 47/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0242 - categorical_accuracy: 0.4686
# Epoch 47: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0242 - categorical_accuracy: 0.4686 - val_loss: 1.1306 - val_categorical_accuracy: 0.4488
# Epoch 48/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0207 - categorical_accuracy: 0.4701
# Epoch 48: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0202 - categorical_accuracy: 0.4705 - val_loss: 1.0762 - val_categorical_accuracy: 0.4661
# Epoch 49/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0256 - categorical_accuracy: 0.4695
# Epoch 49: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0256 - categorical_accuracy: 0.4695 - val_loss: 1.0919 - val_categorical_accuracy: 0.4475
# Epoch 50/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0225 - categorical_accuracy: 0.4714
# Epoch 50: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 52ms/step - loss: 1.0225 - categorical_accuracy: 0.4714 - val_loss: 1.1099 - val_categorical_accuracy: 0.4547
# Epoch 51/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0217 - categorical_accuracy: 0.4775
# Epoch 51: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 16s 48ms/step - loss: 1.0211 - categorical_accuracy: 0.4776 - val_loss: 1.1076 - val_categorical_accuracy: 0.4771
# Epoch 52/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0250 - categorical_accuracy: 0.4739
# Epoch 52: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 16s 50ms/step - loss: 1.0250 - categorical_accuracy: 0.4739 - val_loss: 1.0741 - val_categorical_accuracy: 0.4636
# Epoch 53/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0223 - categorical_accuracy: 0.4725
# Epoch 53: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0223 - categorical_accuracy: 0.4725 - val_loss: 1.1107 - val_categorical_accuracy: 0.4655
# Epoch 54/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0211 - categorical_accuracy: 0.4753
# Epoch 54: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0218 - categorical_accuracy: 0.4748 - val_loss: 1.0909 - val_categorical_accuracy: 0.4469
# Epoch 55/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0215 - categorical_accuracy: 0.4744
# Epoch 55: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0208 - categorical_accuracy: 0.4747 - val_loss: 1.0597 - val_categorical_accuracy: 0.4758
# Epoch 56/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0216 - categorical_accuracy: 0.4742
# Epoch 56: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0216 - categorical_accuracy: 0.4742 - val_loss: 1.0399 - val_categorical_accuracy: 0.4741
# Epoch 57/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0247 - categorical_accuracy: 0.4673
# Epoch 57: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0233 - categorical_accuracy: 0.4674 - val_loss: 1.0737 - val_categorical_accuracy: 0.4513
# Epoch 58/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0218 - categorical_accuracy: 0.4744
# Epoch 58: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0212 - categorical_accuracy: 0.4744 - val_loss: 1.0750 - val_categorical_accuracy: 0.4653
# Epoch 59/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0254 - categorical_accuracy: 0.4767
# Epoch 59: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0259 - categorical_accuracy: 0.4765 - val_loss: 1.0794 - val_categorical_accuracy: 0.4754
# Epoch 60/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0169 - categorical_accuracy: 0.4774
# Epoch 60: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0169 - categorical_accuracy: 0.4774 - val_loss: 1.0946 - val_categorical_accuracy: 0.4530
# Epoch 61/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0244 - categorical_accuracy: 0.4669
# Epoch 61: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0244 - categorical_accuracy: 0.4673 - val_loss: 1.0642 - val_categorical_accuracy: 0.4773
# Epoch 62/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0194 - categorical_accuracy: 0.4785
# Epoch 62: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0206 - categorical_accuracy: 0.4788 - val_loss: 1.0539 - val_categorical_accuracy: 0.4644
# Epoch 63/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0249 - categorical_accuracy: 0.4701
# Epoch 63: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0249 - categorical_accuracy: 0.4701 - val_loss: 1.0690 - val_categorical_accuracy: 0.4661
# Epoch 64/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0188 - categorical_accuracy: 0.4729
# Epoch 64: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0187 - categorical_accuracy: 0.4730 - val_loss: 1.1042 - val_categorical_accuracy: 0.4524
# Epoch 65/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0218 - categorical_accuracy: 0.4758
# Epoch 65: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 15s 44ms/step - loss: 1.0218 - categorical_accuracy: 0.4758 - val_loss: 1.0404 - val_categorical_accuracy: 0.4767
# Epoch 66/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0188 - categorical_accuracy: 0.4712
# Epoch 66: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0200 - categorical_accuracy: 0.4712 - val_loss: 1.0646 - val_categorical_accuracy: 0.4790
# Epoch 67/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0209 - categorical_accuracy: 0.4782
# Epoch 67: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0223 - categorical_accuracy: 0.4777 - val_loss: 1.1263 - val_categorical_accuracy: 0.4503
# Epoch 68/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0224 - categorical_accuracy: 0.4722
# Epoch 68: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0217 - categorical_accuracy: 0.4721 - val_loss: 1.0777 - val_categorical_accuracy: 0.4720
# Epoch 69/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0220 - categorical_accuracy: 0.4792
# Epoch 69: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 16s 50ms/step - loss: 1.0220 - categorical_accuracy: 0.4792 - val_loss: 1.0596 - val_categorical_accuracy: 0.4691
# Epoch 70/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0202 - categorical_accuracy: 0.4782
# Epoch 70: val_categorical_accuracy did not improve from 0.49335
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0211 - categorical_accuracy: 0.4780 - val_loss: 1.0629 - val_categorical_accuracy: 0.4678
# Epoch 71/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0190 - categorical_accuracy: 0.4729
# Epoch 71: val_categorical_accuracy improved from 0.49335 to 0.49757, saving model to /content/drive/My Drive/WebMining/models/graphsage_directed_base.hdf5
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0190 - categorical_accuracy: 0.4727 - val_loss: 1.0531 - val_categorical_accuracy: 0.4976
# Epoch 72/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0177 - categorical_accuracy: 0.4763
# Epoch 72: val_categorical_accuracy did not improve from 0.49757
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0177 - categorical_accuracy: 0.4763 - val_loss: 1.0892 - val_categorical_accuracy: 0.4596
# Epoch 73/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0230 - categorical_accuracy: 0.4746
# Epoch 73: val_categorical_accuracy improved from 0.49757 to 0.49821, saving model to /content/drive/My Drive/WebMining/models/graphsage_directed_base.hdf5
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0230 - categorical_accuracy: 0.4746 - val_loss: 1.0197 - val_categorical_accuracy: 0.4982
# Epoch 74/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0231 - categorical_accuracy: 0.4781
# Epoch 74: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0231 - categorical_accuracy: 0.4781 - val_loss: 1.0740 - val_categorical_accuracy: 0.4653
# Epoch 75/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0211 - categorical_accuracy: 0.4777
# Epoch 75: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0203 - categorical_accuracy: 0.4776 - val_loss: 1.1091 - val_categorical_accuracy: 0.4560
# Epoch 76/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0239 - categorical_accuracy: 0.4745
# Epoch 76: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0245 - categorical_accuracy: 0.4744 - val_loss: 1.0703 - val_categorical_accuracy: 0.4769
# Epoch 77/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0194 - categorical_accuracy: 0.4742
# Epoch 77: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0194 - categorical_accuracy: 0.4742 - val_loss: 1.0921 - val_categorical_accuracy: 0.4678
# Epoch 78/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0168 - categorical_accuracy: 0.4791
# Epoch 78: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0158 - categorical_accuracy: 0.4788 - val_loss: 1.0735 - val_categorical_accuracy: 0.4659
# Epoch 79/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0153 - categorical_accuracy: 0.4801
# Epoch 79: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0153 - categorical_accuracy: 0.4801 - val_loss: 1.1123 - val_categorical_accuracy: 0.4581
# Epoch 80/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0199 - categorical_accuracy: 0.4804
# Epoch 80: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0199 - categorical_accuracy: 0.4804 - val_loss: 1.0985 - val_categorical_accuracy: 0.4608
# Epoch 81/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0157 - categorical_accuracy: 0.4777
# Epoch 81: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0174 - categorical_accuracy: 0.4774 - val_loss: 1.0573 - val_categorical_accuracy: 0.4758
# Epoch 82/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0178 - categorical_accuracy: 0.4779
# Epoch 82: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0178 - categorical_accuracy: 0.4779 - val_loss: 1.0401 - val_categorical_accuracy: 0.4963
# Epoch 83/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0191 - categorical_accuracy: 0.4785
# Epoch 83: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0190 - categorical_accuracy: 0.4784 - val_loss: 1.0520 - val_categorical_accuracy: 0.4613
# Epoch 84/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0176 - categorical_accuracy: 0.4754
# Epoch 84: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0165 - categorical_accuracy: 0.4751 - val_loss: 1.0754 - val_categorical_accuracy: 0.4836
# Epoch 85/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0195 - categorical_accuracy: 0.4827
# Epoch 85: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0201 - categorical_accuracy: 0.4824 - val_loss: 1.1105 - val_categorical_accuracy: 0.4551
# Epoch 86/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0212 - categorical_accuracy: 0.4698
# Epoch 86: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0199 - categorical_accuracy: 0.4699 - val_loss: 1.0604 - val_categorical_accuracy: 0.4708
# Epoch 87/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0158 - categorical_accuracy: 0.4774
# Epoch 87: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0149 - categorical_accuracy: 0.4777 - val_loss: 1.0454 - val_categorical_accuracy: 0.4786
# Epoch 88/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0151 - categorical_accuracy: 0.4833
# Epoch 88: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0157 - categorical_accuracy: 0.4835 - val_loss: 1.0627 - val_categorical_accuracy: 0.4678
# Epoch 89/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0201 - categorical_accuracy: 0.4759
# Epoch 89: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0188 - categorical_accuracy: 0.4760 - val_loss: 1.0488 - val_categorical_accuracy: 0.4847
# Epoch 90/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0189 - categorical_accuracy: 0.4761
# Epoch 90: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 15s 45ms/step - loss: 1.0189 - categorical_accuracy: 0.4761 - val_loss: 1.0686 - val_categorical_accuracy: 0.4672
# Epoch 91/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0176 - categorical_accuracy: 0.4771
# Epoch 91: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0176 - categorical_accuracy: 0.4771 - val_loss: 1.0991 - val_categorical_accuracy: 0.4560
# Epoch 92/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0225 - categorical_accuracy: 0.4729
# Epoch 92: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0229 - categorical_accuracy: 0.4727 - val_loss: 1.0753 - val_categorical_accuracy: 0.4919
# Epoch 93/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0207 - categorical_accuracy: 0.4821
# Epoch 93: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0207 - categorical_accuracy: 0.4821 - val_loss: 1.0871 - val_categorical_accuracy: 0.4594
# Epoch 94/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0165 - categorical_accuracy: 0.4810
# Epoch 94: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0165 - categorical_accuracy: 0.4810 - val_loss: 1.1174 - val_categorical_accuracy: 0.4452
# Epoch 95/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0177 - categorical_accuracy: 0.4762
# Epoch 95: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0177 - categorical_accuracy: 0.4762 - val_loss: 1.0482 - val_categorical_accuracy: 0.4805
# Epoch 96/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0167 - categorical_accuracy: 0.4805
# Epoch 96: val_categorical_accuracy did not improve from 0.49821
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0167 - categorical_accuracy: 0.4805 - val_loss: 1.0762 - val_categorical_accuracy: 0.4739
# Epoch 97/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0193 - categorical_accuracy: 0.4790
# Epoch 97: val_categorical_accuracy improved from 0.49821 to 0.51552, saving model to /content/drive/My Drive/WebMining/models/graphsage_directed_base.hdf5
# 330/330 [==============================] - 14s 44ms/step - loss: 1.0195 - categorical_accuracy: 0.4788 - val_loss: 1.0136 - val_categorical_accuracy: 0.5155
# Epoch 98/100
# 330/330 [==============================] - ETA: 0s - loss: 1.0168 - categorical_accuracy: 0.4801
# Epoch 98: val_categorical_accuracy did not improve from 0.51552
# 330/330 [==============================] - 17s 51ms/step - loss: 1.0168 - categorical_accuracy: 0.4801 - val_loss: 1.0723 - val_categorical_accuracy: 0.4642
# Epoch 99/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0124 - categorical_accuracy: 0.4814
# Epoch 99: val_categorical_accuracy did not improve from 0.51552
# 330/330 [==============================] - 14s 43ms/step - loss: 1.0119 - categorical_accuracy: 0.4811 - val_loss: 1.1426 - val_categorical_accuracy: 0.4433
# Epoch 100/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.0168 - categorical_accuracy: 0.4824
# Epoch 100: val_categorical_accuracy did not improve from 0.51552
# 330/330 [==============================] - 17s 50ms/step - loss: 1.0177 - categorical_accuracy: 0.4822 - val_loss: 1.0984 - val_categorical_accuracy: 0.4627

# %%
sg.utils.plot_history(history)

# %% [markdown]
# ### Evaluate the Model

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# Now we have trained the model we can evaluate on the test set.

# %%
# Make prediction
predictions = model.predict(test_gen)
predictions = target_encoding.inverse_transform(predictions)
results = pd.Series(predictions, index=test_labels.index)

test_gen = generator.flow(test_labels.index, test_targets)

# Evaluation Metrics
cm = confusion_matrix(test_labels, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Directed GraphSAGE on Test Set")
print(classification_report(test_labels, results))

# Performance
test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.66      0.68       714
#            1       0.70      0.27      0.39      1345
#            2       0.08      0.16      0.10       156
#            3       0.12      0.83      0.21       119
#
#     accuracy                           0.41      2334
#    macro avg       0.40      0.48      0.35      2334
# weighted avg       0.63      0.41      0.45      2334
#
# 47/47 [==============================] - 2s 46ms/step - loss: 1.1329 - categorical_accuracy: 0.4160
#
# Test Set Metrics:
# 	loss: 1.1329
# 	categorical_accuracy: 0.4160

# %% [markdown]
# ### Making predictions with the model in papers pubblished in 2002 and *2003*

# %%
#Load and evaluate the best model version
model = load_model(PATH_MODEL_GS_D_B, custom_objects={'MeanAggregator': MeanAggregator})

# %%
# Introduce prediction nodes
generator = DirectedGraphSAGENodeGenerator(graph_citation_full, batch_size, in_samples, out_samples)
prediction_targets = target_encoding.transform(test_nodes)
prediction_gen = generator.flow(test_nodes.index, prediction_targets)

# Make prediction
predictions = model.predict(prediction_gen)
predictions = target_encoding.inverse_transform(predictions)

# Create prediction dataset
results = pd.Series(predictions, index=test_nodes.index)
df_results = pd.DataFrame({"Predicted": results, "True": test_nodes})

# Evaluation Metrics
cm = confusion_matrix(test_nodes, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Directed GraphSAGE on Prediction Set")
print(classification_report(test_nodes, results))

# Performance
prediction_metrics = model.evaluate(prediction_gen)
print("\nPrediction Set Metrics:")
for name, val in zip(model.metrics_names, prediction_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1537
#            1       0.93      0.53      0.68      2209
#            2       0.13      0.36      0.19       233
#            3       0.15      0.50      0.23       204
#
#     accuracy                           0.69      4183
#    macro avg       0.54      0.60      0.52      4183
# weighted avg       0.86      0.69      0.74      4183
#
# 84/84 [==============================] - 3s 32ms/step - loss: 0.7161 - categorical_accuracy: 0.6935
#
# Prediction Set Metrics:
# 	loss: 0.7161
# 	categorical_accuracy: 0.6935
