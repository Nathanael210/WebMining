# %% [markdown]
# # Graphsage undirect paper classification

# %%
# install StellarGraph if running on Google Colab
import sys
if 'google.colab' in sys.modules:
    # %pip install -q stellargraph[demos]==1.2.1
# Out:
#      |████████████████████████████████| 435 kB 8.0 MB/s
#      |████████████████████████████████| 482 kB 44.7 MB/s
#      |████████████████████████████████| 462 kB 40.7 MB/s
#      |████████████████████████████████| 41 kB 388 kB/s
#   Building wheel for mplleaflet (setup.py) ... done

# %%
import networkx as nx
import pandas as pd
import numpy as np
import itertools
import os

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.utils import class_weight

import stellargraph as sg
from stellargraph import StellarGraph, StellarDiGraph
from stellargraph import globalvar
from stellargraph.mapper import GraphSAGENodeGenerator, DirectedGraphSAGENodeGenerator
from stellargraph.layer import GraphSAGE, MeanAggregator, DirectedGraphSAGE

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential, load_model
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, f1_score, make_scorer
from sklearn.utils.multiclass import unique_labels
from stellargraph import datasets
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from collections import Counter

from google.colab import drive
drive.mount('/content/drive')

import torch
torch.cuda.is_available()

# %matplotlib inline
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Paths

# %%
# Parent paths
google_path = '/content/drive/My Drive/'
local_path = '/home/v.zevallosm/'
parent_path = google_path

#Specific paths
PATH_DATES = parent_path+'WebMining/data/raw/hep-th-slacdates_unzipped.txt'
PATH_CITATION = parent_path+'WebMining/data/raw/hep-th-citations_unzipped_filtered.txt'
PATH_LABEL = parent_path+'WebMining/data/processed/papers_label.csv'
PATH_ATTRIBUTES = parent_path+'WebMining/data/processed/papers_label.csv'

PATH_MODEL_GS_U_B = parent_path+'WebMining/models/graphsage_undirected_base.hdf5'

# %% [markdown]
# ## Loading the dataset

# %%
def read_dates(path):
    df = pd.read_csv(path, sep=' ', header=None, names=['id_paper', 'slac_date'])
    df['slac_date'] = pd.to_datetime(df['slac_date'])
    display(df.head(5))
    return (df)

# %%
def read_citation(path, df):
    df = pd.read_csv(path, sep=' ', header=None, names=['source', 'target'])
    display(df.head(5))
    return(df)

# %%
def get_labels(path, df2, label, date):
    df1 = pd.read_csv(path, index_col=0)
    df1.index.name='id_paper'
    df2 = df2.set_index("id_paper")
    df1 = pd.merge(df1, df2, left_index=True, right_index=True)
    label_full = df1[label]
    label_train = df1[df1.slac_date < date][label]
    label_test = df1[df1.slac_date >= date][label]
    print('Full nodes: %s   Train nodes: %s   Test nodes: %s'%(len(label_full), len(label_train), len(label_test)))
    return (label_full, label_train, label_test)

# %%
def get_features(path, df2, date):
    # Papers ids 
    df1 = pd.read_csv(path, index_col=0)
    df1.index.name='id_paper'

    # Date df
    df2 = df2.set_index("id_paper")

    # Combine datasets
    df1 = pd.merge(df1, df2, left_index=True, right_index=True)

    # Date features
    df1['slac_date'] = pd.to_datetime(df1['slac_date'])
    df1['year']= df1[date].dt.year
    df1['month']= df1[date].dt.month
    df1['week']= df1[date].dt.isocalendar().week

    df1['month_sin'] = np.sin((df1.month-1)*(2.*np.pi/12))
    df1['month_cos'] = np.cos((df1.month-1)*(2.*np.pi/12))

    df1['week_sin'] = np.sin((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))
    df1['week_cos'] = np.cos((df1[date].dt.isocalendar().week-1)*(2.*np.pi/53))

    ls = ['year', 'month_sin', 'month_cos', 'week_sin', 'week_cos']
    df_date = df1[ls]
    display(df_date.head(5))
    return(df_date)

# %%
df_dates = read_dates(PATH_DATES)
# Out:
#    id_paper  slac_date
# 0      1001 2000-01-04
# 1      1002 2000-01-04
# 2      1003 2000-01-04
# 3      1004 2000-01-04
# 4      1005 2000-01-04

# %%
df_citation = read_citation(PATH_CITATION, df_dates)
# Out:
#    source   target
# 0    1001  9304045
# 1    1001  9308122
# 2    1001  9309097
# 3    1001  9311042
# 4    1001  9401139

# %%
full_nodes, train_nodes, test_nodes = get_labels(PATH_LABEL, df_dates, 'label', '2002-01-01')
# Out:
# Full nodes: 27750   Train nodes: 23567   Test nodes: 4183

# %%
df_attributes = get_features(PATH_LABEL, df_dates, 'slac_date')
# Out:
#           year  month_sin  month_cos  week_sin  week_cos
# id_paper
# 1001      2000        0.0        1.0       0.0       1.0
# 1002      2000        0.0        1.0       0.0       1.0
# 1003      2000        0.0        1.0       0.0       1.0
# 1004      2000        0.0        1.0       0.0       1.0
# 1005      2000        0.0        1.0       0.0       1.0

# %% [markdown]
# ## Graph construction

# %%
graph_citation_full = StellarGraph({"paper": df_attributes}, {"cites": df_citation})
print(graph_citation_full.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 27750, Edges: 351763
#
#  Node types:
#   paper: [27750]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [351763]
#         Weights: all 1 (default)
#         Features: none

# %%
graph_citation_train = graph_citation_full.subgraph(train_nodes.index)
print(graph_citation_train.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 23567, Edges: 271167
#
#  Node types:
#   paper: [23567]
#     Features: float32 vector, length 5
#     Edge types: paper-cites->paper
#
#  Edge types:
#     paper-cites->paper: [271167]
#         Weights: all 1 (default)
#         Features: none

# %% [markdown]
# ### Splitting the data

# %%
train_labels, test_labels = model_selection.train_test_split(
    train_nodes,
    train_size=0.7, #0.05
    test_size=None,
    stratify=train_nodes,
    random_state=42,
)

val_labels, test_labels = model_selection.train_test_split(
    test_labels, 
    train_size=0.67, #0.2
    test_size=None, 
    stratify=test_labels, 
    random_state=42,
)

# %% [markdown]
# Stratified sampling gives the following counts:

# %%
Counter(train_labels)
# Out:
# Counter({0: 5044, 1: 9509, 2: 1103, 3: 840})

# %% [markdown]
# The training set has class imbalance is compensated, with class weights inversely proportional to class support.

# %%
#get class_weights
class_weights = class_weight.compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(train_labels),
                                        y = train_labels                                                    
                                    )
class_weights = dict(zip(np.unique(train_labels), class_weights))
class_weights
# Out:
# {0: 0.8176050753370341,
#  1: 0.43369439478388894,
#  2: 3.7388939256572984,
#  3: 4.90952380952381}

# %% [markdown]
# ### Converting to numeric arrays

# %% [markdown]
# For our categorical target, we will use one-hot vectors that will be fed into a soft-max Keras layer during training.

# %%
target_encoding = preprocessing.LabelBinarizer()

train_targets = target_encoding.fit_transform(train_labels)
val_targets = target_encoding.transform(val_labels)
test_targets = target_encoding.transform(test_labels)

# %% [markdown]
# ## Creating the GraphSAGE model in Keras

# %% [markdown]
# To feed data from the graph to the Keras model we need a generator. The generators are specialized to the model and the learning task so we choose the `GraphSAGENodeGenerator` as we are predicting node attributes with a GraphSAGE model.
#
# We need specify the `batch_size` to use for training and the number of nodes to sample at each level of the model. Here we choose a two-layer model with 10 nodes sampled in the first layer, and 10 in the second.

# %%
batch_size = 50
num_samples = [10, 4]

generator = GraphSAGENodeGenerator(graph_citation_train, batch_size, num_samples)

# %% [markdown]
# Using the `generator.flow()` method, we can create iterators over nodes that should be used to train, validate, or evaluate the model. For training we use only the training nodes returned from our splitter and the target values. The `shuffle=True` argument is given to the `flow` method to improve training.

# %%
train_gen = generator.flow(train_labels.index, train_targets, shuffle=True)
val_gen = generator.flow(val_labels.index, val_targets, shuffle=True)
test_gen = generator.flow(test_labels.index, test_targets)

# %% [markdown]
# Now we can specify our machine learning model, and use 2 layers of 32 neurons each of them. And a dropout of 0.1 to help the model to generalize.

# %%
graphsage_model = GraphSAGE(
    layer_sizes=[32, 32], generator=generator, bias=True, dropout=0.1 #, activations=["relu"] or  activation=keras.layers.LeakyReLU(alpha=0.01)
)

# %% [markdown]
# Now we create a model to predict the 4 categories using Keras softmax layers.

# %%
x_inp, x_out = graphsage_model.in_out_tensors()
prediction = layers.Dense(units=train_targets.shape[1], activation="softmax")(x_out)

# %%
prediction.shape
# Out:
# TensorShape([None, 4])

# %% [markdown]
# ### Training the model

# %% [markdown]
# Now let's create the actual Keras model with the graph inputs `x_inp` provided by the `graph_model` and outputs being the predictions from the softmax layer

# %%
model = Model(inputs=x_inp, outputs=prediction)
model.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),
    loss=losses.categorical_crossentropy,
    metrics = [metrics.CategoricalAccuracy()]
)
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 10, 5)]      0           []
#
#  input_3 (InputLayer)           [(None, 40, 5)]      0           []
#
#  input_1 (InputLayer)           [(None, 1, 5)]       0           []
#
#  reshape (Reshape)              (None, 1, 10, 5)     0           ['input_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 10, 4, 5)     0           ['input_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 5)         0           ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 1, 10, 5)     0           ['reshape[0][0]']
#
#  dropout_3 (Dropout)            (None, 10, 5)        0           ['input_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 10, 4, 5)     0           ['reshape_1[0][0]']
#
#  mean_aggregator (MeanAggregato  multiple            192         ['dropout_1[0][0]',
#  r)                                                               'dropout[0][0]',
#                                                                   'dropout_3[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 10, 32)    0           ['mean_aggregator[1][0]']
#
#  dropout_5 (Dropout)            (None, 1, 32)        0           ['mean_aggregator[0][0]']
#
#  dropout_4 (Dropout)            (None, 1, 10, 32)    0           ['reshape_2[0][0]']
#
#  mean_aggregator_1 (MeanAggrega  (None, 1, 32)       1056        ['dropout_5[0][0]',
#  tor)                                                             'dropout_4[0][0]']
#
#  reshape_3 (Reshape)            (None, 32)           0           ['mean_aggregator_1[0][0]']
#
#  lambda (Lambda)                (None, 32)           0           ['reshape_3[0][0]']
#
#  dense (Dense)                  (None, 4)            132         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1,380
# Trainable params: 1,380
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Train the model, keeping track of its loss and accuracy on the training set, and its generalisation performance on the validation set.

# %%
#create callback
checkpoint = ModelCheckpoint(filepath=PATH_MODEL_GS_U_B, 
                             monitor='val_categorical_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')

#fit the model
history = model.fit(train_gen, 
                    epochs=100, 
                    validation_data=val_gen, 
                    class_weight=class_weights,
                    verbose=1, 
                    shuffle=True,
                    callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3881 - categorical_accuracy: 0.3252
# Epoch 1: val_categorical_accuracy improved from -inf to 0.05151, saving model to /content/drive/My Drive/WebMining/models/graphsage_undirected_base.hdf5
# 330/330 [==============================] - 43s 111ms/step - loss: 1.3881 - categorical_accuracy: 0.3252 - val_loss: 1.3824 - val_categorical_accuracy: 0.0515
# Epoch 2/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3876 - categorical_accuracy: 0.2542
# Epoch 2: val_categorical_accuracy did not improve from 0.05151
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3874 - categorical_accuracy: 0.2543 - val_loss: 1.3871 - val_categorical_accuracy: 0.0515
# Epoch 3/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3857 - categorical_accuracy: 0.2980
# Epoch 3: val_categorical_accuracy did not improve from 0.05151
# 330/330 [==============================] - 15s 45ms/step - loss: 1.3859 - categorical_accuracy: 0.2978 - val_loss: 1.3874 - val_categorical_accuracy: 0.0515
# Epoch 4/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3871 - categorical_accuracy: 0.2266
# Epoch 4: val_categorical_accuracy improved from 0.05151 to 0.57653, saving model to /content/drive/My Drive/WebMining/models/graphsage_undirected_base.hdf5
# 330/330 [==============================] - 17s 52ms/step - loss: 1.3871 - categorical_accuracy: 0.2266 - val_loss: 1.3833 - val_categorical_accuracy: 0.5765
# Epoch 5/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3855 - categorical_accuracy: 0.2191
# Epoch 5: val_categorical_accuracy improved from 0.57653 to 0.57906, saving model to /content/drive/My Drive/WebMining/models/graphsage_undirected_base.hdf5
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3866 - categorical_accuracy: 0.2193 - val_loss: 1.3796 - val_categorical_accuracy: 0.5791
# Epoch 6/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3869 - categorical_accuracy: 0.2408
# Epoch 6: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3876 - categorical_accuracy: 0.2409 - val_loss: 1.3798 - val_categorical_accuracy: 0.5791
# Epoch 7/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3873 - categorical_accuracy: 0.3211
# Epoch 7: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 14s 44ms/step - loss: 1.3873 - categorical_accuracy: 0.3211 - val_loss: 1.3943 - val_categorical_accuracy: 0.0701
# Epoch 8/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3867 - categorical_accuracy: 0.2175
# Epoch 8: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3867 - categorical_accuracy: 0.2175 - val_loss: 1.3907 - val_categorical_accuracy: 0.0701
# Epoch 9/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2239
# Epoch 9: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 11s 34ms/step - loss: 1.3869 - categorical_accuracy: 0.2243 - val_loss: 1.3841 - val_categorical_accuracy: 0.5791
# Epoch 10/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3875 - categorical_accuracy: 0.2404
# Epoch 10: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 11s 34ms/step - loss: 1.3874 - categorical_accuracy: 0.2407 - val_loss: 1.3892 - val_categorical_accuracy: 0.0701
# Epoch 11/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3863 - categorical_accuracy: 0.2237
# Epoch 11: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3867 - categorical_accuracy: 0.2239 - val_loss: 1.3833 - val_categorical_accuracy: 0.5791
# Epoch 12/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3872 - categorical_accuracy: 0.2768
# Epoch 12: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 13s 40ms/step - loss: 1.3869 - categorical_accuracy: 0.2768 - val_loss: 1.3879 - val_categorical_accuracy: 0.0701
# Epoch 13/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3864 - categorical_accuracy: 0.2202
# Epoch 13: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 11s 34ms/step - loss: 1.3864 - categorical_accuracy: 0.2202 - val_loss: 1.3863 - val_categorical_accuracy: 0.3057
# Epoch 14/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3863 - categorical_accuracy: 0.2481
# Epoch 14: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3863 - categorical_accuracy: 0.2481 - val_loss: 1.3828 - val_categorical_accuracy: 0.5791
# Epoch 15/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2649
# Epoch 15: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3860 - categorical_accuracy: 0.2647 - val_loss: 1.3863 - val_categorical_accuracy: 0.0701
# Epoch 16/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2662
# Epoch 16: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 38ms/step - loss: 1.3865 - categorical_accuracy: 0.2662 - val_loss: 1.3913 - val_categorical_accuracy: 0.0701
# Epoch 17/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2406
# Epoch 17: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 13s 39ms/step - loss: 1.3865 - categorical_accuracy: 0.2406 - val_loss: 1.3885 - val_categorical_accuracy: 0.0701
# Epoch 18/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3866 - categorical_accuracy: 0.2587
# Epoch 18: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3866 - categorical_accuracy: 0.2584 - val_loss: 1.3922 - val_categorical_accuracy: 0.0540
# Epoch 19/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3862 - categorical_accuracy: 0.2539
# Epoch 19: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3862 - categorical_accuracy: 0.2539 - val_loss: 1.3914 - val_categorical_accuracy: 0.0540
# Epoch 20/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3860 - categorical_accuracy: 0.2139
# Epoch 20: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3860 - categorical_accuracy: 0.2139 - val_loss: 1.3851 - val_categorical_accuracy: 0.5791
# Epoch 21/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3864 - categorical_accuracy: 0.2528
# Epoch 21: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3863 - categorical_accuracy: 0.2526 - val_loss: 1.3879 - val_categorical_accuracy: 0.0701
# Epoch 22/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3870 - categorical_accuracy: 0.2471
# Epoch 22: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3861 - categorical_accuracy: 0.2472 - val_loss: 1.3884 - val_categorical_accuracy: 0.0701
# Epoch 23/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3863 - categorical_accuracy: 0.2474
# Epoch 23: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3863 - categorical_accuracy: 0.2474 - val_loss: 1.3867 - val_categorical_accuracy: 0.0701
# Epoch 24/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3863 - categorical_accuracy: 0.1938
# Epoch 24: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3863 - categorical_accuracy: 0.1937 - val_loss: 1.3888 - val_categorical_accuracy: 0.0701
# Epoch 25/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3873 - categorical_accuracy: 0.2611
# Epoch 25: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3873 - categorical_accuracy: 0.2611 - val_loss: 1.3906 - val_categorical_accuracy: 0.0701
# Epoch 26/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3862 - categorical_accuracy: 0.1996
# Epoch 26: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3862 - categorical_accuracy: 0.1996 - val_loss: 1.3863 - val_categorical_accuracy: 0.0540
# Epoch 27/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3861 - categorical_accuracy: 0.1962
# Epoch 27: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3865 - categorical_accuracy: 0.1964 - val_loss: 1.3839 - val_categorical_accuracy: 0.3057
# Epoch 28/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3864 - categorical_accuracy: 0.2417
# Epoch 28: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3864 - categorical_accuracy: 0.2417 - val_loss: 1.3839 - val_categorical_accuracy: 0.5791
# Epoch 29/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3866 - categorical_accuracy: 0.2373
# Epoch 29: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3866 - categorical_accuracy: 0.2373 - val_loss: 1.3864 - val_categorical_accuracy: 0.0540
# Epoch 30/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3859 - categorical_accuracy: 0.1886
# Epoch 30: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3871 - categorical_accuracy: 0.1885 - val_loss: 1.3824 - val_categorical_accuracy: 0.5791
# Epoch 31/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2498
# Epoch 31: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3865 - categorical_accuracy: 0.2498 - val_loss: 1.3896 - val_categorical_accuracy: 0.0701
# Epoch 32/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2250
# Epoch 32: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3865 - categorical_accuracy: 0.2250 - val_loss: 1.3868 - val_categorical_accuracy: 0.0701
# Epoch 33/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.1737
# Epoch 33: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3868 - categorical_accuracy: 0.1740 - val_loss: 1.3800 - val_categorical_accuracy: 0.5791
# Epoch 34/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2956
# Epoch 34: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3865 - categorical_accuracy: 0.2956 - val_loss: 1.3919 - val_categorical_accuracy: 0.0540
# Epoch 35/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3863 - categorical_accuracy: 0.1966
# Epoch 35: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3863 - categorical_accuracy: 0.1966 - val_loss: 1.3860 - val_categorical_accuracy: 0.0540
# Epoch 36/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3854 - categorical_accuracy: 0.2430
# Epoch 36: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3860 - categorical_accuracy: 0.2433 - val_loss: 1.3853 - val_categorical_accuracy: 0.5791
# Epoch 37/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3866 - categorical_accuracy: 0.1996
# Epoch 37: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3866 - categorical_accuracy: 0.1996 - val_loss: 1.3848 - val_categorical_accuracy: 0.5791
# Epoch 38/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2843
# Epoch 38: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3862 - categorical_accuracy: 0.2838 - val_loss: 1.3906 - val_categorical_accuracy: 0.0540
# Epoch 39/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3860 - categorical_accuracy: 0.2082
# Epoch 39: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3860 - categorical_accuracy: 0.2082 - val_loss: 1.3848 - val_categorical_accuracy: 0.5791
# Epoch 40/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3875 - categorical_accuracy: 0.2276
# Epoch 40: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3864 - categorical_accuracy: 0.2274 - val_loss: 1.3875 - val_categorical_accuracy: 0.0701
# Epoch 41/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3862 - categorical_accuracy: 0.2484
# Epoch 41: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3857 - categorical_accuracy: 0.2483 - val_loss: 1.3906 - val_categorical_accuracy: 0.0701
# Epoch 42/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3861 - categorical_accuracy: 0.2193
# Epoch 42: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3861 - categorical_accuracy: 0.2193 - val_loss: 1.3891 - val_categorical_accuracy: 0.0540
# Epoch 43/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3864 - categorical_accuracy: 0.2017
# Epoch 43: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3863 - categorical_accuracy: 0.2014 - val_loss: 1.3908 - val_categorical_accuracy: 0.0701
# Epoch 44/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3866 - categorical_accuracy: 0.2149
# Epoch 44: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3864 - categorical_accuracy: 0.2147 - val_loss: 1.3866 - val_categorical_accuracy: 0.3057
# Epoch 45/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3862 - categorical_accuracy: 0.2139
# Epoch 45: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3862 - categorical_accuracy: 0.2141 - val_loss: 1.3832 - val_categorical_accuracy: 0.3057
# Epoch 46/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3867 - categorical_accuracy: 0.2540
# Epoch 46: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3862 - categorical_accuracy: 0.2539 - val_loss: 1.3845 - val_categorical_accuracy: 0.0701
# Epoch 47/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3867 - categorical_accuracy: 0.2819
# Epoch 47: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3860 - categorical_accuracy: 0.2816 - val_loss: 1.3889 - val_categorical_accuracy: 0.0701
# Epoch 48/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3852 - categorical_accuracy: 0.2100
# Epoch 48: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3863 - categorical_accuracy: 0.2101 - val_loss: 1.3848 - val_categorical_accuracy: 0.5791
# Epoch 49/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3866 - categorical_accuracy: 0.2227
# Epoch 49: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3866 - categorical_accuracy: 0.2227 - val_loss: 1.3865 - val_categorical_accuracy: 0.0540
# Epoch 50/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2400
# Epoch 50: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3860 - categorical_accuracy: 0.2399 - val_loss: 1.3876 - val_categorical_accuracy: 0.0540
# Epoch 51/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3861 - categorical_accuracy: 0.2247
# Epoch 51: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3859 - categorical_accuracy: 0.2249 - val_loss: 1.3830 - val_categorical_accuracy: 0.5791
# Epoch 52/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3861 - categorical_accuracy: 0.2826
# Epoch 52: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3861 - categorical_accuracy: 0.2826 - val_loss: 1.3926 - val_categorical_accuracy: 0.0540
# Epoch 53/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3866 - categorical_accuracy: 0.1987
# Epoch 53: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3859 - categorical_accuracy: 0.1985 - val_loss: 1.3860 - val_categorical_accuracy: 0.0540
# Epoch 54/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3861 - categorical_accuracy: 0.2127
# Epoch 54: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3855 - categorical_accuracy: 0.2130 - val_loss: 1.3843 - val_categorical_accuracy: 0.5791
# Epoch 55/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3857 - categorical_accuracy: 0.2273
# Epoch 55: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3857 - categorical_accuracy: 0.2273 - val_loss: 1.3840 - val_categorical_accuracy: 0.0701
# Epoch 56/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3865 - categorical_accuracy: 0.2090
# Epoch 56: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3865 - categorical_accuracy: 0.2090 - val_loss: 1.3819 - val_categorical_accuracy: 0.5791
# Epoch 57/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3866 - categorical_accuracy: 0.2191
# Epoch 57: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3866 - categorical_accuracy: 0.2191 - val_loss: 1.3842 - val_categorical_accuracy: 0.5791
# Epoch 58/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3856 - categorical_accuracy: 0.2709
# Epoch 58: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3859 - categorical_accuracy: 0.2707 - val_loss: 1.3861 - val_categorical_accuracy: 0.0540
# Epoch 59/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3858 - categorical_accuracy: 0.2495
# Epoch 59: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3858 - categorical_accuracy: 0.2495 - val_loss: 1.3864 - val_categorical_accuracy: 0.0540
# Epoch 60/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3857 - categorical_accuracy: 0.1691
# Epoch 60: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3857 - categorical_accuracy: 0.1691 - val_loss: 1.3814 - val_categorical_accuracy: 0.5791
# Epoch 61/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3861 - categorical_accuracy: 0.2911
# Epoch 61: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3861 - categorical_accuracy: 0.2911 - val_loss: 1.3879 - val_categorical_accuracy: 0.0540
# Epoch 62/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3872 - categorical_accuracy: 0.2579
# Epoch 62: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3864 - categorical_accuracy: 0.2578 - val_loss: 1.3911 - val_categorical_accuracy: 0.0701
# Epoch 63/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3858 - categorical_accuracy: 0.2273
# Epoch 63: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3856 - categorical_accuracy: 0.2269 - val_loss: 1.3893 - val_categorical_accuracy: 0.0701
# Epoch 64/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3867 - categorical_accuracy: 0.1956
# Epoch 64: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3862 - categorical_accuracy: 0.1959 - val_loss: 1.3866 - val_categorical_accuracy: 0.0701
# Epoch 65/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3872 - categorical_accuracy: 0.2871
# Epoch 65: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3864 - categorical_accuracy: 0.2867 - val_loss: 1.3929 - val_categorical_accuracy: 0.0701
# Epoch 66/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3859 - categorical_accuracy: 0.2283
# Epoch 66: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3859 - categorical_accuracy: 0.2283 - val_loss: 1.3878 - val_categorical_accuracy: 0.0540
# Epoch 67/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3857 - categorical_accuracy: 0.1824
# Epoch 67: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3857 - categorical_accuracy: 0.1824 - val_loss: 1.3849 - val_categorical_accuracy: 0.3057
# Epoch 68/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3867 - categorical_accuracy: 0.2648
# Epoch 68: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3862 - categorical_accuracy: 0.2648 - val_loss: 1.3881 - val_categorical_accuracy: 0.0540
# Epoch 69/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3853 - categorical_accuracy: 0.2317
# Epoch 69: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3858 - categorical_accuracy: 0.2317 - val_loss: 1.3896 - val_categorical_accuracy: 0.0701
# Epoch 70/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3852 - categorical_accuracy: 0.1996
# Epoch 70: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 11s 35ms/step - loss: 1.3859 - categorical_accuracy: 0.1995 - val_loss: 1.3893 - val_categorical_accuracy: 0.0705
# Epoch 71/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3868 - categorical_accuracy: 0.1827
# Epoch 71: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3861 - categorical_accuracy: 0.1831 - val_loss: 1.3846 - val_categorical_accuracy: 0.0540
# Epoch 72/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3861 - categorical_accuracy: 0.2280
# Epoch 72: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3861 - categorical_accuracy: 0.2280 - val_loss: 1.3853 - val_categorical_accuracy: 0.5791
# Epoch 73/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3869 - categorical_accuracy: 0.2408
# Epoch 73: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3863 - categorical_accuracy: 0.2407 - val_loss: 1.3886 - val_categorical_accuracy: 0.0540
# Epoch 74/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3859 - categorical_accuracy: 0.2298
# Epoch 74: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3859 - categorical_accuracy: 0.2298 - val_loss: 1.3827 - val_categorical_accuracy: 0.5791
# Epoch 75/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3866 - categorical_accuracy: 0.2439
# Epoch 75: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3858 - categorical_accuracy: 0.2436 - val_loss: 1.3866 - val_categorical_accuracy: 0.0701
# Epoch 76/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3855 - categorical_accuracy: 0.3094
# Epoch 76: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3856 - categorical_accuracy: 0.3092 - val_loss: 1.3945 - val_categorical_accuracy: 0.0701
# Epoch 77/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3859 - categorical_accuracy: 0.1431
# Epoch 77: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 11s 35ms/step - loss: 1.3859 - categorical_accuracy: 0.1431 - val_loss: 1.3879 - val_categorical_accuracy: 0.0540
# Epoch 78/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3855 - categorical_accuracy: 0.2248
# Epoch 78: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3855 - categorical_accuracy: 0.2248 - val_loss: 1.3840 - val_categorical_accuracy: 0.5791
# Epoch 79/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3863 - categorical_accuracy: 0.2474
# Epoch 79: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3855 - categorical_accuracy: 0.2474 - val_loss: 1.3819 - val_categorical_accuracy: 0.5791
# Epoch 80/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3861 - categorical_accuracy: 0.2118
# Epoch 80: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3857 - categorical_accuracy: 0.2121 - val_loss: 1.3807 - val_categorical_accuracy: 0.5791
# Epoch 81/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3864 - categorical_accuracy: 0.2759
# Epoch 81: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3864 - categorical_accuracy: 0.2759 - val_loss: 1.3830 - val_categorical_accuracy: 0.5791
# Epoch 82/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3851 - categorical_accuracy: 0.2337
# Epoch 82: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3857 - categorical_accuracy: 0.2338 - val_loss: 1.3861 - val_categorical_accuracy: 0.0701
# Epoch 83/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3857 - categorical_accuracy: 0.2250
# Epoch 83: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3858 - categorical_accuracy: 0.2250 - val_loss: 1.3832 - val_categorical_accuracy: 0.5791
# Epoch 84/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3863 - categorical_accuracy: 0.2169
# Epoch 84: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 38ms/step - loss: 1.3861 - categorical_accuracy: 0.2170 - val_loss: 1.3853 - val_categorical_accuracy: 0.5788
# Epoch 85/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3849 - categorical_accuracy: 0.2672
# Epoch 85: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3858 - categorical_accuracy: 0.2669 - val_loss: 1.3868 - val_categorical_accuracy: 0.0540
# Epoch 86/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3855 - categorical_accuracy: 0.2220
# Epoch 86: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3858 - categorical_accuracy: 0.2221 - val_loss: 1.3852 - val_categorical_accuracy: 0.0540
# Epoch 87/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3867 - categorical_accuracy: 0.2211
# Epoch 87: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3859 - categorical_accuracy: 0.2212 - val_loss: 1.3884 - val_categorical_accuracy: 0.0701
# Epoch 88/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3868 - categorical_accuracy: 0.2309
# Epoch 88: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3862 - categorical_accuracy: 0.2307 - val_loss: 1.3876 - val_categorical_accuracy: 0.0701
# Epoch 89/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3847 - categorical_accuracy: 0.2205
# Epoch 89: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3858 - categorical_accuracy: 0.2207 - val_loss: 1.3851 - val_categorical_accuracy: 0.0701
# Epoch 90/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3860 - categorical_accuracy: 0.1997
# Epoch 90: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3860 - categorical_accuracy: 0.1997 - val_loss: 1.3856 - val_categorical_accuracy: 0.0701
# Epoch 91/100
# 328/330 [============================>.] - ETA: 0s - loss: 1.3850 - categorical_accuracy: 0.2767
# Epoch 91: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3857 - categorical_accuracy: 0.2770 - val_loss: 1.3858 - val_categorical_accuracy: 0.0701
# Epoch 92/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3856 - categorical_accuracy: 0.2290
# Epoch 92: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 38ms/step - loss: 1.3856 - categorical_accuracy: 0.2290 - val_loss: 1.3842 - val_categorical_accuracy: 0.0701
# Epoch 93/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3858 - categorical_accuracy: 0.2453
# Epoch 93: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 13s 38ms/step - loss: 1.3860 - categorical_accuracy: 0.2454 - val_loss: 1.3872 - val_categorical_accuracy: 0.0701
# Epoch 94/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3856 - categorical_accuracy: 0.2055
# Epoch 94: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3854 - categorical_accuracy: 0.2052 - val_loss: 1.3865 - val_categorical_accuracy: 0.0540
# Epoch 95/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3858 - categorical_accuracy: 0.1921
# Epoch 95: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3858 - categorical_accuracy: 0.1921 - val_loss: 1.3831 - val_categorical_accuracy: 0.5791
# Epoch 96/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3853 - categorical_accuracy: 0.2718
# Epoch 96: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3853 - categorical_accuracy: 0.2718 - val_loss: 1.3883 - val_categorical_accuracy: 0.0701
# Epoch 97/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3842 - categorical_accuracy: 0.2301
# Epoch 97: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 37ms/step - loss: 1.3854 - categorical_accuracy: 0.2298 - val_loss: 1.3864 - val_categorical_accuracy: 0.0701
# Epoch 98/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3850 - categorical_accuracy: 0.2699
# Epoch 98: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 35ms/step - loss: 1.3850 - categorical_accuracy: 0.2699 - val_loss: 1.3898 - val_categorical_accuracy: 0.0701
# Epoch 99/100
# 330/330 [==============================] - ETA: 0s - loss: 1.3853 - categorical_accuracy: 0.2035
# Epoch 99: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 12s 36ms/step - loss: 1.3853 - categorical_accuracy: 0.2035 - val_loss: 1.3875 - val_categorical_accuracy: 0.0540
# Epoch 100/100
# 329/330 [============================>.] - ETA: 0s - loss: 1.3857 - categorical_accuracy: 0.2128
# Epoch 100: val_categorical_accuracy did not improve from 0.57906
# 330/330 [==============================] - 13s 38ms/step - loss: 1.3853 - categorical_accuracy: 0.2129 - val_loss: 1.3864 - val_categorical_accuracy: 0.0701

# %%
sg.utils.plot_history(history)

# %% [markdown]
# ### Evaluate the Model

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# Now we have trained the model we can evaluate on the test set.

# %%
# Make prediction
predictions = model.predict(test_gen)
predictions = target_encoding.inverse_transform(predictions)
results = pd.Series(predictions, index=test_labels.index)

test_gen = generator.flow(test_labels.index, test_targets)

# Evaluation Metrics
cm = confusion_matrix(test_labels, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Undirected GraphSAGE on Test Set")
print(classification_report(test_labels, results))

# Performance
test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.01      0.02       714
#            1       0.00      0.00      0.00      1345
#            2       0.07      1.00      0.13       156
#            3       0.00      0.00      0.00       119
#
#     accuracy                           0.07      2334
#    macro avg       0.24      0.25      0.04      2334
# weighted avg       0.27      0.07      0.01      2334
#
#  1/47 [..............................] - ETA: 3s - loss: 1.3883 - categorical_accuracy: 0.0800
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 47/47 [==============================] - 1s 26ms/step - loss: 1.3864 - categorical_accuracy: 0.0698
#
# Test Set Metrics:
# 	loss: 1.3864
# 	categorical_accuracy: 0.0698

# %% [markdown]
# ## Making predictions with the model in papers pubblished in 2002 and *2003*

# %%
#Load and evaluate the best model version
model = load_model(PATH_MODEL_GS_U_B, custom_objects={'MeanAggregator': MeanAggregator})

# %%
# Introduce prediction nodes
generator = GraphSAGENodeGenerator(graph_citation_full, batch_size, num_samples)
prediction_targets = target_encoding.transform(test_nodes)
prediction_gen = generator.flow(test_nodes.index, prediction_targets)

# Make prediction
predictions = model.predict(prediction_gen)
predictions = target_encoding.inverse_transform(predictions)

# Create prediction dataset
results = pd.Series(predictions, index=test_nodes.index)
df_results = pd.DataFrame({"Predicted": results, "True": test_nodes})

# Evaluation Metrics
cm = confusion_matrix(test_nodes, results) #results intead of predictions
plot_confusion_matrix(cm, classes = unique_labels(train_labels), title = "Undirected GraphSAGE on Prediction Set")
print(classification_report(test_nodes, results))

# Performance
prediction_metrics = model.evaluate(prediction_gen)
print("\nPrediction Set Metrics:")
for name, val in zip(model.metrics_names, prediction_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1537
#            1       0.53      1.00      0.69      2209
#            2       0.00      0.00      0.00       233
#            3       0.00      0.00      0.00       204
#
#     accuracy                           0.53      4183
#    macro avg       0.13      0.25      0.17      4183
# weighted avg       0.28      0.53      0.37      4183
#
# 84/84 [==============================] - 3s 27ms/step - loss: 1.3802 - categorical_accuracy: 0.5281
#
# Prediction Set Metrics:
# 	loss: 1.3802
# 	categorical_accuracy: 0.5281
